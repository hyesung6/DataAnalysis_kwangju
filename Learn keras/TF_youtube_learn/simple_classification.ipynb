# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')

from termcolor import colored

n_sample = 100
x_train = np.random.normal(0, 1, size=(n_sample, 1)).astype('float32')
y_train = (x_train >= 0).astype(np.float32)

# fig, ax = plt.subplots(figsize=(12, 8))
# ax.scatter(x_train, y_train)
# ax.tick_params(labelsize=20)

class classifier(tf.keras.Model):
    def __init__(self):
        super(classifier, self).__init__()
        
        self.d1 = tf.keras.layers.Dense(units=1, activation='sigmoid')
        
    def call(self, x):
        predictions = self.d1(x)
        return predictions

LR = 0.01
EPOCHS = 100
model = classifier()
loss_object = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.SGD(learning_rate=LR)

loss_metric = tf.keras.metrics.Mean()
acc_metric = tf.keras.metrics.CategoricalAccuracy()

# %%
for epoch in range(EPOCHS):
    for x, y in zip(x_train, y_train):
        x = tf.reshape(x, (-1, 1))
        y = tf.reshape(y, (-1, 1))
        
        with tf.GradientTape() as tape:
            predictions = model(x)
            loss = loss_object(y, predictions)
            
        gradients = tape.gradient(loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))
        
        loss_metric(loss)
        acc_metric(y, predictions)
        
    print(colored('Epoch: ', 'cyan', 'on_white'), epoch + 1)
    template = 'Train loss : {:.6f}\t Train Accuracy: {:.2f}%'
    
    ds_loss = loss_metric.result()
    ds_acc = acc_metric.result()
    
    print(template.format(ds_loss, ds_acc*100))
    
    loss_metric.reset_states()
    acc_metric.reset_states()
# Out:
# Epoch:  1
# Train loss : 0.699018	 Train Accuracy: 100.00%
# Epoch:  2
# Train loss : 0.619860	 Train Accuracy: 100.00%
# Epoch:  3
# Train loss : 0.562101	 Train Accuracy: 100.00%
# Epoch:  4
# Train loss : 0.517926	 Train Accuracy: 100.00%
# Epoch:  5
# Train loss : 0.482822	 Train Accuracy: 100.00%
# Epoch:  6
# Train loss : 0.454083	 Train Accuracy: 100.00%
# Epoch:  7
# Train loss : 0.429999	 Train Accuracy: 100.00%
# Epoch:  8
# Train loss : 0.409437	 Train Accuracy: 100.00%
# Epoch:  9
# Train loss : 0.391612	 Train Accuracy: 100.00%
# Epoch:  10
# Train loss : 0.375965	 Train Accuracy: 100.00%
# Epoch:  11
# Train loss : 0.362085	 Train Accuracy: 100.00%
# Epoch:  12
# Train loss : 0.349661	 Train Accuracy: 100.00%
# Epoch:  13
# Train loss : 0.338454	 Train Accuracy: 100.00%
# Epoch:  14
# Train loss : 0.328278	 Train Accuracy: 100.00%
# Epoch:  15
# Train loss : 0.318983	 Train Accuracy: 100.00%
# Epoch:  16
# Train loss : 0.310447	 Train Accuracy: 100.00%
# Epoch:  17
# Train loss : 0.302574	 Train Accuracy: 100.00%
# Epoch:  18
# Train loss : 0.295281	 Train Accuracy: 100.00%
# Epoch:  19
# Train loss : 0.288500	 Train Accuracy: 100.00%
# Epoch:  20
# Train loss : 0.282173	 Train Accuracy: 100.00%
# Epoch:  21
# Train loss : 0.276253	 Train Accuracy: 100.00%
# Epoch:  22
# Train loss : 0.270696	 Train Accuracy: 100.00%
# Epoch:  23
# Train loss : 0.265469	 Train Accuracy: 100.00%
# Epoch:  24
# Train loss : 0.260538	 Train Accuracy: 100.00%
# Epoch:  25
# Train loss : 0.255878	 Train Accuracy: 100.00%
# Epoch:  26
# Train loss : 0.251464	 Train Accuracy: 100.00%
# Epoch:  27
# Train loss : 0.247275	 Train Accuracy: 100.00%
# Epoch:  28
# Train loss : 0.243293	 Train Accuracy: 100.00%
# Epoch:  29
# Train loss : 0.239501	 Train Accuracy: 100.00%
# Epoch:  30
# Train loss : 0.235885	 Train Accuracy: 100.00%
# Epoch:  31
# Train loss : 0.232432	 Train Accuracy: 100.00%
# Epoch:  32
# Train loss : 0.229129	 Train Accuracy: 100.00%
# Epoch:  33
# Train loss : 0.225966	 Train Accuracy: 100.00%
# Epoch:  34
# Train loss : 0.222934	 Train Accuracy: 100.00%
# Epoch:  35
# Train loss : 0.220024	 Train Accuracy: 100.00%
# Epoch:  36
# Train loss : 0.217227	 Train Accuracy: 100.00%
# Epoch:  37
# Train loss : 0.214538	 Train Accuracy: 100.00%
# Epoch:  38
# Train loss : 0.211948	 Train Accuracy: 100.00%
# Epoch:  39
# Train loss : 0.209452	 Train Accuracy: 100.00%
# Epoch:  40
# Train loss : 0.207045	 Train Accuracy: 100.00%
# Epoch:  41
# Train loss : 0.204721	 Train Accuracy: 100.00%
# Epoch:  42
# Train loss : 0.202476	 Train Accuracy: 100.00%
# Epoch:  43
# Train loss : 0.200306	 Train Accuracy: 100.00%
# Epoch:  44
# Train loss : 0.198206	 Train Accuracy: 100.00%
# Epoch:  45
# Train loss : 0.196172	 Train Accuracy: 100.00%
# Epoch:  46
# Train loss : 0.194202	 Train Accuracy: 100.00%
# Epoch:  47
# Train loss : 0.192292	 Train Accuracy: 100.00%
# Epoch:  48
# Train loss : 0.190439	 Train Accuracy: 100.00%
# Epoch:  49
# Train loss : 0.188640	 Train Accuracy: 100.00%
# Epoch:  50
# Train loss : 0.186893	 Train Accuracy: 100.00%
# Epoch:  51
# Train loss : 0.185195	 Train Accuracy: 100.00%
# Epoch:  52
# Train loss : 0.183545	 Train Accuracy: 100.00%
# Epoch:  53
# Train loss : 0.181939	 Train Accuracy: 100.00%
# Epoch:  54
# Train loss : 0.180376	 Train Accuracy: 100.00%
# Epoch:  55
# Train loss : 0.178855	 Train Accuracy: 100.00%
# Epoch:  56
# Train loss : 0.177372	 Train Accuracy: 100.00%
# Epoch:  57
# Train loss : 0.175928	 Train Accuracy: 100.00%
# Epoch:  58
# Train loss : 0.174519	 Train Accuracy: 100.00%
# Epoch:  59
# Train loss : 0.173145	 Train Accuracy: 100.00%
# Epoch:  60
# Train loss : 0.171805	 Train Accuracy: 100.00%
# Epoch:  61
# Train loss : 0.170496	 Train Accuracy: 100.00%
# Epoch:  62
# Train loss : 0.169218	 Train Accuracy: 100.00%
# Epoch:  63
# Train loss : 0.167970	 Train Accuracy: 100.00%
# Epoch:  64
# Train loss : 0.166750	 Train Accuracy: 100.00%
# Epoch:  65
# Train loss : 0.165557	 Train Accuracy: 100.00%
# Epoch:  66
# Train loss : 0.164391	 Train Accuracy: 100.00%
# Epoch:  67
# Train loss : 0.163250	 Train Accuracy: 100.00%
# Epoch:  68
# Train loss : 0.162134	 Train Accuracy: 100.00%
# Epoch:  69
# Train loss : 0.161041	 Train Accuracy: 100.00%
# Epoch:  70
# Train loss : 0.159971	 Train Accuracy: 100.00%
# Epoch:  71
# Train loss : 0.158924	 Train Accuracy: 100.00%
# Epoch:  72
# Train loss : 0.157897	 Train Accuracy: 100.00%
# Epoch:  73
# Train loss : 0.156892	 Train Accuracy: 100.00%
# Epoch:  74
# Train loss : 0.155906	 Train Accuracy: 100.00%
# Epoch:  75
# Train loss : 0.154939	 Train Accuracy: 100.00%
# Epoch:  76
# Train loss : 0.153992	 Train Accuracy: 100.00%
# Epoch:  77
# Train loss : 0.153062	 Train Accuracy: 100.00%
# Epoch:  78
# Train loss : 0.152150	 Train Accuracy: 100.00%
# Epoch:  79
# Train loss : 0.151255	 Train Accuracy: 100.00%
# Epoch:  80
# Train loss : 0.150376	 Train Accuracy: 100.00%
# Epoch:  81
# Train loss : 0.149513	 Train Accuracy: 100.00%
# Epoch:  82
# Train loss : 0.148666	 Train Accuracy: 100.00%
# Epoch:  83
# Train loss : 0.147834	 Train Accuracy: 100.00%
# Epoch:  84
# Train loss : 0.147017	 Train Accuracy: 100.00%
# Epoch:  85
# Train loss : 0.146214	 Train Accuracy: 100.00%
# Epoch:  86
# Train loss : 0.145424	 Train Accuracy: 100.00%
# Epoch:  87
# Train loss : 0.144648	 Train Accuracy: 100.00%
# Epoch:  88
# Train loss : 0.143885	 Train Accuracy: 100.00%
# Epoch:  89
# Train loss : 0.143135	 Train Accuracy: 100.00%
# Epoch:  90
# Train loss : 0.142397	 Train Accuracy: 100.00%
# Epoch:  91
# Train loss : 0.141671	 Train Accuracy: 100.00%
# Epoch:  92
# Train loss : 0.140957	 Train Accuracy: 100.00%
# Epoch:  93
# Train loss : 0.140254	 Train Accuracy: 100.00%
# Epoch:  94
# Train loss : 0.139562	 Train Accuracy: 100.00%
# Epoch:  95
# Train loss : 0.138881	 Train Accuracy: 100.00%
# Epoch:  96
# Train loss : 0.138211	 Train Accuracy: 100.00%
# Epoch:  97
# Train loss : 0.137551	 Train Accuracy: 100.00%
# Epoch:  98
# Train loss : 0.136901	 Train Accuracy: 100.00%
# Epoch:  99
# Train loss : 0.136261	 Train Accuracy: 100.00%
# Epoch:  100
# Train loss : 0.135630	 Train Accuracy: 100.00%
