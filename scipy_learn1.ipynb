# %%
import scipy as sp
import scipy.stats

# %%
rv = sp.stats.norm()

# %%
'''
확률분포 객체는 모수를 인수로 갖는다.
확률분포마다 모수 설정은 조금씩 다를 수 있지만
공통적으로 
loc : 일반적으로 분포의 기댓값       --> 평균 
scale : 일반적으로 분포의 표준편차   --> 분산
를 모수로 갖는다.

'''

# %%
# 기댓값이 1이고, 표준편차가 2인 정규분포 객체 생성
rv = sp.stats.norm(loc=1, scale=2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
type(rv)
# Out:
# scipy.stats._distn_infrastructure.rv_frozen

# %%
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)   # FutureWarning 제거

import pandas as pd
import numpy as np
import math
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

font_family = 'Malgun Gothic'

sns.set(font=font_family, rc={'axes.unicode_minus' : False})

# %%
xx = np.linspace(-8, 8, 100)
pdf = rv.pdf(xx)
plt.plot(xx, pdf)
plt.title("확률밀도함수 ( PDF )")
plt.show()

# %%
# 기댓값이 0이고 표준 편차가 0.1인 정규분포 객체를 만들고 확률밀도함수를 그려라
dist = sp.stats.norm(loc= 0 , scale=0.1)
pdf = dist.pdf(xx)
plt.plot(xx, pdf)
plt.show()

# %%
# 확률밀도함수의 최댓값은?
pdf.max()
# Out:
# 2.8781544236067225

# %%
len(pdf)
# Out:
# 100

# %%
xxx = np.linspace(-8, 20, 100)

# %%
dist.pdf(xx)   # 확률밀도함수를 구할 때, x축 인자가 무조건 들어가야 함
# Out:
# array([0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 2.36375953e-313, 2.91113621e-287,
#        2.63120065e-262, 1.74533024e-238, 8.49637103e-216, 3.03543915e-194,
#        7.95869389e-174, 1.53141987e-154, 2.16261376e-136, 2.24127865e-119,
#        1.70468819e-103, 9.51538264e-089, 3.89798147e-075, 1.17188634e-062,
#        2.58561238e-051, 4.18671649e-041, 4.97526130e-032, 4.33900793e-024,
#        2.77713633e-017, 1.30447621e-011, 4.49683896e-007, 1.13765535e-003,
# ...

# %%
pdf2 = dist.pdf(xxx)
pdf2.max()
# Out:
# 2.8781544236067016

# %%
plt.plot(xxx, pdf2)

# %%
# 표준화 :

# 표준정규분포는 평균이 0, 표준편차가 1인 정규분포.

# 정규분포는 최댓값 축에서부터의 넓이에 따른 확률이 정해져있음
# 모든 정규분포는 넓이가 1로 정해져있고
# 모두 모양이 같으므로,
# 표준정규분포가 아니더라도 해당 정규분포의 넓이를 알면
# 표준정규분포에 대입하여, 확률을 구해낼 수 있음

# 표준정규분포 표현식 :   N(0, 1)

# %%
plt.plot(xxx, rv.cdf(xxx))

# %%
# 확률밀도함수 : 특정 구간의 확률을 나타내기 위한 함수. ( 연속확률분포에서 사용됨 )
# 이산확률분포와 다르게 연속된 값을 가지고 있으므로 지점을 딱 정할 수 없고
# 구간을 정해서 그 확률을 구함..

# 숫자가 1~12까지 있을 때, 1~5까지의 확률밀도함수 5/12


# 누적분포함수 : 주어진 확률분포에서 확률변수가 특정 값보다 작거나 같을 확률
# 숫자가 1~12까지 있을 때, 1~5까지의 확률밀도함수 5/12 이면,
# 5보다 작을 확률 ( =누적분포함수 ) 은 5/12

# 확률밀도함수와 누적분포함수는 서로 미적분 관계
# 확률밀도함수를 적분하면 누적분포함수
# 누적분포함수를 미분하면 확률밀도함수

# %%
# 이산확률분포에서 확률의 분포를 나타내기 위한 함수는
# 확률질량함수 ( PMF ) 라고 함

# %%
cdf = dist.cdf(xx)
plt.plot(xx, cdf)

# %%
import sympy

sympy.init_printing(use_latex='mathjax')

# %%
# 누적분포함수 ( Cumulative Distribution Function, CDF )
xx = np.linspace(-8, 8, 100)
cdf = rv.cdf(xx)
plt.plot(xx, cdf)
plt.show()

# %%
# 무작위 표본 생성
# Random Value Sampling, RVS
# rvs(size=(3, 5), random_state=0)
# size : 표본 생성 시 생성될 표본의 배열 크기
# random_state : 난수 시드 값

# %%
rv.rvs(size=(3,5), random_state=42)
# Out:
# array([[ 1.99342831,  0.7234714 ,  2.29537708,  4.04605971,  0.53169325],
#        [ 0.53172609,  4.15842563,  2.53486946,  0.06105123,  2.08512009],
#        [ 0.07316461,  0.06854049,  1.48392454, -2.82656049, -2.44983567]])

# %%
sns.distplot(rv.rvs(size=(4,5), random_state=42))
plt.title('RVS 랜덤 샘플링 결과')
plt.xlabel('표본값')
plt.ylabel('count')
plt.show()


# xlabel은 x축 레이블 이름을 설정
# ylabel은 y축 레이블 이름을 설정
# xlim은 x축 최소~최대값의 범위 설정
# ylim은 y축 최소~최대값의 범위 설정

# %%
sns.distplot(rv.rvs(size=(4,5), random_state=42))
plt.title('RVS 랜덤 샘플링 결과')
plt.xlabel('표본값')
plt.ylabel('count')
plt.xlim(-8, 8)
plt.ylim(0, 1)
plt.show()

# %%
# 연습문제
# rvs로 1000개의 정규분포 표본 데이터 생성하고,
# 표본 데이터로부터 표본평균과 표본분산을 도출해내고
# 도출 값을 모수로 지정한 기댓값(평균) 및 표준편차(분산)와 비교하라

rv = stats.norm(loc=11, scale=3)
rvs_ = rv.rvs(size=(100,10), random_state=22)

# %%
rvs_.mean()
# Out:
# 11.074726625857224

# %%
rvs_.std()
# Out:
# 3.1529032693965866

# %%
print('norm() 정규분포 객체 생성 시 입력한 기댓값 : 11')
print('norm() 정규분포 객체 생성 시 입력한 표준편차 : 3')
print(f'rvs() 무작위 표본 데이터의 기댓값 : {rvs_.mean():.5f}')
print(f'rvs() 무작위 표본 데이터의 표준편차 : {rvs_.std():.5f}')
# Out:
# norm() 정규분포 객체 생성 시 입력한 기댓값 : 11
# norm() 정규분포 객체 생성 시 입력한 표준편차 : 3
# rvs() 무작위 표본 데이터의 기댓값 : 11.07473
# rvs() 무작위 표본 데이터의 표준편차 : 3.15290

# %%
sns.distplot(rvs_, xx)
plt.ylim(0, 0.16)
plt.xlim(-10, 30)
plt.show()

# %%
type(sns.distplot(rvs_, xx))
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
rv1 = stats.uniform()
rv2 = stats.uniform()

np.random.seed(0)
N = 50000
x_1 = rv1.rvs(N)
x_2 = rv2.rvs(N)
x_3 = x_1 + x_2

plt.figure(figsize=(12,5))

plt.subplot(1, 3, 1)
sns.distplot(x_1, kde=False)
plt.title('균일분포')
plt.xlabel('표본값')
plt.xlim(-0.2, 2.2)

plt.subplot(1, 3, 2)
sns.distplot(x_2, kde=False)
plt.title('균일분포')
plt.xlabel('표본값')
plt.xlim(-0.2, 2.2)

plt.subplot(1, 3, 3)
sns.distplot(x_3, kde=False)
plt.title('균일분포 표본 합의 분포')
plt.xlabel('표본값')
plt.xlim(-0.2, 2.2)

plt.show()

# %% [markdown]
# 균일분포 합의 분포는 균일분포와 같지 않다.

# %%
# 10개 표본에 대해 1000회 시뮬레이션
# *시뮬레이션 : 확률변수의 표본을 생성하는 작업

rv_1 = stats.uniform()
rv_2 = stats.uniform()
rv_3 = stats.uniform()
rv_4 = stats.uniform()
rv_5 = stats.uniform()
rv_6 = stats.uniform()
rv_7 = stats.uniform()
rv_8 = stats.uniform()
rv_9 = stats.uniform()
rv_10 = stats.uniform()

N = 1000

rvx_1 = rv_1.rvs(N)
rvx_2 = rv_2.rvs(N)
rvx_3 = rv_3.rvs(N)
rvx_4 = rv_4.rvs(N)
rvx_5 = rv_5.rvs(N)
rvx_6 = rv_6.rvs(N)
rvx_7 = rv_7.rvs(N)
rvx_8 = rv_8.rvs(N)
rvx_9 = rv_9.rvs(N)
rvx_10 = rv_10.rvs(N)

rvx_sum = (rvx_1 + rvx_2 + rvx_3 + rvx_4 + rvx_5 + \
          rvx_6 + rvx_7 + rvx_8 + rvx_9 + rvx_10)


plt.subplot(5, 2, 1)
sns.distplot(rvx_1, kde=False)
plt.title('1번 표본 균일분포')
plt.xlim(-1, 2)

plt.subplot(5, 2, 2)
sns.distplot(rvx_2, kde=False)
plt.title('2번 표본 균일분포')
plt.xlim(-1, 2)

plt.subplot(5, 2, 3)
sns.distplot(rvx_3, kde=False)
plt.title('3번 표본 균일분포')
plt.xlim(-1, 2)

plt.subplot(5, 2, 4)
sns.distplot(rvx_4, kde=False)
plt.title('4번 표본 균일분포')
plt.xlim(-1, 2)

plt.subplot(5, 2, 5)
sns.distplot(rvx_5, kde=False)
plt.title('5번 표본 균일분포')
plt.xlim(-1, 2)

plt.subplot(5, 2, 6)
sns.distplot(rvx_6, kde=False)
plt.title('6번 표본 균일분포')
plt.xlim(-1, 2)

plt.subplot(5, 2, 7)
sns.distplot(rvx_7, kde=False)
plt.title('7번 표본 균일분포')
plt.xlim(-1, 2)

plt.subplot(5, 2, 8)
sns.distplot(rvx_8, kde=False)
plt.title('8번 표본 균일분포')
plt.xlim(-1, 2)

plt.subplot(5, 2, 9)
sns.distplot(rvx_9, kde=False)
plt.title('9번 표본 균일분포')
plt.xlim(-1, 2)

plt.subplot(5, 2, 10)
sns.distplot(rvx_10, kde=False)
plt.title('10번 표본 균일분포')
plt.xlim(-1, 2)
# plt.figure(figsize=(7,3))        
# plt.tight_layout(pad=10)
plt.subplots_adjust(left=0.1, right=1.95, bottom=0.2, top=3, wspace=0.5, hspace=0.5)
plt.show()


plt.figure(figsize=(10,5))
sns.distplot(rvx_sum, kde=False)
plt.title('표본값 1 ~ 10까지의 표본 합')
plt.show()
