# %%
import sqlite3
import sqlalchemy
import pandas as pd

# %%
engine = sqlalchemy.create_engine("postgresql://postgres:qwer1234@localhost:5432/postgres")

# %%
pd.read_sql('select * from cslee.tb_grade', engine)
# Out:
#    grade    low_sal     high_sal
# 0      1          0     40000000
# 1      2   40000000     60000000
# 2      3   60000001     80000000
# 3      4   80000001    110000000
# 4      5  110000001  99999999999

# %%
pd.read_sql('select * from cslee.tb_accnt', engine)
# Out:
#         accno  cust_no prod_cd  cont_amt  int_rate    op_date    ma_date  \
# 0      105400    10115   P1000     49430     27.36 2013-12-10 2014-12-30
# 1      105401    10183   P1003     50850     17.97 2013-12-10 2014-12-30
# 2      105402    10027   P1005     81297     29.54 2013-12-10 2014-12-30
# 3      105403    10015   P1000       211     11.85 2013-12-10 2014-12-30
# 4      105404    10044   P1009     60251     29.49 2013-12-10 2014-12-30
# ...       ...      ...     ...       ...       ...        ...        ...
# 47495  140135    10168   P1006     87870      7.30 2012-10-21 2012-02-07
# 47496  140136    10008   P1005     38885     10.75 2012-10-21 2012-02-07
# 47497  140137    10074   P1000     39178     15.45 2012-10-21 2012-02-07
# 47498  140138    10001   P1005     97365     14.99 2012-10-21 2012-02-07
# 47499  140139    10177   P1003     93536     17.25 2012-10-21 2012-02-07
#
#        manager
# 0         1010
# 1         1009
# 2         1008
# 3         1014
# ...

# %%
pd.read_sql("select date_part('month', op_date) as 하반기_월, \
cust_no as 하반기_고객 from cslee.tb_accnt" , engine)
# Out:
#        하반기_월  하반기_고객
# 0       12.0   10115
# 1       12.0   10183
# 2       12.0   10027
# 3       12.0   10015
# 4       12.0   10044
# ...      ...     ...
# 47495   10.0   10168
# 47496   10.0   10008
# 47497   10.0   10074
# 47498   10.0   10001
# 47499   10.0   10177
#
# [47500 rows x 2 columns]

# %%
pd.read_sql("select date_part('month', op_date)::integer as 월, \
            count(cust_no) as 주문고객_수 from cslee.tb_accnt \
            group by 월 ", engine, index_col=['월'])
# Out:
#     주문고객_수
# 월
# 4     3000
# 10    4539
# 7     3235
# 9     3765
# 6     1980
# 12    5906
# 3     6330
# 1     5540
# 5     4610
# 2     2160
# 11    2000
# 8     4435

# %%
pd.read_sql("select (case when date_part('month', op_date) != 0 then '계'), \
            count(cust_no) as 주문고객_수 from cslee.tb_accnt \
            group by 월 \
            order by 월 asc " , engine, index_col=['월'])
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1807     if not evt_handled:
# -> 1808         self.dialect.do_execute(
#    1809             cursor, statement, parameters, context
#    1810         )
#    1812 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# SyntaxError: 오류:  구문 오류, ")" 부근
# LINE 1: ...se when date_part('month', op_date) != 0 then '계'),        ...
# ...

# %%
tot = pd.Series({'계':5540+2160+6330+3000+4610+1980+
                   3235+4435+3765+4539+2000+5906})

# %%
print(tot)
# Out:
# 계    47500
# dtype: int64

# %%
a= {'월':'계', '주문고객_수':47500}
dict(a)
type(a)
# Out:
# dict

# %%
mon_cust.reset_index(inplace=True)

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
tot_chart = mon_cust.append(a, ignore_index=True)
tot_chart
# Out:
#      월  주문고객_수
# 0    1    5540
# 1    2    2160
# 2    3    6330
# 3    4    3000
# 4    5    4610
# 5    6    1980
# 6    7    3235
# 7    8    4435
# 8    9    3765
# 9   10    4539
# 10  11    2000
# 11  12    5906
# 12   계   47500

# %%
tot_chart.set_index('월')
# Out:
#     주문고객_수
# 월
# 1     5540
# 2     2160
# 3     6330
# 4     3000
# 5     4610
# 6     1980
# 7     3235
# 8     4435
# 9     3765
# 10    4539
# 11    2000
# 12    5906
# 계    47500

# %%
mon_cust
# Out:
#     주문고객_수
# 월
# 1     5540
# 2     2160
# 3     6330
# 4     3000
# 5     4610
# 6     1980
# 7     3235
# 8     4435
# 9     3765
# 10    4539
# 11    2000
# 12    5906
