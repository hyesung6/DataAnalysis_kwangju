# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('20210101-20210331.csv', encoding='utf-8')

# %%
data.columns.values
# Out:
# array(['system:index', 'AOT', 'AOT_RETRIEVAL_ACCURACY', 'B1', 'B11',
#        'B12', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9',
#        'CLOUDY_PIXEL_PERCENTAGE', 'CLOUD_COVERAGE_ASSESSMENT',
#        'CLOUD_SHADOW_PERCENTAGE', 'DARK_FEATURES_PERCENTAGE',
#        'DATASTRIP_ID', 'DATATAKE_IDENTIFIER', 'DATATAKE_TYPE',
#        'DEGRADED_MSI_DATA_PERCENTAGE', 'FORMAT_CORRECTNESS',
#        'GENERAL_QUALITY', 'GENERATION_TIME', 'GEOMETRIC_QUALITY',
#        'GRANULE_ID', 'HIGH_PROBA_CLOUDS_PERCENTAGE',
#        'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1',
#        'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10',
#        'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11',
#        'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12',
#        'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2',
#        'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3',
#        'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4',
#        'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5',
#        'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6',
#        'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7',
# ...

# %%
data['system:band_names'][0]
# Out:
# '[B1, B2, B3, B4, B5, B6, B7, B8, B8A, B9, B11, B12, AOT, WVP, SCL, TCI_R, TCI_G, TCI_B, MSK_CLDPRB, MSK_SNWPRB, QA10, QA20, QA60, ndvi]'

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.set_index('system:index', inplace=True)

# %%
band_grb = data.loc[:, ['B2', 'B3', 'B4', 'B8', 'ndvi']]

# %%
band_rgb = band_grb.reset_index()

# %%
band_rgb
# Out:
#                                          system:index          B2          B3  \
# 0   20210117T022029_20210117T022027_T52SCF_2021011...  443.360313  572.090456
# 1   20210117T022029_20210117T022027_T52SCF_2021022...  443.360313  572.090456
# 2   20210117T022029_20210117T022027_T52SCF_2021030...  443.360313  572.090456
# 3   20210117T022029_20210117T022027_T52SCF_2021031...  443.360313  572.090456
# 4   20210117T022029_20210117T022027_T52SCF_2021032...  443.360313  572.090456
# 5   20210221T021721_20210221T022406_T52SCF_2021011...  477.987840  605.461637
# 6   20210221T021721_20210221T022406_T52SCF_2021022...  477.987840  605.461637
# 7   20210221T021721_20210221T022406_T52SCF_2021030...  477.987840  605.461637
# 8   20210221T021721_20210221T022406_T52SCF_2021031...  477.987840  605.461637
# 9   20210221T021721_20210221T022406_T52SCF_2021032...  477.987840  605.461637
# 10  20210308T021559_20210308T021602_T52SCF_2021011...  671.047867  799.098353
# ...

# %%
band_rgb.rename({'system:index' : 'date'}, axis=1, inplace=True)

# %%
band_rgb['date'][0]
# Out:
# '20210117T022029_20210117T022027_T52SCF_20210117T022029_20210117T022027_T52SCF'

# %%
band_rgb['date'] = band_rgb['date'].apply(lambda x : x.split('_')[0])

# %%
band_rgb.rename({'date':'datetime'}, inplace=True)

# %%
band_rgb.set_index('date')
# Out:
#                          B2          B3           B4           B8      ndvi
# date
# 20210117T022029  443.360313  572.090456   734.792840  1631.695868  0.347715
# 20210117T022029  443.360313  572.090456   734.792840  1631.695868  0.347715
# 20210117T022029  443.360313  572.090456   734.792840  1631.695868  0.347715
# 20210117T022029  443.360313  572.090456   734.792840  1631.695868  0.347715
# 20210117T022029  443.360313  572.090456   734.792840  1631.695868  0.347715
# 20210221T021721  477.987840  605.461637   798.339673  1631.428606  0.308622
# 20210221T021721  477.987840  605.461637   798.339673  1631.428606  0.308622
# 20210221T021721  477.987840  605.461637   798.339673  1631.428606  0.308622
# 20210221T021721  477.987840  605.461637   798.339673  1631.428606  0.308622
# 20210221T021721  477.987840  605.461637   798.339673  1631.428606  0.308622
# 20210308T021559  671.047867  799.098353   927.037654  1759.450649  0.300781
# ...

# %%
band_rgb.rename({'date' : 'datetime',
                 'B2' : 'Green',
                 'B3' : 'Blue',
                 'B4' : 'Red',
                 'B8' : 'NIR'},
                 inplace=True,
                 axis=1)

# %%
band_rgb.drop_duplicates()
# Out:
#            datetime       Green        Blue          Red          NIR  \
# 0   20210117T022029  443.360313  572.090456   734.792840  1631.695868
# 5   20210221T021721  477.987840  605.461637   798.339673  1631.428606
# 10  20210308T021559  671.047867  799.098353   927.037654  1759.450649
# 15  20210318T021559  735.152705  862.652677   990.736080  1887.281274
# 20  20210323T021601  655.179829  815.136331  1007.250363  1903.406116
#
#         ndvi
# 0   0.347715
# 5   0.308622
# 10  0.300781
# 15  0.277341
# 20  0.300816

# %%
band_rgb.rename({'Green' : 'Blue',
                 'Blue' : 'Green'},
                inplace=True,
                axis=1)

# %%
band_rgb.drop_duplicates()
# Out:
#            datetime        Blue       Green          Red          NIR  \
# 0   20210117T022029  443.360313  572.090456   734.792840  1631.695868
# 5   20210221T021721  477.987840  605.461637   798.339673  1631.428606
# 10  20210308T021559  671.047867  799.098353   927.037654  1759.450649
# 15  20210318T021559  735.152705  862.652677   990.736080  1887.281274
# 20  20210323T021601  655.179829  815.136331  1007.250363  1903.406116
#
#         ndvi
# 0   0.347715
# 5   0.308622
# 10  0.300781
# 15  0.277341
# 20  0.300816

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,6))
plt.plot(band_rgb['Red'])
plt.plot(band_rgb['Green'])
plt.plot(band_rgb['Blue'])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [98], in <cell line: 1>()
# ----> 1 plt.barh(band_rgb.corr(), 5)
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2403, in barh(y, width, height, left, align, **kwargs)
#    2401 @_copy_docstring_and_deprecators(Axes.barh)
#    2402 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
# -> 2403     return gca().barh(
#    2404         y, width, height=height, left=left, align=align, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:2551, in Axes.barh(self, y, width, height, left, align, **kwargs)
#    2452 r"""
#    2453 Make a horizontal bar plot.
#    2454
#    (...)
#    2548 .
#    2549 """
#    2550 kwargs.setdefault('orientation', 'horizontal')
# -> 2551 patches = self.bar(x=left, height=height, width=width, bottom=y,
# ...
