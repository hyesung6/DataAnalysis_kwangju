# %% [markdown]
# # 네이버 웹툰 데이터셋 분석

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('naver_webtoon_data.csv')
df = pd.DataFrame(data)
df
# Out:
#           id              title      author      genre  \
# 0     756056       가난을 등에 업은 소녀  B급달궁 / 오은지   스토리, 로맨스
# 1     670144               가담항설          랑또   스토리, 판타지
# 2     732071       가령의 정체불명 이야기          가령  옴니버스, 드라마
# 3     703844              가비지타임         2사장   스토리, 스포츠
# 4     785701             가상&RPG         주다현   스토리, 판타지
# ...      ...                ...         ...        ...
# 1851  718018      [드라마원작] 알고있지만          정서   스토리, 로맨스
# 1852  697679  [드라마원작] 쌉니다 천리...         김규삼    스토리, 개그
# 1853  675393    [드라마원작] 한번 더 해요     미티 / 구구   스토리, 드라마
# 1854  677536  [드라마원작] 내 ID는 ...         기맹기   스토리, 로맨스
# 1855   67235  [드라마원작] 지금 우리 ...         주동근   스토리, 스릴러
#
#                                             description  rating  \
# 0     흔하디 흔한 재벌후계자와 캔디도 울고 갈 박복한 가난소녀의 파란만장 동거기!인기작 ...    9.11
# 1     이번 주인공은 돌이다!돌이지만 동료도 모으고 악당도 물리친다!랑또 작가표 동양 판타...    9.98
# 2     어느 날... 인어가 내게 말을 걸어왔다. 눈을 떠보니 총구가 있었다. 그리고 몸이...    9.95
# 3       한국 최초 한국형 고교스포츠 웹툰!열혈따윈 개나 줘, 낙오자들 뿐인 농구부의 운명은?    9.96
# 4     "사람은 좀 죽여도 싸우는건 싫어해요." 게임에서조차 집 바깥을 나가지 않는 '제리...    9.94
# ...                                                 ...     ...
# 1851  "넌 내가 나비라는걸 알고 있잖아."알면서도 빠지고 싶은 사랑<투명한 동거> 정서 ...    9.97
# 1852   "고객은 왕이 아니다, 직원이 왕이다!"병맛 드라마를 뛰어넘는 미친 상상력의 원작 웹툰    9.98
# 1853  결혼 8년차 부부. 성대광과 유선영. 대학시절 킹카 퀸카로 CC로 만나 결혼까지 골...    9.91
# 1854  못생긴 얼굴에서 미인으로 새롭게 태어난 그녀, 강미래! 그런데... 어디서 본 듯 한데?    9.83
# 1855  평범하던 학교에 벌어진 감금사건..그리고 감금사건에 가려 미처 알지 못한 감염자. ...    9.56
#
#                   date  completed      age   free  \
# 0     2020.10.19 00:00       True    전체연령가   True
# 1     2020.10.07 23:00       True  12세 이용가   True
# 2     2020.02.03 23:22       True  15세 이용가   True
# 3     2022.05.28 22:58      False    전체연령가  False
# 4     2022.06.01 22:57      False  12세 이용가  False
# ...                ...        ...      ...    ...
# 1851        2019.07.17       True  15세 이용가   True
# 1852        2018.06.21       True    전체연령가   True
# 1853        2018.03.22       True  18세 이용가   True
# 1854        2017.12.29       True  12세 이용가   True
# 1855        2011.11.09       True  18세 이용가   True
#
#                                                    link
# 0     https://comic.naver.com/webtoon/list?titleId=7...
# 1     https://comic.naver.com/webtoon/list?titleId=6...
# 2     https://comic.naver.com/webtoon/list?titleId=7...
# 3     https://comic.naver.com/webtoon/list?titleId=7...
# 4     https://comic.naver.com/webtoon/list?titleId=7...
# ...                                                 ...
# 1851  https://comic.naver.com/webtoon/list?titleId=7...
# 1852  https://comic.naver.com/webtoon/list?titleId=6...
# 1853  https://comic.naver.com/webtoon/list?titleId=6...
# 1854  https://comic.naver.com/webtoon/list?titleId=6...
# 1855  https://comic.naver.com/webtoon/list?titleId=6...
#
# [1856 rows x 11 columns]

# %%
webtoon_descript = df['description']

# %%
# description 컬럼만 추출하여 txt 파일로 저장
# to_csv 함수에서 확장자를 .txt로 지정하면 그냥 txt파일로 저장됨
# index=False 인자를 주면 인덱스 없이 저장
# sep= 인자를 안 주면 , 로 구분된 txt파일이 저장됨
webtoon_descript = webtoon_descript.applymap(lambda x: x.replace('\u200b', '')
webtoon_descript.to_csv('webtoon_keyword.txt', encoding='euc-kr')
# Out:
#   Input In [48]
#     webtoon_descript.to_csv('webtoon_keyword.txt', encoding='euc-kr')
#     ^
# SyntaxError: invalid syntax

# %%
# 자연어 처리기에 넣어야하므로
# open과 read 함수를 이용하여 변수 저장
webtoon_descript = open('webtoon_keyword.txt').read()

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
from wordcloud import WordCloud

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
# Requirement already satisfied: numpy>=1.6 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (1.21.5)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (4.8.0)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp39-cp39-win_amd64.whl (344 kB)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0

# %%
from konlpy.tag import Okt

# %%
from collections import Counter

# %%
twitter = Okt()

keyword = []
keyword = twitter.pos(webtoon_descript)

# %%
noun_adj_list = []

for word, tag in keyword:
    if tag in ['noun', 'Adjective']:
        noun_adj_list.append(word)
        
counts = Counter(noun_adj_list)
tags = counts.most_common(40)

# %%
tags
# Out:
# [('같은', 4),
#  ('없는', 2),
#  ('있을까', 2),
#  ('있는', 2),
#  ('흔한', 1),
#  ('박복한', 1),
#  ('있었다', 1),
#  ('뿐인', 1),
#  ('싫어해요', 1),
#  ('아슬아슬한', 1),
#  ('좋아하던', 1),
#  ('인한', 1),
#  ('당연하게만', 1),
#  ('소중함을', 1),
#  ('강한', 1),
#  ('자유롭게', 1),
#  ('있어도', 1),
#  ('행복하게', 1),
#  ('고군', 1),
#  ('그러던', 1),
#  ('이상한', 1),
#  ('아닌', 1),
#  ('행복한', 1),
#  ('무심하거나', 1),
#  ('수상하다', 1),
#  ('험난한', 1),
#  ('기묘한', 1),
#  ('서툴고', 1),
#  ('어색했던', 1),
#  ('헷갈리고', 1),
#  ('서툴기만', 1),
#  ('당당하고', 1),
#  ('솔직하게', 1),
#  ('성공할', 1),
#  ('솔직하지', 1),
#  ('어떻게', 1),
#  ('없기로', 1),
#  ('높은', 1),
#  ('있거든요', 1),
#  ('아니', 1)]

# %%
wc = WordCloud(font_path='C:\\Windows\\Fonts\\malgunsl.ttf', background_color="white", max_font_size=60)
cloud = wc.generate_from_frequencies(dict(tags))

# %%
cloud

# %%
print(cloud)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x000001EFEF7F1AC0>

# %%
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
plt.show()

# %%
'''
클라우드 시각화는 했는데
데이터셋 자체가 중복키워드를 뽑아내기에 부적합했음
'''

# 유사한 다른 데이터셋으로 진행

# %%
data = pd.read_csv('naver_webtoon_data2.csv')
df = pd.DataFrame(data)
df
# Out:
#       id                      Name                      Writer     Likes  \
# 0      0                Let's Play  Leeanne M. Krecic (Mongie)     30.6M
# 1      1               True Beauty                     Yaongyi     39.9M
# 2      2       Midnight Poppy Land                    Lilydusk     10.4M
# 3      3               Age Matters                 Enjelicious     25.9M
# 4      4              Unholy Blood    Lina Im / Jeonghyeon Kim      9.9M
# ..   ...                       ...                         ...       ...
# 564  564       Third Shift Society           Meredith Moriarty  8,66,428
# 565  565                Adamsville              Michael Regina  1,84,981
# 566  566               WEBTOON Now      LOZOLZ / Wyatt the Cat      1.9M
# 567  567  Staying Healthy Together             Various Artists      1.5M
# 568  568        ã„´ã…‡ã„¹ã…‡ã„´ã„¹                      LOZOLZ  2,65,458
#
#             Genre  Rating Subscribers  \
# 0         Romance    9.62        4.2M
# 1         Romance    9.60        6.4M
# 2         Romance    9.81        2.1M
# 3         Romance    9.79        3.5M
# 4    Supernatural    9.85        1.5M
# ..            ...     ...         ...
# 564  Supernatural    9.78      376.9K
# 565       Mystery    9.32       60.4K
# 566   Informative    9.25      459.2K
# 567   Informative    9.76      204.6K
# 568   Informative    8.83      109.1K
#
#                                                Summary              Update  \
# 0    She's young, single and about to achieve her d...    UP EVERY TUESDAY
# 1    After binge-watching beauty videos online, a s...  UP EVERY WEDNESDAY
# 2    After making a grisly discovery in the country...   UP EVERY SATURDAY
# 3    She's a hopeless romantic who's turning 30's  ...  UP EVERY WEDNESDAY
# 4    When vampires destroy her chance to have the n...   UP EVERY THURSDAY
# ..                                                 ...                 ...
# 564  Life's funny. One minute you're jobless, deep ...     UP EVERY FRIDAY
# 565  "Adamsville" is an all ages series about two m...           COMPLETED
# 566                        Get your WEBTOON news here!     UP EVERY MONDAY
# 567  A series of tips for staying safe during the C...           COMPLETED
# 568  The mysterious team that brings Webtoon to you...           COMPLETED
#
#                                           Reading Link
# 0    https://www.webtoons.com/en/romance/letsplay/l...
# 1    https://www.webtoons.com/en/romance/truebeauty...
# 2    https://www.webtoons.com/en/romance/midnight-p...
# 3    https://www.webtoons.com/en/romance/age-matter...
# 4    https://www.webtoons.com/en/supernatural/unhol...
# ..                                                 ...
# 564  https://www.webtoons.com/en/supernatural/third...
# 565  https://www.webtoons.com/en/mystery/adamsville...
# 566  https://www.webtoons.com/en/tiptoon/webtoon-no...
# 567  https://www.webtoons.com/en/tiptoon/staying-he...
# 568  https://www.webtoons.com/en/tiptoon/lozolz/lis...
#
# [569 rows x 10 columns]

# %%
df.sort_values('Genre')
# Out:
#       id                           Name                        Writer  \
# 43    43                   Neon Revenge                          MURO
# 223  223                      Code Adam                     Atterozen
# 420  420                 REAWAKENED MAN    Yongtaek Chae / Jaehan Kim
# 242  242                    microHUNTER                   NAGATERBANG
# 208  208  I Get Stronger the More I Eat        Kitaeon / Frost Mourne
# ..   ...                            ...                           ...
# 88    88                        Bastard  Carnby Kim / Youngchan Hwang
# 545  545                         Rotten                       Goodguy
# 546  546                       Delusion                     Hongjacga
# 538  538                         Shriek               Various Artists
# 470  470           School Bus Graveyard                   lilredbeany
#
#         Likes     Genre  Rating Subscribers  \
# 43   1,40,430    Action    9.68      267.3K
# 223        3M    Action    9.77        766K
# 420  1,03,691    Action    9.45      145.8K
# 242    47,983    Action    9.55      328.3K
# 208  1,79,307    Action    8.45      210.9K
# ..        ...       ...     ...         ...
# 88         7M  Thriller    9.87        1.5M
# 545      1.1M  Thriller    9.68      386.1K
# 546  8,02,309  Thriller    9.79      189.6K
# 538  3,77,712  Thriller    9.75      337.6K
# 470  5,39,252  Thriller    9.77      452.3K
#
#                                                Summary              Update  \
# 43   No one would have ever guessed that nerdy-look...  UP EVERY WEDNESDAY
# 223  They were trained as children to become super-...     UP EVERY MONDAY
# 420  If there's one thing Hwan Seok can't stand, it...    UP EVERY TUESDAY
# 242  While out to get his sister's favorite snack, ...     UP EVERY FRIDAY
# 208  Known as "Pet Shop," Mr. Kim has the unique ab...   UP EVERY SATURDAY
# ..                                                 ...                 ...
# 88               There is a serial killer in my house!           COMPLETED
# 545  Jaeshin sees dead people, and Officer Han can ...           COMPLETED
# 546  It's 1935 in Gyeongseong, and struggling artis...           COMPLETED
# 538  Prepare to swallow your screams. This horror a...           COMPLETED
# 470  Ashlyn is a loner in high school with no frien...  UP EVERY WEDNESDAY
#
#                                           Reading Link
# 43   https://www.webtoons.com/en/fantasy/the-spark-...
# 223  https://www.webtoons.com/en/action/code-adam/l...
# 420  https://www.webtoons.com/en/action/reawaken-ma...
# 242  https://www.webtoons.com/en/action/sarimin/lis...
# 208  https://www.webtoons.com/en/action/i-get-stron...
# ..                                                 ...
# 88   https://www.webtoons.com/en/thriller/bastard/l...
# 545  https://www.webtoons.com/en/thriller/rotten/li...
# 546  https://www.webtoons.com/en/thriller/delusion/...
# 538  https://www.webtoons.com/en/thriller/shriek/li...
# 470  https://www.webtoons.com/en/thriller/school-bu...
#
# [569 rows x 10 columns]

# %%
df['Genre']
# Out:
# 0           Romance
# 1           Romance
# 2           Romance
# 3           Romance
# 4      Supernatural
#            ...
# 564    Supernatural
# 565         Mystery
# 566     Informative
# 567     Informative
# 568     Informative
# Name: Genre, Length: 569, dtype: object

# %%
webtoon_genre = df['Genre']
webtoon_genre.to_csv('webtoon_genre_cloud.txt', encoding='euc-kr', index=False)

# %%
text = open('webtoon_genre_cloud.txt').read()
text
# Out:
# 'Genre\nRomance\nRomance\nRomance\nRomance\nSupernatural\nFantasy\nSupernatural\nAction\nRomance\nDrama\nRomance\nDrama\nDrama\nFantasy\nFantasy\nRomance\nRomance\nAction\nThriller\nRomance\nSupernatural\nDrama\nDrama\nFantasy\nMystery\nDrama\nRomance\nThriller\nRomance\nRomance\nRomance\nRomance\nRomance\nAction\nRomance\nRomance\nDrama\nDrama\nHistorical\nDrama\nRomance\nFantasy\nRomance\nAction\nFantasy\nFantasy\nRomance\nFantasy\nDrama\nRomance\nDrama\nDrama\nComedy\nFantasy\nThriller\nDrama\nThriller\nFantasy\nDrama\nDrama\nSci-fi\nAction\nDrama\nSci-fi\nSlice of life\nDrama\nMystery\nHistorical\nFantasy\nDrama\nDrama\nSlice of life\nDrama\nThriller\nAction\nMystery\nDrama\nDrama\nFantasy\nHeartwarming\nDrama\nThriller\nDrama\nDrama\nFantasy\nRomance\nDrama\nDrama\nThriller\nRomance\nRomance\nDrama\nSupernatural\nDrama\nRomance\nDrama\nRomance\nRomance\nDrama\nDrama\nAction\nDrama\nThriller\nFantasy\nRomance\nSupernatural\nRomance\nDrama\nDrama\nFantasy\nSuperhero\nRomance\nRomance\nFantasy\nDrama\nRomance\nThriller\nDrama\nDrama\nDrama\nDrama\nSlice of life\nFantasy\nDrama\nRomance\nDrama\nRomance\nRomance\nDrama\nDrama\nDrama\nSupernatural\nComedy\nFantasy\nFantasy\nDrama\nHistorical\nThriller\nDrama\nDrama\nSupernatural\nRomance\nSci-fi\nSuperhero\nDrama\nSupernatural\nSci-fi\nSuperhero\nSci-fi\nSuperhero\nFantasy\nDrama\nDrama\nDrama\nFantasy\nAction\nSci-fi\nDrama\nFantasy\nDrama\nSupernatural\nFantasy\nFantasy\nFantasy\nDrama\nDrama\nDrama\nComedy\nSci-fi\nRomance\nFantasy\nSci-fi\nRomance\nFantasy\nDrama\nDrama\nDrama\nRomance\nRomance\nFantasy\nComedy\nRomance\nFantasy\nAction\nAction\nFantasy\nFantasy\nAction\nAction\nAction\nFantasy\nRomance\nFantasy\nAction\nFantasy\nAction\nRomance\nFantasy\nAction\nFantasy\nAction\nAction\nRomance\nAction\nFantasy\nRomance\nFantasy\nFantasy\nAction\nComedy\nFantasy\nComedy\nFantasy\nAction\nComedy\nFantasy\nRomance\nAction\nFantasy\nFantasy\nFantasy\nAction\nFantasy\nAction\nFantasy\nAction\nFantasy\nAction\nFantasy\nFantasy\nFantasy\nFantasy\nFantasy\nMystery\nFantasy\nRomance\nFantasy\nFantasy\nFantasy\nRomance\nAction\nFantasy\nAction\nComedy\nAction\nRomance\nFantasy\nFantasy\nFantasy\nFantasy\nFantasy\nThriller\nFantasy\nFantasy\nAction\nComedy\nFantasy\nRomance\nFantasy\nFantasy\nFantasy\nComedy\nSupernatural\nFantasy\nSci-fi\nSci-fi\nFantasy\nFantasy\nAction\nRomance\nSci-fi\nRomance\nComedy\nAction\nRomance\nAction\nAction\nSupernatural\nRomance\nFantasy\nFantasy\nFantasy\nRomance\nFantasy\nFantasy\nComedy\nComedy\nFantasy\nFantasy\nThriller\nFantasy\nFantasy\nFantasy\nSlice of life\nSci-fi\nSupernatural\nAction\nFantasy\nSci-fi\nAction\nSci-fi\nFantasy\nAction\nAction\nFantasy\nFantasy\nFantasy\nFantasy\nFantasy\nSci-fi\nSupernatural\nSci-fi\nFantasy\nFantasy\nComedy\nSuperhero\nSci-fi\nSupernatural\nComedy\nFantasy\nFantasy\nFantasy\nFantasy\nSupernatural\nSupernatural\nSlice of life\nComedy\nSlice of life\nComedy\nRomance\nComedy\nComedy\nRomance\nComedy\nRomance\nSlice of life\nRomance\nRomance\nComedy\nComedy\nRomance\nComedy\nSlice of life\nSports\nRomance\nComedy\nSlice of life\nComedy\nRomance\nSlice of life\nSports\nComedy\nSlice of life\nComedy\nComedy\nComedy\nComedy\nSupernatural\nComedy\nSci-fi\nComedy\nSlice of life\nComedy\nSlice of life\nComedy\nSlice of life\nSlice of life\nSlice of life\nSlice of life\nComedy\nSlice of life\nComedy\nRomance\nSlice of life\nSlice of life\nSci-fi\nComedy\nSupernatural\nComedy\nSlice of life\nSlice of life\nSuperhero\nSlice of life\nComedy\nComedy\nComedy\nSlice of life\nComedy\nSports\nSlice of life\nSlice of life\nComedy\nComedy\nComedy\nSports\nSlice of life\nSlice of life\nComedy\nSlice of life\nComedy\nComedy\nComedy\nSlice of life\nSlice of life\nComedy\nSuperhero\nSlice of life\nComedy\nComedy\nSports\nAction\nAction\nAction\nSports\nAction\nSports\nSci-fi\nSuperhero\nSports\nAction\nAction\nAction\nSports\nSuperhero\nSupernatural\nMystery\nSci-fi\nSci-fi\nSci-fi\nSupernatural\nSci-fi\nSci-fi\nSuperhero\nSupernat ...

# %%
type(text)
# Out:
# str

# %%
# twitter = Okt()

# keyword = []
# keyword = twitter.pos(text)

# noun_adj_list = []

# for word, tag in text:
#     if tag in ['noun', 'Adjective']:
#         noun_adj_list.append(word)
        
counts = Counter(text)
tags = counts.most_common(40)

wc2 = WordCloud(font_path='C:\\Windows\\Fonts\\malgunsl.ttf', background_color="white", max_font_size=60)
cloud2 = wc.generate_from_frequencies(dict(tags))

plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud2)
plt.show()

# %%
counts
# Out:
# Counter({'G': 1,
#          'e': 378,
#          'n': 273,
#          'r': 341,
#          '\n': 570,
#          'R': 90,
#          'o': 323,
#          'm': 209,
#          'a': 479,
#          'c': 222,
#          'S': 150,
#          'u': 92,
#          'p': 69,
#          't': 205,
#          'l': 205,
#          'F': 95,
#          's': 118,
#          'y': 165,
#          'A': 47,
#          'i': 259,
#          'D': 60,
#          'T': 35,
#          'h': 61,
#          'M': 9,
#          'H': 26,
#          'C': 52,
#          'd': 52,
#          '-': 32,
#          'f': 135,
#          ' ': 98,
#          'w': 2,
#          'g': 2,
#          'I': 5,
#          'v': 5})

# %%
# 영어 분석기 사용하려 했으나
# 잘 안 돼서 그냥 텍스트 번역기 돌리기로 함

# !pip install googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
# Collecting idna==2.*
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2021.10.8)
# Collecting chardet==3.*
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting hstspreload
#   Downloading hstspreload-2021.12.1-py3-none-any.whl (1.3 MB)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.2.0)
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py): started
#   Building wheel for googletrans (setup.py): finished with status 'done'
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17429 sha256=880e507738954b4caddfbd83a3a506d4b1d429dbc48789636bd7ee39f9e09cb0
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\60\b3\27\d8aff3e2d5c2d0d97a117cdf0d5f13cd121e2c2b5fb49b55a0
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, h2, h11, rfc3986, idna, httpcore, hstspreload, chardet, httpx, googletrans
#   Attempting uninstall: idna
#     Found existing installation: idna 3.3
#     Uninstalling idna-3.3:
#       Successfully uninstalled idna-3.3
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.12.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.

# %%
from googletrans import Translator
translator = Translator()

a = translator.translate(text, src='en', dest='ko')

# %%
text_trans = a
text_trans = str(text_trans)

# %%
text_trans2 = str(a.text)
text_trans3 = text_trans2.split('\n')

# %%
text_trans3
# Out:
# ['장르',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '신의 조화',
#  '공상',
#  '신의 조화',
#  '동작',
#  '로맨스',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '공상',
#  '공상',
#  '로맨스',
#  '로맨스',
#  '동작',
#  '스릴러',
#  '로맨스',
#  '신의 조화',
#  '드라마',
#  '드라마',
#  '공상',
#  '신비',
#  '드라마',
#  '로맨스',
#  '스릴러',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '동작',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '역사적인',
#  '드라마',
#  '로맨스',
#  '공상',
#  '로맨스',
#  '동작',
#  '공상',
#  '공상',
#  '로맨스',
#  '공상',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '코메디',
#  '공상',
#  '스릴러',
#  '드라마',
#  '스릴러',
#  '공상',
#  '드라마',
#  '드라마',
#  '공상 과학',
#  '동작',
#  '드라마',
#  '공상 과학',
#  '삶의 슬라이스',
#  '드라마',
#  '신비',
#  '역사적인',
#  '공상',
#  '드라마',
#  '드라마',
#  '삶의 슬라이스',
#  '드라마',
#  '스릴러',
#  '동작',
#  '신비',
#  '드라마',
#  '드라마',
#  '공상',
#  '마음 흐뭇한',
#  '드라마',
#  '스릴러',
#  '드라마',
#  '드라마',
#  '공상',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '스릴러',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '신의 조화',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '동작',
#  '드라마',
#  '스릴러',
#  '공상',
#  '로맨스',
#  '신의 조화',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '공상',
#  '슈퍼 히어로',
#  '로맨스',
#  '로맨스',
#  '공상',
#  '드라마',
#  '로맨스',
#  '스릴러',
#  '드라마',
#  '드라마',
#  '드라마',
#  '드라마',
#  '삶의 슬라이스',
#  '공상',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '드라마',
#  '신의 조화',
#  '코메디',
#  '공상',
#  '공상',
#  '드라마',
#  '역사적인',
#  '스릴러',
#  '드라마',
#  '드라마',
#  '신의 조화',
#  '로맨스',
#  '공상 과학',
#  '슈퍼 히어로',
#  '드라마',
#  '신의 조화',
#  '공상 과학',
#  '슈퍼 히어로',
#  '공상 과학',
#  '슈퍼 히어로',
#  '공상',
#  '드라마',
#  '드라마',
#  '드라마',
#  '공상',
#  '동작',
#  '공상 과학',
#  '드라마',
#  '공상',
#  '드라마',
#  '신의 조화',
#  '공상',
#  '공상',
#  '공상',
#  '드라마',
#  '드라마',
#  '드라마',
#  '코메디',
#  '공상 과학',
#  '로맨스',
#  '공상',
#  '공상 과학',
#  '로맨스',
#  '공상',
#  '드라마',
#  '드라마',
#  '드라마',
#  '로맨스',
#  '로맨스',
#  '공상',
#  '코메디',
#  '로맨스',
#  '공상',
#  '동작',
#  '동작',
#  '공상',
#  '공상',
#  '동작',
#  '동작',
#  '동작',
#  '공상',
#  '로맨스',
#  '공상',
#  '동작',
#  '공상',
#  '동작',
#  '로맨스',
#  '공상',
#  '동작',
#  '공상',
#  '동작',
#  '동작',
#  '로맨스',
#  '동작',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '동작',
#  '코메디',
#  '공상',
#  '코메디',
#  '공상',
#  '동작',
#  '코메디',
#  '공상',
#  '로맨스',
#  '동작',
#  '공상',
#  '공상',
#  '공상',
#  '동작',
#  '공상',
#  '동작',
#  '공상',
#  '동작',
#  '공상',
#  '동작',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '신비',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '로맨스',
#  '동작',
#  '공상',
#  '동작',
#  '코메디',
#  '동작',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '스릴러',
#  '공상',
#  '공상',
#  '동작',
#  '코메디',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '코메디',
#  '신의 조화',
#  '공상',
#  '공상 과학',
#  '공상 과학',
#  '공상',
#  '공상',
#  '동작',
#  '로맨스',
#  '공상 과학',
#  '로맨스',
#  '코메디',
#  '동작',
#  '로맨스',
#  '동작',
#  '동작',
#  '신의 조화',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '코메디',
#  '코메디',
#  '공상',
#  '공상',
#  '스릴러',
#  '공상',
#  '공상',
#  '공상',
#  '삶의 슬라이스',
#  '공상 과학',
#  '신의 조화',
#  '동작',
#  '공상',
#  '공상 과학',
#  '동작',
#  '공상 과학',
#  '공상',
#  '동작',
#  '동작',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상 과학',
#  '신의 조화',
#  '공상 과학',
#  '공상',
#  '공상',
#  '코메디',
#  '슈퍼 히어로',
#  '공상 과학',
#  '신의 조화',
#  '코메디',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '신의 조화',
#  '신의 조화',
#  '삶의 슬라이스',
#  '코메디',
#  '삶의 슬라이스',
#  '코메디',
#  '로맨스',
#  '코메디',
#  '코메디',
#  '로맨스',
#  '코메디',
#  '로맨스',
#  '삶의 슬라이스',
#  '로맨스',
#  '로맨스',
#  '코메디',
#  '코메디',
#  '로맨스',
#  '코메디',
#  '삶의 슬라이스',
#  '스포츠',
#  '로맨스',
#  '코메디',
#  '삶의 슬라이스',
#  '코메디',
#  '로맨스',
#  '삶의 슬라이스',
#  '스포츠',
#  '코메디',
#  '삶의 슬라이스',
#  '코메디',
#  '코메디',
#  '코메디',
#  '코메디',
#  '신의 조화',
#  '코메디',
#  '공상 과학',
#  '코메디',
#  '삶의 슬라이스',
#  '코메디',
#  '삶의 슬라이스',
#  '코메디',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '코메디',
#  '삶의 슬라이스',
#  '코메디',
#  '로맨스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '공상 과학',
#  '코메디',
#  '신의 조화',
#  '코메디',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '슈퍼 히어로',
#  '삶의 슬라이스',
#  '코메디',
#  '코메디',
#  '코메디',
#  '삶의 슬라이스',
#  '코메디',
#  '스포츠',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '코메디',
#  '코메디',
#  '코메디',
#  '스포츠',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '코메디',
#  '삶의 슬라이스',
#  '코메디',
#  '코메디',
#  '코메디',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '코메디',
#  '슈퍼 히어로',
#  '삶의 슬라이스',
#  '코메디',
#  '코메디',
#  '스포츠',
#  '동작',
#  '동작',
#  '동작',
#  '스포츠',
#  '동작',
#  '스포츠',
#  '공상 과학',
#  '슈퍼 히어로',
#  '스포츠',
#  '동작',
#  '동작',
#  '동작',
#  '스포츠',
#  '슈퍼 히어로',
#  '신의 조화',
#  '신비',
#  '공상 과학',
#  '공상 과학',
#  '공상 과학',
#  '신의 조화',
#  '공상 과학',
#  '공상 과학',
#  '슈퍼 히어로',
#  '신의 조화',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '동작',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '공상 과학',
#  '신의 조화',
#  '슈퍼 히어로',
#  '동작',
#  '슈퍼 히어로',
#  '삶의 슬라이스',
#  '로맨스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '로맨스',
#  '로맨스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '유익한',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '삶의 슬라이스',
#  '유익한',
#  '스릴러',
#  '스릴러',
#  '로맨스',
#  '로맨스',
#  '공포',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '공상 과학',
#  '로맨스',
#  '신의 조화',
#  '신의 조화',
#  '신의 조화',
#  '역사적인',
#  '로맨스',
#  '공상 과학',
#  '마음 흐뭇한',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '신의 조화',
#  '공상 과학',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '스포츠',
#  '신의 조화',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '신의 조화',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '공상 과학',
#  '신비',
#  '공상 과학',
#  '공포',
#  '공상 과학',
#  '공포',
#  '스릴러',
#  '신의 조화',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '스릴러',
#  '공포',
#  '공포',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '공포',
#  '스릴러',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '신의 조화',
#  '스릴러',
#  '신비',
#  '신비',
#  '신의 조화',
#  '스릴러',
#  '신의 조화',
#  '공포',
#  '공포',
#  '신의 조화',
#  '신비',
#  '유익한',
#  '유익한',
#  '유익한']

# %%
# 구글번역기 라이브러리를 통해 한글로 변환한 데이터셋
# 장르 데이터로 활용하기에 부적합한 속성들의 이름을 바꿔줌
text_trans4 = []
for i in text_trans3:
    if i == '삶의 슬라이스':
        i = '일상물'
    elif i == '신의 조화':
        i = '초자연'
    elif i == '유익한':
        i = '정보전달적'
    elif i == '동작':
        i = '액션'       
    text_trans4.append(i)
    
text_trans4
# Out:
# ['장르',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '초자연',
#  '공상',
#  '초자연',
#  '액션',
#  '로맨스',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '공상',
#  '공상',
#  '로맨스',
#  '로맨스',
#  '액션',
#  '스릴러',
#  '로맨스',
#  '초자연',
#  '드라마',
#  '드라마',
#  '공상',
#  '신비',
#  '드라마',
#  '로맨스',
#  '스릴러',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '액션',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '역사적인',
#  '드라마',
#  '로맨스',
#  '공상',
#  '로맨스',
#  '액션',
#  '공상',
#  '공상',
#  '로맨스',
#  '공상',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '코메디',
#  '공상',
#  '스릴러',
#  '드라마',
#  '스릴러',
#  '공상',
#  '드라마',
#  '드라마',
#  '공상 과학',
#  '액션',
#  '드라마',
#  '공상 과학',
#  '일상물',
#  '드라마',
#  '신비',
#  '역사적인',
#  '공상',
#  '드라마',
#  '드라마',
#  '일상물',
#  '드라마',
#  '스릴러',
#  '액션',
#  '신비',
#  '드라마',
#  '드라마',
#  '공상',
#  '마음 흐뭇한',
#  '드라마',
#  '스릴러',
#  '드라마',
#  '드라마',
#  '공상',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '스릴러',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '초자연',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '액션',
#  '드라마',
#  '스릴러',
#  '공상',
#  '로맨스',
#  '초자연',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '공상',
#  '슈퍼 히어로',
#  '로맨스',
#  '로맨스',
#  '공상',
#  '드라마',
#  '로맨스',
#  '스릴러',
#  '드라마',
#  '드라마',
#  '드라마',
#  '드라마',
#  '일상물',
#  '공상',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '드라마',
#  '초자연',
#  '코메디',
#  '공상',
#  '공상',
#  '드라마',
#  '역사적인',
#  '스릴러',
#  '드라마',
#  '드라마',
#  '초자연',
#  '로맨스',
#  '공상 과학',
#  '슈퍼 히어로',
#  '드라마',
#  '초자연',
#  '공상 과학',
#  '슈퍼 히어로',
#  '공상 과학',
#  '슈퍼 히어로',
#  '공상',
#  '드라마',
#  '드라마',
#  '드라마',
#  '공상',
#  '액션',
#  '공상 과학',
#  '드라마',
#  '공상',
#  '드라마',
#  '초자연',
#  '공상',
#  '공상',
#  '공상',
#  '드라마',
#  '드라마',
#  '드라마',
#  '코메디',
#  '공상 과학',
#  '로맨스',
#  '공상',
#  '공상 과학',
#  '로맨스',
#  '공상',
#  '드라마',
#  '드라마',
#  '드라마',
#  '로맨스',
#  '로맨스',
#  '공상',
#  '코메디',
#  '로맨스',
#  '공상',
#  '액션',
#  '액션',
#  '공상',
#  '공상',
#  '액션',
#  '액션',
#  '액션',
#  '공상',
#  '로맨스',
#  '공상',
#  '액션',
#  '공상',
#  '액션',
#  '로맨스',
#  '공상',
#  '액션',
#  '공상',
#  '액션',
#  '액션',
#  '로맨스',
#  '액션',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '액션',
#  '코메디',
#  '공상',
#  '코메디',
#  '공상',
#  '액션',
#  '코메디',
#  '공상',
#  '로맨스',
#  '액션',
#  '공상',
#  '공상',
#  '공상',
#  '액션',
#  '공상',
#  '액션',
#  '공상',
#  '액션',
#  '공상',
#  '액션',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '신비',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '로맨스',
#  '액션',
#  '공상',
#  '액션',
#  '코메디',
#  '액션',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '스릴러',
#  '공상',
#  '공상',
#  '액션',
#  '코메디',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '코메디',
#  '초자연',
#  '공상',
#  '공상 과학',
#  '공상 과학',
#  '공상',
#  '공상',
#  '액션',
#  '로맨스',
#  '공상 과학',
#  '로맨스',
#  '코메디',
#  '액션',
#  '로맨스',
#  '액션',
#  '액션',
#  '초자연',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '코메디',
#  '코메디',
#  '공상',
#  '공상',
#  '스릴러',
#  '공상',
#  '공상',
#  '공상',
#  '일상물',
#  '공상 과학',
#  '초자연',
#  '액션',
#  '공상',
#  '공상 과학',
#  '액션',
#  '공상 과학',
#  '공상',
#  '액션',
#  '액션',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상 과학',
#  '초자연',
#  '공상 과학',
#  '공상',
#  '공상',
#  '코메디',
#  '슈퍼 히어로',
#  '공상 과학',
#  '초자연',
#  '코메디',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '초자연',
#  '초자연',
#  '일상물',
#  '코메디',
#  '일상물',
#  '코메디',
#  '로맨스',
#  '코메디',
#  '코메디',
#  '로맨스',
#  '코메디',
#  '로맨스',
#  '일상물',
#  '로맨스',
#  '로맨스',
#  '코메디',
#  '코메디',
#  '로맨스',
#  '코메디',
#  '일상물',
#  '스포츠',
#  '로맨스',
#  '코메디',
#  '일상물',
#  '코메디',
#  '로맨스',
#  '일상물',
#  '스포츠',
#  '코메디',
#  '일상물',
#  '코메디',
#  '코메디',
#  '코메디',
#  '코메디',
#  '초자연',
#  '코메디',
#  '공상 과학',
#  '코메디',
#  '일상물',
#  '코메디',
#  '일상물',
#  '코메디',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '코메디',
#  '일상물',
#  '코메디',
#  '로맨스',
#  '일상물',
#  '일상물',
#  '공상 과학',
#  '코메디',
#  '초자연',
#  '코메디',
#  '일상물',
#  '일상물',
#  '슈퍼 히어로',
#  '일상물',
#  '코메디',
#  '코메디',
#  '코메디',
#  '일상물',
#  '코메디',
#  '스포츠',
#  '일상물',
#  '일상물',
#  '코메디',
#  '코메디',
#  '코메디',
#  '스포츠',
#  '일상물',
#  '일상물',
#  '코메디',
#  '일상물',
#  '코메디',
#  '코메디',
#  '코메디',
#  '일상물',
#  '일상물',
#  '코메디',
#  '슈퍼 히어로',
#  '일상물',
#  '코메디',
#  '코메디',
#  '스포츠',
#  '액션',
#  '액션',
#  '액션',
#  '스포츠',
#  '액션',
#  '스포츠',
#  '공상 과학',
#  '슈퍼 히어로',
#  '스포츠',
#  '액션',
#  '액션',
#  '액션',
#  '스포츠',
#  '슈퍼 히어로',
#  '초자연',
#  '신비',
#  '공상 과학',
#  '공상 과학',
#  '공상 과학',
#  '초자연',
#  '공상 과학',
#  '공상 과학',
#  '슈퍼 히어로',
#  '초자연',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '액션',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '공상 과학',
#  '초자연',
#  '슈퍼 히어로',
#  '액션',
#  '슈퍼 히어로',
#  '일상물',
#  '로맨스',
#  '일상물',
#  '일상물',
#  '로맨스',
#  '로맨스',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '정보전달적',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '정보전달적',
#  '스릴러',
#  '스릴러',
#  '로맨스',
#  '로맨스',
#  '공포',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '공상 과학',
#  '로맨스',
#  '초자연',
#  '초자연',
#  '초자연',
#  '역사적인',
#  '로맨스',
#  '공상 과학',
#  '마음 흐뭇한',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '초자연',
#  '공상 과학',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '스포츠',
#  '초자연',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '초자연',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '공상 과학',
#  '신비',
#  '공상 과학',
#  '공포',
#  '공상 과학',
#  '공포',
#  '스릴러',
#  '초자연',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '스릴러',
#  '공포',
#  '공포',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '공포',
#  '스릴러',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '초자연',
#  '스릴러',
#  '신비',
#  '신비',
#  '초자연',
#  '스릴러',
#  '초자연',
#  '공포',
#  '공포',
#  '초자연',
#  '신비',
#  '정보전달적',
#  '정보전달적',
#  '정보전달적']

# %%
text_trans4.remove('장르')
text_trans4
# Out:
# ['로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '초자연',
#  '공상',
#  '초자연',
#  '액션',
#  '로맨스',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '공상',
#  '공상',
#  '로맨스',
#  '로맨스',
#  '액션',
#  '스릴러',
#  '로맨스',
#  '초자연',
#  '드라마',
#  '드라마',
#  '공상',
#  '신비',
#  '드라마',
#  '로맨스',
#  '스릴러',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '액션',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '역사적인',
#  '드라마',
#  '로맨스',
#  '공상',
#  '로맨스',
#  '액션',
#  '공상',
#  '공상',
#  '로맨스',
#  '공상',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '코메디',
#  '공상',
#  '스릴러',
#  '드라마',
#  '스릴러',
#  '공상',
#  '드라마',
#  '드라마',
#  '공상 과학',
#  '액션',
#  '드라마',
#  '공상 과학',
#  '일상물',
#  '드라마',
#  '신비',
#  '역사적인',
#  '공상',
#  '드라마',
#  '드라마',
#  '일상물',
#  '드라마',
#  '스릴러',
#  '액션',
#  '신비',
#  '드라마',
#  '드라마',
#  '공상',
#  '마음 흐뭇한',
#  '드라마',
#  '스릴러',
#  '드라마',
#  '드라마',
#  '공상',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '스릴러',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '초자연',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '액션',
#  '드라마',
#  '스릴러',
#  '공상',
#  '로맨스',
#  '초자연',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '공상',
#  '슈퍼 히어로',
#  '로맨스',
#  '로맨스',
#  '공상',
#  '드라마',
#  '로맨스',
#  '스릴러',
#  '드라마',
#  '드라마',
#  '드라마',
#  '드라마',
#  '일상물',
#  '공상',
#  '드라마',
#  '로맨스',
#  '드라마',
#  '로맨스',
#  '로맨스',
#  '드라마',
#  '드라마',
#  '드라마',
#  '초자연',
#  '코메디',
#  '공상',
#  '공상',
#  '드라마',
#  '역사적인',
#  '스릴러',
#  '드라마',
#  '드라마',
#  '초자연',
#  '로맨스',
#  '공상 과학',
#  '슈퍼 히어로',
#  '드라마',
#  '초자연',
#  '공상 과학',
#  '슈퍼 히어로',
#  '공상 과학',
#  '슈퍼 히어로',
#  '공상',
#  '드라마',
#  '드라마',
#  '드라마',
#  '공상',
#  '액션',
#  '공상 과학',
#  '드라마',
#  '공상',
#  '드라마',
#  '초자연',
#  '공상',
#  '공상',
#  '공상',
#  '드라마',
#  '드라마',
#  '드라마',
#  '코메디',
#  '공상 과학',
#  '로맨스',
#  '공상',
#  '공상 과학',
#  '로맨스',
#  '공상',
#  '드라마',
#  '드라마',
#  '드라마',
#  '로맨스',
#  '로맨스',
#  '공상',
#  '코메디',
#  '로맨스',
#  '공상',
#  '액션',
#  '액션',
#  '공상',
#  '공상',
#  '액션',
#  '액션',
#  '액션',
#  '공상',
#  '로맨스',
#  '공상',
#  '액션',
#  '공상',
#  '액션',
#  '로맨스',
#  '공상',
#  '액션',
#  '공상',
#  '액션',
#  '액션',
#  '로맨스',
#  '액션',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '액션',
#  '코메디',
#  '공상',
#  '코메디',
#  '공상',
#  '액션',
#  '코메디',
#  '공상',
#  '로맨스',
#  '액션',
#  '공상',
#  '공상',
#  '공상',
#  '액션',
#  '공상',
#  '액션',
#  '공상',
#  '액션',
#  '공상',
#  '액션',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '신비',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '로맨스',
#  '액션',
#  '공상',
#  '액션',
#  '코메디',
#  '액션',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '스릴러',
#  '공상',
#  '공상',
#  '액션',
#  '코메디',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '코메디',
#  '초자연',
#  '공상',
#  '공상 과학',
#  '공상 과학',
#  '공상',
#  '공상',
#  '액션',
#  '로맨스',
#  '공상 과학',
#  '로맨스',
#  '코메디',
#  '액션',
#  '로맨스',
#  '액션',
#  '액션',
#  '초자연',
#  '로맨스',
#  '공상',
#  '공상',
#  '공상',
#  '로맨스',
#  '공상',
#  '공상',
#  '코메디',
#  '코메디',
#  '공상',
#  '공상',
#  '스릴러',
#  '공상',
#  '공상',
#  '공상',
#  '일상물',
#  '공상 과학',
#  '초자연',
#  '액션',
#  '공상',
#  '공상 과학',
#  '액션',
#  '공상 과학',
#  '공상',
#  '액션',
#  '액션',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '공상 과학',
#  '초자연',
#  '공상 과학',
#  '공상',
#  '공상',
#  '코메디',
#  '슈퍼 히어로',
#  '공상 과학',
#  '초자연',
#  '코메디',
#  '공상',
#  '공상',
#  '공상',
#  '공상',
#  '초자연',
#  '초자연',
#  '일상물',
#  '코메디',
#  '일상물',
#  '코메디',
#  '로맨스',
#  '코메디',
#  '코메디',
#  '로맨스',
#  '코메디',
#  '로맨스',
#  '일상물',
#  '로맨스',
#  '로맨스',
#  '코메디',
#  '코메디',
#  '로맨스',
#  '코메디',
#  '일상물',
#  '스포츠',
#  '로맨스',
#  '코메디',
#  '일상물',
#  '코메디',
#  '로맨스',
#  '일상물',
#  '스포츠',
#  '코메디',
#  '일상물',
#  '코메디',
#  '코메디',
#  '코메디',
#  '코메디',
#  '초자연',
#  '코메디',
#  '공상 과학',
#  '코메디',
#  '일상물',
#  '코메디',
#  '일상물',
#  '코메디',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '코메디',
#  '일상물',
#  '코메디',
#  '로맨스',
#  '일상물',
#  '일상물',
#  '공상 과학',
#  '코메디',
#  '초자연',
#  '코메디',
#  '일상물',
#  '일상물',
#  '슈퍼 히어로',
#  '일상물',
#  '코메디',
#  '코메디',
#  '코메디',
#  '일상물',
#  '코메디',
#  '스포츠',
#  '일상물',
#  '일상물',
#  '코메디',
#  '코메디',
#  '코메디',
#  '스포츠',
#  '일상물',
#  '일상물',
#  '코메디',
#  '일상물',
#  '코메디',
#  '코메디',
#  '코메디',
#  '일상물',
#  '일상물',
#  '코메디',
#  '슈퍼 히어로',
#  '일상물',
#  '코메디',
#  '코메디',
#  '스포츠',
#  '액션',
#  '액션',
#  '액션',
#  '스포츠',
#  '액션',
#  '스포츠',
#  '공상 과학',
#  '슈퍼 히어로',
#  '스포츠',
#  '액션',
#  '액션',
#  '액션',
#  '스포츠',
#  '슈퍼 히어로',
#  '초자연',
#  '신비',
#  '공상 과학',
#  '공상 과학',
#  '공상 과학',
#  '초자연',
#  '공상 과학',
#  '공상 과학',
#  '슈퍼 히어로',
#  '초자연',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '액션',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '공상 과학',
#  '초자연',
#  '슈퍼 히어로',
#  '액션',
#  '슈퍼 히어로',
#  '일상물',
#  '로맨스',
#  '일상물',
#  '일상물',
#  '로맨스',
#  '로맨스',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '정보전달적',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '일상물',
#  '정보전달적',
#  '스릴러',
#  '스릴러',
#  '로맨스',
#  '로맨스',
#  '공포',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '공상 과학',
#  '로맨스',
#  '초자연',
#  '초자연',
#  '초자연',
#  '역사적인',
#  '로맨스',
#  '공상 과학',
#  '마음 흐뭇한',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '초자연',
#  '공상 과학',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '스포츠',
#  '초자연',
#  '로맨스',
#  '로맨스',
#  '로맨스',
#  '초자연',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '슈퍼 히어로',
#  '공상 과학',
#  '신비',
#  '공상 과학',
#  '공포',
#  '공상 과학',
#  '공포',
#  '스릴러',
#  '초자연',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '스릴러',
#  '공포',
#  '공포',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '공포',
#  '공포',
#  '공포',
#  '스릴러',
#  '공포',
#  '스릴러',
#  '스릴러',
#  '스릴러',
#  '초자연',
#  '스릴러',
#  '신비',
#  '신비',
#  '초자연',
#  '스릴러',
#  '초자연',
#  '공포',
#  '공포',
#  '초자연',
#  '신비',
#  '정보전달적',
#  '정보전달적',
#  '정보전달적']

# %%
twitter = Okt()

# keyword = []
# keyword = twitter.pos(text_trans2)

# noun_adj_list = []

# for word, tag in text_trans2:
#     if tag in ['noun', 'Adjective']:
#         noun_adj_list.append(word)

counts = Counter(text_trans4)
tags = counts.most_common(20)

wc2 = WordCloud(font_path='C:\\Windows\\Fonts\\malgunsl.ttf', background_color="white", max_font_size=60)
cloud2 = wc2.generate_from_frequencies(dict(tags))

plt.figure(figsize=(20,11))
plt.axis('off')
plt.imshow(cloud2)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            569 non-null    int64
#  1   Name          569 non-null    object
#  2   Writer        568 non-null    object
#  3   Likes         569 non-null    object
#  4   Genre         569 non-null    object
#  5   Rating        569 non-null    float64
#  6   Subscribers   569 non-null    object
#  7   Summary       569 non-null    object
#  8   Update        569 non-null    object
#  9   Reading Link  569 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 44.6+ KB

# %%
df.rename(columns={'Likes':'좋아요', 'Rating':'평점', 'Subscribers':'구독자'}, inplace=True)

# %%
ratings = pd.concat([df['평점'], df['좋아요'], df['구독자']], axis=1)

# %%
ratings
# Out:
#        평점       좋아요     구독자
# 0    9.62     30.6M    4.2M
# 1    9.60     39.9M    6.4M
# 2    9.81     10.4M    2.1M
# 3    9.79     25.9M    3.5M
# 4    9.85      9.9M    1.5M
# ..    ...       ...     ...
# 564  9.78  8,66,428  376.9K
# 565  9.32  1,84,981   60.4K
# 566  9.25      1.9M  459.2K
# 567  9.76      1.5M  204.6K
# 568  8.83  2,65,458  109.1K
#
# [569 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='NanumGothic')
sns.pairplot(ratings, diag_kind='hist')
plt.figure(figsize=(12,12))
plt.show()

# %%
sns.lineplot(x=ratings['좋아요'], y=ratings['평점'])
# Out:
# <AxesSubplot:xlabel='좋아요', ylabel='평점'>

# %%
sns.regplot(x=ratings['좋아요'], y=ratings['평점'])
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 sns.regplot(x=ratings['좋아요'], y=ratings['평점'])
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\regression.py:863, in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861 scatter_kws["marker"] = marker
#     862 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 863 plotter.plot(ax, scatter_kws, line_kws)
#     864 return ax
#
# File ~\anaconda3\lib\site-packages\seaborn\regression.py:370, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     367     self.scatterplot(ax, scatter_kws)
#     369 if self.fit_reg:
# --> 370     self.lineplot(ax, line_kws)
#     372 # Label the axes
#     373 if hasattr(self.x, "name"):
#
# File ~\anaconda3\lib\site-packages\seaborn\regression.py:413, in _RegressionPlotter.lineplot(self, ax, kws)
#     411 """Draw the model."""
#     412 # Fit the regression model
# --> 413 grid, yhat, err_bands = self.fit_regression(ax)
#     414 edges = grid[0], grid[-1]
#     416 # Get set default aesthetics
#
# File ~\anaconda3\lib\site-packages\seaborn\regression.py:201, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     199         else:
#     200             x_min, x_max = ax.get_xlim()
# --> 201     grid = np.linspace(x_min, x_max, 100)
#     202 ci = self.ci
#     204 # Fit the regression
#
# File <__array_function__ internals>:5, in linspace(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\function_base.py:127, in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     123 div = (num - 1) if endpoint else num
#     125 # Convert float/complex array scalars to float, gh-3504
#     126 # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 127 start = asanyarray(start) * 1.0
#     128 stop  = asanyarray(stop)  * 1.0
#     130 dt = result_type(start, stop, float(num))
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('<U8'), dtype('float64')) -> None
