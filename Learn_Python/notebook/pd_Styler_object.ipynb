# %%
df = pd.DataFrame({'angle':angle_list,
                   'Miller':Miller_list,
                   'LiCor':LiCor_list})
caption = f'file name : {picture[0]}'
styler = df.style.set_caption(caption)
styles = [dict(selector="caption", props=[("text-align", "left"), ("color", 'gray')])]
styler.set_table_styles(styles)
    
styler
# Out:
# <style type="text/css">
# #T_52635 caption {
#   text-align: left;
#   color: gray;
# }
# </style>
# <table id="T_52635">
#   <caption>file name : ﻿picture        	ICT0908A_9_Raw.png
# </caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52635_level0_col0" class="col_heading level0 col0" >angle</th>
#       <th id="T_52635_level0_col1" class="col_heading level0 col1" >Miller</th>
#       <th id="T_52635_level0_col2" class="col_heading level0 col2" >LiCor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52635_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52635_row0_col0" class="data row0 col0" >60</td>
#       <td id="T_52635_row0_col1" class="data row0 col1" >3.77</td>
#       <td id="T_52635_row0_col2" class="data row0 col2" >3.46</td>
#     </tr>
#     <tr>
#       <th id="T_52635_level0_row1" class="row_heading level0 row1" >1</th>
# ...
