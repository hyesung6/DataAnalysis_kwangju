# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
response = requests.get('http://www.hanbit.co.kr/store/books/new_book_list.html')

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <!--[if lte IE 8]>
# <script>
#   location.replace('/support/explorer_upgrade.html');
# </script>
# <![endif]-->
#   <meta charset="utf-8"/>
#   <title>
#    한빛출판네트워크
#   </title>
#   <link href="https://www.hanbit.co.kr/images/common/hanbit.ico" rel="shortcut icon"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="website" property="og:type"/>
#   <meta content="한빛출판네트워크" property="og:title"/>
#   <meta content="더 넓은 세상, 더 나은 미래를 위한 아시아 출판 네트워크 :: 한빛미디어, 한빛아카데미, 한빛비즈, 한빛라이프, 한빛에듀" property="og:description"/>
#   <meta content="https://www.hanbit.co.kr/images/hanbitpubnet_logo.jpg" property="og:image"/>
#   <meta content="https://www.hanbit.co.kr/store/books/new_book_list.html" property="og:url"/>
#   <link href="https://www.hanbit.co.kr/store/books/new_book_list.html" rel="canonical">
# ...

# %%
soup.select_one('.view_box .book_tit a').text
# Out:
# '받침 없는 한글 동화 : 4권 세트'

# %%
soup.select_one('.view_box .book_tit a').contents
# Out:
# ['받침 없는 한글 동화 : 4권 세트']

# %%
soup.select_one('.view_box .book_tit a').name
# Out:
# 'a'

# %%
response.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n<!--[if lte IE 8]>\r\n<script>\r\n  location.replace(\'/support/explorer_upgrade.html\');\r\n</script>\r\n<![endif]-->\r\n<meta charset="utf-8"/>\r\n<title>\xed\x95\x9c\xeb\xb9\x9b\xec\xb6\x9c\xed\x8c\x90\xeb\x84\xa4\xed\x8a\xb8\xec\x9b\x8c\xed\x81\xac</title>\r\n<link rel="shortcut icon" href="https://www.hanbit.co.kr/images/common/hanbit.ico"> \r\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n<meta property="og:type" content="website"/>\r\n<meta property="og:title" content="\xed\x95\x9c\xeb\xb9\x9b\xec\xb6\x9c\xed\x8c\x90\xeb\x84\xa4\xed\x8a\xb8\xec\x9b\x8c\xed\x81\xac"/>\r\n<meta property="og:description" content="\xeb\x8d\x94 \xeb\x84\x93\xec\x9d\x80 \xec\x84\xb8\xec\x83\x81, \xeb\x8d\x94 \xeb\x82\x98\xec\x9d\x80 \xeb\xaf\xb8\xeb\x9e\x98\xeb\xa5\xbc \xec\x9c\x84\xed\x95\x9c \xec\x95\x84\xec\x8b\x9c\xec\x95\x84 \xec\xb6\x9c\xed\x8c\x90 \xeb\x84\xa4\xed\x8a\xb8\xec\x9b\x8c\xed\x81\xac :: \xed\x95\x9c\xeb\xb9\x9b\xeb\xa
# ...

# %%
header = requests.head('http://www.hanbit.co.kr/store/books/new_book_list.html')

# %%
soup_header = BeautifulSoup(header.text, 'lxml')

# %%
soup.header
# Out:
# <header>
# <!-- top menu -->
# <nav>
# <div id="wrap_nav">
# <ul class="top_brand">
# <li><a href="https://www.hanbit.co.kr/index.html" name="hanbit_network"><span>HOME</span></a></li>
# <li><a href="https://www.hanbit.co.kr/media/">한빛미디어</a></li>
# <li><a href="https://www.hanbit.co.kr/academy/">한빛아카데미</a></li>
# <li><a href="https://www.hanbit.co.kr/biz/">한빛비즈</a></li>
# <li><a href="https://www.hanbit.co.kr/life/">한빛라이프</a></li>
# <li><a href="https://www.hanbit.co.kr/edu/">한빛에듀</a></li>
# <li><a href="https://www.hanbit.co.kr/realtime/">리얼타임</a></li>
# <li><a href="https://www.hanbit.co.kr/textbook/" target="_blank">한빛정보교과서</a></li>
# <li><a href="https://www.hanbit.co.kr/rent/" target="_blank">한빛대관서비스</a></li>
# </ul>
# <ul class="top_menu">
# <li><a class="login" href="https://www.hanbit.co.kr/member/login.html">로그인</a></li>
# <li><a class="join" href="https://www.hanbit.co.kr/member/member_agree.html">회원가입</a></li>
# ...

# %%
soup.text    # html.parser로 만든 soup 객체
# Out:
# '\n\n\n\n\n한빛출판네트워크\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n메뉴 바로가기\n검색 및 카테고리 바로가기\n본문 바로가기\n\n\n\n\n\n\n\n\nHOME\n한빛미디어\n한빛아카데미\n한빛비즈\n한빛라이프\n한빛에듀\n리얼타임\n한빛정보교과서\n한빛대관서비스\n\n\n로그인\n회원가입\n마이한빛\n장바구니\nENGLISH\n\n\n\n\n\n\n한빛출판네트워크\n\n\n\n\nBRAND\nChannel.H\nSTORE\nSUPPORT\nEVENT\nRIGHTS\nSEARCH\n\n\n\n\n\n\n\n\n카테고리\n\nIT/모바일\n\n프로그래밍\n웹\n모바일/스마트기기\n데이터베이스\n운영체제\n하드웨어\n시스템/네트워크\n보안\n비즈니스/문화\n게임\nIT에세이\n자격증\n인공지능/데이터과학\n MAKE\n\nMake 프로젝트 북\n IT활용\n\n오피스/OA\n그래픽/멀티미디어\n사진/예술\n컴퓨터입문/IT교양\n 대학교재\n\n수학/통계\n과학/공학일반\n컴퓨터공학\n프로그래밍\n데이터과학/인공지능\n전기/전자\n기계/자동차\nOA/그래픽\n경영/경제\n논문\n 실용서\n\n취미/실용\n여행\n건강\n유아/육아\n 경제/경영/인문\n\n경제/경영\n자기계발\n인문/교양\n마케팅\n에세이\n 유아/어린이/초등\n\n4~6세\n5~7세\n예비초등\n초등교과연계 1~12영역\n초등 전학년\n\n\n\n\n\n\n\n새로나온책l\n예약도서l\n베스트셀러l\n전체도서목록l\n시리즈l\n\n오라일리 굿즈\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n한빛출판네트워크 검색\n\n\n\n\n\n\n\n\n인기 검색어 (최근 1개월간)\n\n\n\n\n                  {{ keyword.number }} {{ keyword.bookName }}\n             
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup = BeautifulSoup(response.content, 'lxml')

# %%
soup.text     # lxml 파서로 만든 soup 객체
# html.parser 보다는 lxml 사용 권장
# html.parser는 크롤링 대상 페이지가 html 규격을 제대로
# 지키지 않은 경우에 가져오지 못하는 코드가 있을 수 있음
# 또한 lxml이 일반적인 속도면에서 더욱 빠름
# Out:
# '\n\n\n\n\n한빛출판네트워크\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n메뉴 바로가기\n검색 및 카테고리 바로가기\n본문 바로가기\n\n\n\n\n\n\n\n\nHOME\n한빛미디어\n한빛아카데미\n한빛비즈\n한빛라이프\n한빛에듀\n리얼타임\n한빛정보교과서\n한빛대관서비스\n\n\n로그인\n회원가입\n마이한빛\n장바구니\nENGLISH\n\n\n\n\n\n\n한빛출판네트워크\n\n\n\n\nBRAND\nChannel.H\nSTORE\nSUPPORT\nEVENT\nRIGHTS\nSEARCH\n\n\n\n\n\n\n\n\n카테고리\n\nIT/모바일\n\n프로그래밍\n웹\n모바일/스마트기기\n데이터베이스\n운영체제\n하드웨어\n시스템/네트워크\n보안\n비즈니스/문화\n게임\nIT에세이\n자격증\n인공지능/데이터과학\n MAKE\n\nMake 프로젝트 북\n IT활용\n\n오피스/OA\n그래픽/멀티미디어\n사진/예술\n컴퓨터입문/IT교양\n 대학교재\n\n수학/통계\n과학/공학일반\n컴퓨터공학\n프로그래밍\n데이터과학/인공지능\n전기/전자\n기계/자동차\nOA/그래픽\n경영/경제\n논문\n 실용서\n\n취미/실용\n여행\n건강\n유아/육아\n 경제/경영/인문\n\n경제/경영\n자기계발\n인문/교양\n마케팅\n에세이\n 유아/어린이/초등\n\n4~6세\n5~7세\n예비초등\n초등교과연계 1~12영역\n초등 전학년\n\n\n\n\n\n\n\n새로나온책l\n예약도서l\n베스트셀러l\n전체도서목록l\n시리즈l\n\n오라일리 굿즈\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n한빛출판네트워크 검색\n\n\n\n\n\n\n\n\n인기 검색어 (최근 1개월간)\n\n\n\n\n                  {{ keyword.number }} {{ keyword.bookName }}\n             
# ...

# %%
soup.tagStack   # html.parser의 태그스택
# Out:
# [<!DOCTYPE html>
#
#  <html lang="ko">
#  <head>
#  <!--[if lte IE 8]>
#  <script>
#    location.replace('/support/explorer_upgrade.html');
#  </script>
#  <![endif]-->
#  <meta charset="utf-8"/>
#  <title>한빛출판네트워크</title>
#  <link href="https://www.hanbit.co.kr/images/common/hanbit.ico" rel="shortcut icon"/>
#  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#  <meta content="website" property="og:type"/>
#  <meta content="한빛출판네트워크" property="og:title"/>
#  <meta content="더 넓은 세상, 더 나은 미래를 위한 아시아 출판 네트워크 :: 한빛미디어, 한빛아카데미, 한빛비즈, 한빛라이프, 한빛에듀" property="og:description"/>
#  <meta content="https://www.hanbit.co.kr/images/hanbitpubnet_logo.jpg" property="og:image"/>
#  <meta content="https://www.hanbit.co.kr/store/books/new_book_list.html" property="og:url"/>
#  <link href="https://www.hanbit.co.kr/store/books/new_book_list.html" rel="canonical">
# ...

# %%
soup.tagStack   # lxml의 태그스택
# Out:
# [<!DOCTYPE html>
#
#  <html lang="ko">
#  <head>
#  <!--[if lte IE 8]>
#  <script>
#    location.replace('/support/explorer_upgrade.html');
#  </script>
#  <![endif]-->
#  <meta charset="utf-8"/>
#  <title>한빛출판네트워크</title>
#  <link href="https://www.hanbit.co.kr/images/common/hanbit.ico" rel="shortcut icon"/>
#  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#  <meta content="website" property="og:type"/>
#  <meta content="한빛출판네트워크" property="og:title"/>
#  <meta content="더 넓은 세상, 더 나은 미래를 위한 아시아 출판 네트워크 :: 한빛미디어, 한빛아카데미, 한빛비즈, 한빛라이프, 한빛에듀" property="og:description"/>
#  <meta content="https://www.hanbit.co.kr/images/hanbitpubnet_logo.jpg" property="og:image"/>
#  <meta content="https://www.hanbit.co.kr/store/books/new_book_list.html" property="og:url"/>
#  <link href="https://www.hanbit.co.kr/store/books/new_book_list.html" rel="canonical">
# ...

# %%
# 타이틀 태그 반환
print(soup.title)
# Out:
# <title>한빛출판네트워크</title>

# %%
# 타이틀 태그 객체의 이름을 반환
print(soup.title.name)
# Out:
# title

# %%
# 타이틀 태그의 문자열 반환
print(soup.title.string)
# Out:
# 한빛출판네트워크

# %%
# 타이틀 태그의 부모 태그의 이름 반환
print(soup.title.parent.name)
# Out:
# head

# %%
# 첫 번째 p 태그 반환
print(soup.p)
# Out:
# <p v-html="book.name"></p>

# %%
# 속성이 있는 첫 p 태그 반환
# print(soup.p['class'])

# 위 페이지에는 p태그에 class가 있는 게 없음..

# %%
# 첫 a 태그 반환
soup.a
# Out:
# <a href="#gnb" onclick="document.getElementById('gnb').tabIndex = -1;document.getElementById('gnb').focus();return false;"><span>메뉴 바로가기</span></a>

# %%
# 모든 a 태그 -> 리스트로 반환
soup.find_all('a', limit=10)

# soup.find_all?
# limit=(int)까지만 반환
# Out:
# [<a href="#gnb" onclick="document.getElementById('gnb').tabIndex = -1;document.getElementById('gnb').focus();return false;"><span>메뉴 바로가기</span></a>,
#  <a href="#top_search" onclick="view_hover('main_search_area','','show'), document.getElementById('top_search').tabIndex = -1;document.getElementById('top_search').focus();return false;"><span>검색 및 카테고리 바로가기</span></a>,
#  <a href="#container" onclick="document.getElementById('container').tabIndex = -1;document.getElementById('container').focus();return false;"><span>본문 바로가기</span></a>,
#  <a href="https://www.hanbit.co.kr/index.html" name="hanbit_network"><span>HOME</span></a>,
#  <a href="https://www.hanbit.co.kr/media/">한빛미디어</a>,
#  <a href="https://www.hanbit.co.kr/academy/">한빛아카데미</a>,
#  <a href="https://www.hanbit.co.kr/biz/">한빛비즈</a>,
#  <a href="https://www.hanbit.co.kr/life/">한빛라이프</a>,
#  <a href="https://www.hanbit.co.kr/edu/">한빛에듀</a>,
#  <a href="https://www.hanbit.co.kr/realtime/">리얼타임</a>]

# %%
# id 지정하여 찾기
# print(soup.find())

# soup.find('address', 'location')  : 클래스 location에서 address 태그 찾기
# soup.find('address', id='1')      : ID '1'에서 address 태그 찾기

# %%
for link in soup.find_all('a', limit=20):
    print(link.get('href'))
# Out:
# #gnb
# #top_search
# #container
# https://www.hanbit.co.kr/index.html
# https://www.hanbit.co.kr/media/
# https://www.hanbit.co.kr/academy/
# https://www.hanbit.co.kr/biz/
# https://www.hanbit.co.kr/life/
# https://www.hanbit.co.kr/edu/
# https://www.hanbit.co.kr/realtime/
# https://www.hanbit.co.kr/textbook/
# https://www.hanbit.co.kr/rent/
# https://www.hanbit.co.kr/member/login.html
# https://www.hanbit.co.kr/member/member_agree.html
# https://www.hanbit.co.kr/myhanbit/myhanbit.html
# https://www.hanbit.co.kr/myhanbit/cart.html
# https://www.hanbit.co.kr/publisher/foreignrights.html?lang=e
# https://www.hanbit.co.kr/index.html
# https://www.hanbit.co.kr/brand/brand_submain.html
# https://www.hanbit.co.kr/channel/channel_submain.html

# %%
print(soup.get_text())
# Out:
# 한빛출판네트워크
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 메뉴 바로가기
# 검색 및 카테고리 바로가기
# 본문 바로가기
#
#
#
#
#
#
#
#
# HOME
# 한빛미디어
# 한빛아카데미
# 한빛비즈
# 한빛라이프
# 한빛에듀
# 리얼타임
# 한빛정보교과서
# 한빛대관서비스
#
#
# 로그인
# 회원가입
# 마이한빛
# 장바구니
# ENGLISH
#
#
#
#
#
#
# 한빛출판네트워크
#
#
#
#
# BRAND
# Channel.H
# STORE
# SUPPORT
# EVENT
# RIGHTS
# SEARCH
#
#
#
#
#
#
#
#
# 카테고리
#
# IT/모바일
#
# 프로그래밍
# 웹
# 모바일/스마트기기
# 데이터베이스
# 운영체제
# 하드웨어
# 시스템/네트워크
# 보안
# 비즈니스/문화
# 게임
# IT에세이
# 자격증
# 인공지능/데이터과학
#  MAKE
#
# Make 프로젝트 북
#  IT활용
#
# 오피스/OA
# 그래픽/멀티미디어
# 사진/예술
# 컴퓨터입문/IT교양
#  대학교재
#
# 수학/통계
# 과학/공학일반
# 컴퓨터공학
# 프로그래밍
# 데이터과학/인공지능
# 전기/전자
# 기계/자동차
# OA/그래픽
# 경영/경제
# 논문
#  실용서
#
# 취미/실용
# 여행
# 건강
# 유아/육아
#  경제/경영/인문
#
# 경제/경영
# 자기계발
# 인문/교양
# 마케팅
# 에세이
#  유아/어린이/초등
#
# 4~6세
# 5~7세
# 예비초등
# 초등교과연계 1~12영역
# 초등 전학년
#
#
#
#
#
#
#
# 새로나온책l
# 예약도서l
# 베스트셀러l
# 전체도서목록l
# 시리즈l
#
# 오라일리 굿즈
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 한빛출판네트워크 검색
#
#
#
#
#
#
#
#
# 인기 검색어 (최근 1개월간)
#
#
#
#
# ...

# %%
# requests 로 생성된 response 객체는
# .text 는 유니코드 형태로 저장하고 있고
# .content 는 bytes 형태로 저장하고 있음

# %%
# requests.get(url)로 가져온 response 객체
# 인코딩 형식 확인
response.encoding
# Out:
# 'UTF-8'

# %%
# 헤더의 content-type 확인
response.headers['Content-Type']
# Out:
# 'text/html; charset=UTF-8'

# %%
# 통신 상태 확인
response.ok
# Out:
# True

# %%
# 통신 상태 http 코드번호로 확인
response.status_code
# Out:
# 200

# %% [markdown]
# requests를 통해 html 소스를 가져올 수는 있지만,
# 단순 문자열 형태이므로 Parsing이 불가능.
#
# 때문에, bs(data, parser) 형태로 파싱된 객체를 만든 후,
# 그 객체가 가지고 있는 소스로 원하는 데이터를 뽑아내면 된다.

# %%
#main_content > div > div._persist > div > div:nth-child(1) > div.cluster_body > ul > li:nth-child(1) > div.cluster_text > a
