# %%
import pandas as pd

# %%
data = pd.read_csv('광주광역시_법정동_행정구역_거리행렬.csv', encoding='euc-kr')

# %%
data.sort_index(ascending=True, inplace=True)

# %%
data
# Out:
#       ID           치평동           마륵동            양동           금호동  \
# 0    연제동   5536.810966   6700.342742   5981.641865   7498.956207
# 1    운암동   4354.276245   5269.120569   3323.836157   5530.965808
# 2    덕림동  16011.159877  16234.569710  21158.755588  17818.174018
# 3    삼거동  15297.877630  15333.417710  20544.220937  16806.645949
# 4    동림동   3474.051847   4610.353611   4723.348147   5406.622279
# ..   ...           ...           ...           ...           ...
# 205  광천동   3753.313834   4401.440192   2144.305975   4301.267261
# 206  쌍촌동   1877.224242   2273.629807   3384.456895   2345.002069
# 207  내방동   2887.045642   3478.024334   2557.305080   3440.043760
# 208  덕흥동   1503.546126   2664.017686   5880.422596   4103.830123
# 209  대의동   7175.454357   7274.219818   1995.914757   6197.458589
#
#               진월동           방림동           용두동           노대동           이장동  \
# 0     9861.063479   9198.657934  11962.975428  11763.876336  12353.072098
# ...
