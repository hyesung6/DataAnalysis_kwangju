# %%
# !pip install pulp

import pandas as pd
from pulp import *
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pulp
#   Downloading PuLP-2.6.0-py3-none-any.whl (14.2 MB)
#      |████████████████████████████████| 14.2 MB 5.2 MB/s
# Installing collected packages: pulp
# Successfully installed pulp-2.6.0

# %%
import pandas as pd

# %%
# distance_matrix = pd.read_excel('./광주광역시_경계구역_읍면동_충장동통합.xlsx', usecols = 'B : GM')
distance_matrix = pd.read_excel('./광주광역시_경계구역_읍면동_충장동통합.xlsx')

# %%
pop = pd.read_excel('./행정안전부_지역별(법정동) 주민등록 인구수.xlsx')

# %%
pop_final = list(pop.iloc[:, 1])
final = distance_matrix[:194]

# %%
pop_final
final.columns
# Out:
# Index(['ID', '쌍촌동', '광천동', '덕흥동', '내방동', '양동', '금호동', '농성동', '화정동', '용두동',
#        ...
#        '매곡동', '동림동.1', '삼거동', '서석동', '일곡동', '연제동', '덕림동', '운암동', '충장동', '대의동'],
#       dtype='object', length=194)

# %%
df = pop
df
pop_final
# Out:
# ['대인동',
#  '충장동',
#  '수기동',
#  '대의동',
#  '궁동',
#  '장동',
#  '동명동',
#  '계림동',
#  '산수동',
#  '지산동',
#  '남동',
#  '광산동',
#  '금동',
#  '호남동',
#  '불로동',
#  '황금동',
#  '서석동',
#  '소태동',
#  '용연동',
#  '운림동',
#  '학동',
#  '월남동',
#  '선교동',
#  '내남동',
#  '용산동',
#  '양동',
#  '농성동',
#  '광천동',
#  '유촌동',
#  '덕흥동',
#  '쌍촌동',
#  '화정동',
#  '치평동',
#  '내방동',
#  '서창동',
#  '세하동',
#  '용두동',
#  '풍암동',
#  '벽진동',
#  '금호동',
#  '마륵동',
#  '매월동',
#  '동천동',
#  '사동',
#  '구동',
#  '서동',
#  '월산동',
#  '백운동',
#  '주월동',
#  '노대동',
#  '진월동',
#  '덕남동',
#  '행암동',
#  '임암동',
#  '송하동',
#  '양림동',
#  '방림동',
#  '봉선동',
#  '구소동',
#  '양촌동',
#  '도금동',
#  '승촌동',
#  '지석동',
#  '압촌동',
#  '화장동',
#  '칠석동',
#  '석정동',
#  '신장동',
#  '양과동',
#  '이장동',
#  '대지동',
#  '원산동',
#  '월성동',
#  '중흥동',
#  '유동',
#  '누문동',
#  '북동',
#  '임동',
#  '신안동',
#  '용봉동',
#  '동림동',
#  '운암동',
#  '우산동',
#  '풍향동',
#  '문흥동',
#  '각화동',
#  '두암동',
#  '오치동',
#  '삼각동',
#  '매곡동',
#  '충효동',
#  '덕의동',
#  '금곡동',
#  '망월동',
#  '청풍동',
#  '화암동',
#  '장등동',
#  '운정동',
#  '본촌동',
#  '일곡동',
#  '양산동',
#  '연제동',
#  '신용동',
#  '용두동',
#  '지야동',
#  '태령동',
#  '수곡동',
#  '효령동',
#  '용전동',
#  '용강동',
#  '생용동',
#  '월출동',
#  '대촌동',
#  '오룡동',
#  '송정동',
#  '도산동',
#  '신촌동',
#  '서봉동',
#  '운수동',
#  '선암동',
#  '소촌동',
#  '우산동',
#  '황룡동',
#  '박호동',
#  '비아동',
#  '도천동',
#  '수완동',
#  '월계동',
#  '쌍암동',
#  '산월동',
#  '신창동',
#  '신가동',
#  '운남동',
#  '안청동',
#  '진곡동',
#  '장덕동',
#  '흑석동',
#  '하남동',
#  '장수동',
#  '산정동',
#  '월곡동',
#  '등임동',
#  '산막동',
#  '고룡동',
#  '신룡동',
#  '두정동',
#  '임곡동',
#  '광산동',
#  '오산동',
#  '사호동',
#  '하산동',
#  '유계동',
#  '본덕동',
#  '용봉동',
#  '요기동',
#  '복룡동',
#  '송대동',
#  '옥동',
#  '월전동',
#  '장록동',
#  '송촌동',
#  '지죽동',
#  '용동',
#  '용곡동',
#  '지정동',
#  '명화동',
#  '동산동',
#  '연산동',
#  '도덕동',
#  '송산동',
#  '지평동',
#  '오운동',
#  '삼거동',
#  '양동',
#  '내산동',
#  '대산동',
#  '송학동',
#  '신동',
#  '삼도동',
#  '남산동',
#  '송치동',
#  '산수동',
#  '선동',
#  '지산동',
#  '왕동',
#  '북산동',
#  '명도동',
#  '동호동',
#  '덕림동',
#  '양산동',
#  '동림동',
#  '오선동',
#  '도호동']

# %%
for i in range(193):
  for j in range(193):
    if(final.columns[i+1] == pop_final[j]):
      df['시군구명'][i] = pop['시군구명'][j]
      df['읍면동명'][i] = pop['읍면동명'][j]
      df['계'][i] = pop['계'][j]
    else if(final.columns[i+1])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#     시군구명 읍면동명      계
# 0     서구  쌍촌동  48520
# 1     서구  광천동   7805
# 2     서구  덕흥동    451
# 3     서구  내방동   7315
# 4    광산구   양동     86
# ..   ...  ...    ...
# 188  광산구  소촌동  18240
# 189  광산구  소촌동  18240
# 190  광산구  두정동    174
# 191   서구  광천동   7805
# 192   서구  내방동   7315
#
# [193 rows x 3 columns]

# %%
# distance_matrix, pop 행렬 순서 맞추기
pop_sort = []

for i in range(194):
  for j in range(194):

# %%
final.set_index('ID', drop = True)
# Out:
#               쌍촌동           광천동           덕흥동           내방동            양동  \
# ID
# 쌍촌동      0.000000   2144.880040   2777.057990   1219.937464   3384.456895
# 광천동   2144.880040      0.000000   3978.915679    925.629677   2144.305975
# 덕흥동   2777.057990   3978.915679      0.000000   3325.467411   5880.422596
# 내방동   1219.937464    925.629677   3325.467411      0.000000   2557.305080
# 양동    3384.456895   2144.305975   5880.422596   2557.305080      0.000000
# ..            ...           ...           ...           ...           ...
# 연제동   5203.873351   4078.424700   4488.934003   4450.337113   5981.641865
# 덕림동  17858.745719  19256.989765  15297.367656  18616.163476  21158.755588
# 운암동   3210.002830   1479.575465   4042.530174   2120.308959   3323.836157
# 충장동   4719.221324   3514.044542   7278.975663   3959.531525   1404.414001
# 대의동   5300.442001   4092.480465   7871.125847   4551.738479   1995.914757
#
#               금호동           농성동           화정동           용두동           노대동  \
# ID
# 쌍촌동   2345.002069   2346.190337   1528.531870   7300.512049   7198.810977
# 광천동   4301.267261   1449.055894   2295.055030   9400.995362   7686.436453
# 덕흥동   4103.830123   4880.983845   4304.702996   7631.902789   9827.266956
# 내방동   3440.043760   1586.586220   1718.937815   8497.535092   7430.223601
# 양동    4696.017023   1038.669816   2359.309870   9784.527111   6063.669832
# ..            ...           ...           ...           ...           ...
# 연제동   7498.956207   5515.912989   6168.480218  11962.975428  11763.876336
# 덕림동  17818.174018  20138.147663  19271.398776  16206.507848  23635.080169
# 운암동   5530.965808   2872.202256   3738.373978  10481.191486   9136.349579
# 충장동   5705.278428   2406.140209   3500.355989  10614.023245   5579.339607
# 대의동   6197.458589   2996.549317   4045.686134  11025.111359   5507.039326
#
#      ...           매곡동         동림동.1           삼거동           서석동  \
# ID   ...
# 쌍촌동  ...   4847.021614   3153.290374  17174.384225   6247.368919
# 광천동  ...   2908.162558   2588.248015  18783.042094   5208.223763
# 덕흥동  ...   5500.964102   2650.422626  14809.415603   8897.869562
# 내방동  ...   3705.422217   2613.922859  18057.813708   5603.358546
# 양동   ...   4137.886531   4723.348147  20544.220937   3077.121691
# ..   ...           ...           ...           ...           ...
# 연제동  ...   2491.806174   2108.316689  17828.379195   8772.651572
# 덕림동  ...  19964.775300  17234.339096   2582.015981  24106.106011
# 운암동  ...   1653.432875   1753.938186  18697.397381   6217.197920
# 충장동  ...   5024.747536   6060.002849  21893.497942   1698.352105
# 대의동  ...   5440.274086   6622.210823  22472.955153   1151.152825
#
#               일곡동           연제동           덕림동           운암동           충장동  \
# ID
# 쌍촌동   7071.763137   5203.873351  17858.745719   3210.002830   4719.221324
# 광천동   5176.414398   4078.424700  19256.989765   1479.575465   3514.044542
# 덕흥동   7306.402450   4488.934003  15297.367656   4042.530174   7278.975663
# 내방동   5960.689499   4450.337113  18616.163476   2120.308959   3959.531525
# 양동    6210.027719   5981.641865  21158.755588   3323.836157   1404.414001
# ..            ...           ...           ...           ...           ...
# 연제동   3146.742693      0.000000  17758.223268   2667.898543   7132.787213
# 덕림동  20799.409150  17758.223268      0.000000  18973.207780  22544.151187
# 운암동   3862.574187   2667.898543  18973.207780      0.000000   4539.401996
# 충장동   6851.039010   7132.787213  22544.151187   4539.401996      0.000000
# 대의동   7157.197991   7625.168520  23133.617884   5066.654206    592.273375
#
#               대의동
# ID
# 쌍촌동   5300.442001
# 광천동   4092.480465
# 덕흥동   7871.125847
# 내방동   4551.738479
# 양동    1995.914757
# ..            ...
# 연제동   7625.168520
# 덕림동  23133.617884
# 운암동   5066.654206
# 충장동    592.273375
# 대의동      0.000000
#
# [193 rows x 193 columns]

# %%
pop_final

# %%
region_name = final.iloc[:1]
region_name_final = list(region_name)
location = region_name_final # 동 이름 전처리

# %%
region_name_final
# Out:
# ['ID',
#  '쌍촌동',
#  '광천동',
#  '덕흥동',
#  '내방동',
#  '양동',
#  '금호동',
#  '농성동',
#  '화정동',
#  '용두동',
#  '노대동',
#  '치평동',
#  '마륵동',
#  '석정동',
#  '신장동',
#  '진월동',
#  '방림동',
#  '지석동',
#  '압촌동',
#  '이장동',
#  '송하동',
#  '대지동',
#  '원산동',
#  '주월동',
#  '봉선동',
#  '행암동',
#  '임암동',
#  '월성동',
#  '덕남동',
#  '양과동',
#  '양림동',
#  '화장동',
#  '칠석동',
#  '양촌동',
#  '도금동',
#  '승촌동',
#  '구소동',
#  '서동',
#  '월산동',
#  '사동',
#  '구동',
#  '운정동',
#  '오룡동',
#  '백운동',
#  '장등동',
#  '지야동',
#  '태령동',
#  '문흥동',
#  '용두동.1',
#  '용강동',
#  '생용동',
#  '수곡동',
#  '효령동',
#  '풍향동',
#  '본촌동',
#  '대촌동',
#  '임동',
#  '북동',
#  '신안동',
#  '유동',
#  '누문동',
#  '월출동',
#  '각화동',
#  '오치동',
#  '용전동',
#  '덕의동',
#  '금곡동',
#  '용봉동',
#  '충효동',
#  '화암동',
#  '중흥동',
#  '망월동',
#  '청풍동',
#  '우산동',
#  '복룡동',
#  '두암동',
#  '신용동',
#  '진곡동',
#  '장덕동',
#  '송대동',
#  '안청동',
#  '신룡동',
#  '두정동',
#  '산막동',
#  '고룡동',
#  '장수동',
#  '산정동',
#  '임곡동',
#  '광산동',
#  '옥동',
#  '장록동',
#  '월곡동',
#  '등임동',
#  '용동',
#  '용곡동',
#  '송촌동',
#  '지죽동',
#  '도덕동',
#  '송정동',
#  '지정동',
#  '동산동',
#  '신촌동',
#  '소촌동',
#  '도산동',
#  '도호동',
#  '박호동',
#  '명화동',
#  '우산동.1',
#  '황룡동',
#  '산월동',
#  '신창동',
#  '월계동',
#  '쌍암동',
#  '산수동',
#  '선동',
#  '신가동',
#  '운남동',
#  '본덕동',
#  '용봉동.1',
#  '오산동',
#  '사호동',
#  '지평동',
#  '양동.1',
#  '송산동',
#  '오운동',
#  '송학동',
#  '신동',
#  '내산동',
#  '대산동',
#  '송치동',
#  '유계동',
#  '삼도동',
#  '남산동',
#  '북산동',
#  '명도동',
#  '지산동',
#  '왕동',
#  '동림동',
#  '오선동',
#  '동호동',
#  '양산동',
#  '선암동',
#  '하남동',
#  '운수동',
#  '서봉동',
#  '흑석동',
#  '비아동',
#  '월전동',
#  '하산동',
#  '요기동',
#  '연산동',
#  '도천동',
#  '수완동',
#  '소태동',
#  '용연동',
#  '내남동',
#  '월남동',
#  '지산동.1',
#  '수기동',
#  '대인동',
#  '선교동',
#  '금동',
#  '호남동',
#  '궁동',
#  '장동',
#  '학동',
#  '운림동',
#  '불로동',
#  '황금동',
#  '산수동.1',
#  '동명동',
#  '용산동',
#  '계림동',
#  '세하동',
#  '매월동',
#  '삼각동',
#  '풍암동',
#  '벽진동',
#  '서창동',
#  '동천동',
#  '유촌동',
#  '양산동.1',
#  '남동',
#  '광산동.1',
#  '매곡동',
#  '동림동.1',
#  '삼거동',
#  '서석동',
#  '일곡동',
#  '연제동',
#  '덕림동',
#  '운암동',
#  '충장동',
#  '대의동']

# %%
a = dict(zip(location, ))

# %%
a = dict(zip(location, pop_final))

# %%
a
# Out:
# {'각화동': '승촌동',
#  '계림동': '오운동',
#  '고룡동': '풍향동',
#  '광산동': '오치동',
#  '광산동.1': '선동',
#  '광천동': '충장동',
#  '구동': '금호동',
#  '구소동': '세하동',
#  '궁동': '용동',
#  '금곡동': '칠석동',
#  '금동': '송촌동',
#  '금호동': '장동',
#  '남동': '산수동',
#  '남산동': '신가동',
#  '내남동': '요기동',
#  '내방동': '대의동',
#  '내산동': '수완동',
#  '노대동': '지산동',
#  '농성동': '동명동',
#  '누문동': '양촌동',
#  '대산동': '월계동',
#  '대의동': '도호동',
#  '대인동': '월전동',
#  '대지동': '학동',
#  '대촌동': '송하동',
#  '덕남동': '광천동',
#  '덕림동': '양산동',
#  '덕의동': '화장동',
#  '덕흥동': '수기동',
#  '도금동': '내방동',
#  '도덕동': '장등동',
#  '도산동': '신용동',
#  '도천동': '하산동',
#  '도호동': '용두동',
#  '동림동': '흑석동',
#  '동림동.1': '왕동',
#  '동명동': '송산동',
#  '동산동': '일곡동',
#  '동천동': '삼도동',
#  '동호동': '장수동',
#  '두암동': '유동',
#  '두정동': '운암동',
#  '등임동': '덕의동',
#  '마륵동': '광산동',
#  '망월동': '대지동',
#  '매곡동': '지산동',
#  '매월동': '양동',
#  '명도동': '안청동',
#  '명화동': '태령동',
#  '문흥동': '월산동',
#  '박호동': '지야동',
#  '방림동': '황금동',
#  '백운동': '동천동',
#  '벽진동': '송학동',
#  '복룡동': '중흥동',
#  '본덕동': '신촌동',
#  '본촌동': '임암동',
#  '봉선동': '내남동',
#  '북동': '방림동',
#  '북산동': '운남동',
#  '불로동': '동산동',
#  '비아동': '두정동',
#  '사동': '벽진동',
#  '사호동': '선암동',
#  '산막동': '우산동',
#  '산수동': '대촌동',
#  '산수동.1': '도덕동',
#  '산월동': '용전동',
#  '산정동': '각화동',
#  '삼각동': '내산동',
#  '삼거동': '북산동',
#  '삼도동': '신창동',
#  '생용동': '노대동',
#  '서동': '용두동',
#  '서봉동': '고룡동',
#  '서석동': '명도동',
#  '서창동': '신동',
#  '석정동': '금동',
#  '선교동': '장록동',
#  '선동': '오룡동',
#  '선암동': '월곡동',
#  '세하동': '삼거동',
#  '소촌동': '연제동',
#  '소태동': '본덕동',
#  '송대동': '신안동',
#  '송산동': '황룡동',
#  '송정동': '운정동',
#  '송촌동': '청풍동',
#  '송치동': '쌍암동',
#  '송하동': '운림동',
#  '송학동': '비아동',
#  '수곡동': '진월동',
#  '수기동': '옥동',
#  '수완동': '유계동',
#  '승촌동': '서창동',
#  '신가동': '송정동',
#  '신동': '도천동',
#  '신룡동': '동림동',
#  '신안동': '봉선동',
#  '신용동': '누문동',
#  '신장동': '호남동',
#  '신창동': '용강동',
#  '신촌동': '양산동',
#  '쌍암동': '월출동',
#  '쌍촌동': '대인동',
#  '안청동': '용봉동',
#  '압촌동': '소태동',
#  '양과동': '유촌동',
#  '양동': '궁동',
#  '양동.1': '우산동',
#  '양림동': '덕흥동',
#  '양산동': '산정동',
#  '양산동.1': '송치동',
#  '양촌동': '치평동',
#  '연산동': '사호동',
#  '연제동': '덕림동',
#  '오룡동': '매월동',
#  '오산동': '운수동',
#  '오선동': '하남동',
#  '오운동': '박호동',
#  '오치동': '지석동',
#  '옥동': '삼각동',
#  '왕동': '장덕동',
#  '요기동': '오산동',
#  '용강동': '주월동',
#  '용곡동': '망월동',
#  '용동': '금곡동',
#  '용두동': '산수동',
#  '용두동.1': '백운동',
#  '용봉동': '석정동',
#  '용봉동.1': '서봉동',
#  '용산동': '지평동',
#  '용연동': '용봉동',
#  '용전동': '압촌동',
#  '우산동': '월성동',
#  '우산동.1': '수곡동',
#  '운남동': '도산동',
#  '운림동': '명화동',
#  '운수동': '산막동',
#  '운암동': '동림동',
#  '운정동': '마륵동',
#  '원산동': '월남동',
#  '월계동': '생용동',
#  '월곡동': '충효동',
#  '월남동': '복룡동',
#  '월산동': '풍암동',
#  '월성동': '농성동',
#  '월전동': '임곡동',
#  '월출동': '도금동',
#  '유계동': '산월동',
#  '유동': '구소동',
#  '유촌동': '남산동',
#  '이장동': '용연동',
#  '일곡동': '동호동',
#  '임곡동': '두암동',
#  '임동': '양림동',
#  '임암동': '양동',
#  '장덕동': '임동',
#  '장동': '용곡동',
#  '장등동': '사동',
#  '장록동': '매곡동',
#  '장수동': '문흥동',
#  '주월동': '선교동',
#  '중흥동': '이장동',
#  '지산동': '진곡동',
#  '지산동.1': '송대동',
#  '지석동': '서석동',
#  '지야동': '구동',
#  '지정동': '본촌동',
#  '지죽동': '화암동',
#  '지평동': '소촌동',
#  '진곡동': '북동',
#  '진월동': '불로동',
#  '청풍동': '원산동',
#  '충장동': '오선동',
#  '충효동': '신장동',
#  '치평동': '남동',
#  '칠석동': '화정동',
#  '태령동': '서동',
#  '풍암동': '대산동',
#  '풍향동': '행암동',
#  '하남동': '등임동',
#  '하산동': '광산동',
#  '학동': '지정동',
#  '행암동': '용산동',
#  '호남동': '지죽동',
#  '화암동': '양과동',
#  '화장동': '쌍촌동',
#  '화정동': '계림동',
#  '황금동': '연산동',
#  '황룡동': '효령동',
#  '효령동': '덕남동',
#  '흑석동': '신룡동'}

# %%
D = {}
for i in range(0, 194): # 딕셔너리 형태로 한 동당 거리행렬 정의
    D[i] = dict(zip(location[i:], [dict(zip(location, list(final.iloc[i+1,1:])))]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-e3fa45c00154> in <module>()
#       1 D = {}
#       2 for i in range(0, 194): # 딕셔너리 형태로 한 동당 거리행렬 정의
# ----> 3     D[i] = dict(zip(location[i:], [dict(zip(location, list(final.iloc[i+1,1:])))]))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     752         for i, k in enumerate(key):
#     753             try:
# --> 754                 self._validate_key(k, i)
#     755             except ValueError as err:
#     756                 raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1407             return
#    1408         elif is_integer(key):
# -> 1409             self._validate_integer(key, axis)
#    1410         elif isinstance(key, tuple):
#    1411             # a tuple should already have been caught by this point
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
merged = {}
for i in range(0, 97):
    merged = {**merged, **D[i]} # 424 + 424 거리행렬 정의

# %%
p = 26 # 임시선별검사소 수 정의

# %%
# P-Median 모델을 통해 최적지 선정하는 코드
X = LpVariable.dicts('X_%s_%s', (location, location), cat = 'Binary',
                     lowBound = 0,
                     upBound = 1)

# %%
prob = LpProblem('P Median', LpMinimize) # 목적 함수
# Out:
# /usr/local/lib/python3.7/dist-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
prob += sum(sum(a[i]*distance_matrix[i][j] * X[i][j] for j in location)for i in location)
prob += sum(X[i][i] for i in location) == p
# Out:
# /usr/local/lib/python3.7/dist-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-bf1ead3e0e1f> in <module>()
#       1 prob = LpProblem('P Median', LpMinimize) # 목적 함수
# ----> 2 prob += sum(sum(a[i]*distance_matrix[i][j] * X[i][j] for j in location)for i in location)
#       3 prob += sum(X[i][i] for i in location) == p
#
# <ipython-input-113-bf1ead3e0e1f> in <genexpr>(.0)
#       1 prob = LpProblem('P Median', LpMinimize) # 목적 함수
# ----> 2 prob += sum(sum(a[i]*distance_matrix[i][j] * X[i][j] for j in location)for i in location)
#       3 prob += sum(X[i][i] for i in location) == p
#
# <ipython-input-113-bf1ead3e0e1f> in <genexpr>(.0)
#       1 prob = LpProblem('P Median', LpMinimize) # 목적 함수
# ----> 2 prob += sum(sum(a[i]*distance_matrix[i][j] * X[i][j] for j in location)for i in location)
#       3 prob += sum(X[i][i] for i in location) == p
#
# KeyError: 'ID'

# %%
for i in location: prob += sum(X[i][j] for j in location) == 1 # 제약식
for i in location:
    for j in location: prob += X[i][j] <= X[j][j]

# %%
prob.writeLP("p-median_Seoul_Whole.lp")
prob.solve()

# %%
# distance_matrix = pd.read_excel('C:/Users/user/Downloads/광주광역시_읍면동_거리행렬.xlsx', usecols = 'B : GM')
# pop = pd.read_excel('C:/Users/user/Downloads/주민등록인구_20220804102055.xlsx', usecols = 'C')

pop_final = list(pop.iloc[0:97, 0])
final = distance_matrix[1:194] # 데이터 전처리 완료

region_name = final.iloc[0, 1:]
region_name_final = list(region_name)
location = region_name_final # 동 이름 전처리

a = dict(zip(location, pop_final))

D = {}
for i in range(0, 424): # 딕셔너리 형태로 한 동당 거리행렬 정의
    D[i] = dict(zip(location[i:], [dict(zip(location, list(final.iloc[i+1,1:])))]))
    
merged = {}
for i in range(0, 424):
    merged = {**merged, **D[i]} # 424 + 424 거리행렬 정의

p = 26 # 임시선별검사소 수 정의

# P-Median 모델을 통해 최적지 선정하는 코드
X = LpVariable.dicts('X_%s_%s', (location, location), cat = 'Binary',
                     lowBound = 0,
                     upBound = 1)

prob = LpProblem('P Median', LpMinimize) # 목적 함수
prob += sum(sum(a[i]*merged[i][j] * X[i][j] for j in location)for i in location)
prob += sum(X[i][i] for i in location) == p

for i in location: prob += sum(X[i][j] for j in location) == 1 # 제약식
for i in location:
    for j in location: prob += X[i][j] <= X[j][j]

prob.writeLP("p-median_Seoul_Whole.lp")
prob.solve()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-05c1a49cfcef> in <module>()
#      13 D = {}
#      14 for i in range(0, 424): # 딕셔너리 형태로 한 동당 거리행렬 정의
# ---> 15     D[i] = dict(zip(location[i:], [dict(zip(location, list(final.iloc[i+1,1:])))]))
#      16
#      17 merged = {}
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     752         for i, k in enumerate(key):
#     753             try:
# --> 754                 self._validate_key(k, i)
#     755             except ValueError as err:
#     756                 raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1407             return
#    1408         elif is_integer(key):
# -> 1409             self._validate_integer(key, axis)
#    1410         elif isinstance(key, tuple):
#    1411             # a tuple should already have been caught by this point
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# # p-median 알고리즘 논문

# %%
location = distance_matrix.columns

# %%
D = distance_matrix

# %%
p = 26

# %%
X = LpVariable.dicts('%s_%s', (location, location), cat = 'Binary', lowBound = 0, upBound = 1)
prob = LpProblem('P Median', LpMinimize)
# Out:
# /usr/local/lib/python3.7/dist-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
LpVariable
# Out:
# {'각화동': {'각화동': 각화동_각화동,
#   '계림동': 각화동_계림동,
#   '고룡동': 각화동_고룡동,
#   '광산동': 각화동_광산동,
#   '광산동.1': 각화동_광산동.1,
#   '광천동': 각화동_광천동,
#   '구동': 각화동_구동,
#   '구소동': 각화동_구소동,
#   '궁동': 각화동_궁동,
#   '금곡동': 각화동_금곡동,
#   '금동': 각화동_금동,
#   '금호동': 각화동_금호동,
#   '남동': 각화동_남동,
#   '남산동': 각화동_남산동,
#   '내남동': 각화동_내남동,
#   '내방동': 각화동_내방동,
#   '내산동': 각화동_내산동,
#   '노대동': 각화동_노대동,
#   '농성동': 각화동_농성동,
#   '누문동': 각화동_누문동,
#   '대산동': 각화동_대산동,
#   '대의동': 각화동_대의동,
#   '대인동': 각화동_대인동,
#   '대지동': 각화동_대지동,
#   '대촌동': 각화동_대촌동,
#   '덕남동': 각화동_덕남동,
#   '덕림동': 각화동_덕림동,
#   '덕의동': 각화동_덕의동,
#   '덕흥동': 각화동_덕흥동,
#   '도금동': 각화동_도금동,
#   '도덕동': 각화동_도덕동,
#   '도산동': 각화동_도산동,
#   '도천동': 각화동_도천동,
#   '도호동': 각화동_도호동,
#   '동림동': 각화동_동림동,
#   '동림동.1': 각화동_동림동.1,
#   '동명동': 각화동_동명동,
#   '동산동': 각화동_동산동,
#   '동천동': 각화동_동천동,
#   '동호동': 각화동_동호동,
#   '두암동': 각화동_두암동,
#   '두정동': 각화동_두정동,
#   '등임동': 각화동_등임동,
#   '마륵동': 각화동_마륵동,
#   '망월동': 각화동_망월동,
#   '매곡동': 각화동_매곡동,
#   '매월동': 각화동_매월동,
#   '명도동': 각화동_명도동,
#   '명화동': 각화동_명화동,
#   '문흥동': 각화동_문흥동,
#   '박호동': 각화동_박호동,
#   '방림동': 각화동_방림동,
#   '백운동': 각화동_백운동,
#   '벽진동': 각화동_벽진동,
#   '복룡동': 각화동_복룡동,
#   '본덕동': 각화동_본덕동,
#   '본촌동': 각화동_본촌동,
#   '봉선동': 각화동_봉선동,
#   '북동': 각화동_북동,
#   '북산동': 각화동_북산동,
#   '불로동': 각화동_불로동,
#   '비아동': 각화동_비아동,
#   '사동': 각화동_사동,
#   '사호동': 각화동_사호동,
#   '산막동': 각화동_산막동,
#   '산수동': 각화동_산수동,
#   '산수동.1': 각화동_산수동.1,
#   '산월동': 각화동_산월동,
#   '산정동': 각화동_산정동,
#   '삼각동': 각화동_삼각동,
#   '삼거동': 각화동_삼거동,
#   '삼도동': 각화동_삼도동,
#   '생용동': 각화동_생용동,
#   '서동': 각화동_서동,
#   '서봉동': 각화동_서봉동,
#   '서석동': 각화동_서석동,
#   '서창동': 각화동_서창동,
#   '석정동': 각화동_석정동,
#   '선교동': 각화동_선교동,
#   '선동': 각화동_선동,
#   '선암동': 각화동_선암동,
#   '세하동': 각화동_세하동,
#   '소촌동': 각화동_소촌동,
#   '소태동': 각화동_소태동,
#   '송대동': 각화동_송대동,
#   '송산동': 각화동_송산동,
#   '송정동': 각화동_송정동,
#   '송촌동': 각화동_송촌동,
#   '송치동': 각화동_송치동,
#   '송하동': 각화동_송하동,
#   '송학동': 각화동_송학동,
#   '수곡동': 각화동_수곡동,
#   '수기동': 각화동_수기동,
#   '수완동': 각화동_수완동,
#   '승촌동': 각화동_승촌동,
#   '신가동': 각화동_신가동,
#   '신동': 각화동_신동,
#   '신룡동': 각화동_신룡동,
#   '신안동': 각화동_신안동,
#   '신용동': 각화동_신용동,
#   '신장동': 각화동_신장동,
#   '신창동': 각화동_신창동,
#   '신촌동': 각화동_신촌동,
#   '쌍암동': 각화동_쌍암동,
#   '쌍촌동': 각화동_쌍촌동,
#   '안청동': 각화동_안청동,
#   '압촌동': 각화동_압촌동,
#   '양과동': 각화동_양과동,
#   '양동': 각화동_양동,
#   '양동.1': 각화동_양동.1,
#   '양림동': 각화동_양림동,
#   '양산동': 각화동_양산동,
#   '양산동.1': 각화동_양산동.1,
#   '양촌동': 각화동_양촌동,
#   '연산동': 각화동_연산동,
#   '연제동': 각화동_연제동,
#   '오룡동': 각화동_오룡동,
#   '오산동': 각화동_오산동,
#   '오선동': 각화동_오선동,
#   '오운동': 각화동_오운동,
#   '오치동': 각화동_오치동,
#   '옥동': 각화동_옥동,
#   '왕동': 각화동_왕동,
#   '요기동': 각화동_요기동,
#   '용강동': 각화동_용강동,
#   '용곡동': 각화동_용곡동,
#   '용동': 각화동_용동,
#   '용두동': 각화동_용두동,
#   '용두동.1': 각화동_용두동.1,
#   '용봉동': 각화동_용봉동,
#   '용봉동.1': 각화동_용봉동.1,
#   '용산동': 각화동_용산동,
#   '용연동': 각화동_용연동,
#   '용전동': 각화동_용전동,
#   '우산동': 각화동_우산동,
#   '우산동.1': 각화동_우산동.1,
#   '운남동': 각화동_운남동,
#   '운림동': 각화동_운림동,
#   '운수동': 각화동_운수동,
#   '운암동': 각화동_운암동,
#   '운정동': 각화동_운정동,
#   '원산동': 각화동_원산동,
#   '월계동': 각화동_월계동,
#   '월곡동': 각화동_월곡동,
#   '월남동': 각화동_월남동,
#   '월산동': 각화동_월산동,
#   '월성동': 각화동_월성동,
#   '월전동': 각화동_월전동,
#   '월출동': 각화동_월출동,
#   '유계동': 각화동_유계동,
#   '유동': 각화동_유동,
#   '유촌동': 각화동_유촌동,
#   '이장동': 각화동_이장동,
#   '일곡동': 각화동_일곡동,
#   '임곡동': 각화동_임곡동,
#   '임동': 각화동_임동,
#   '임암동': 각화동_임암동,
#   '장덕동': 각화동_장덕동,
#   '장동': 각화동_장동,
#   '장등동': 각화동_장등동,
#   '장록동': 각화동_장록동,
#   '장수동': 각화동_장수동,
#   '주월동': 각화동_주월동,
#   '중흥동': 각화동_중흥동,
#   '지산동': 각화동_지산동,
#   '지산동.1': 각화동_지산동.1,
#   '지석동': 각화동_지석동,
#   '지야동': 각화동_지야동,
#   '지정동': 각화동_지정동,
#   '지죽동': 각화동_지죽동,
#   '지평동': 각화동_지평동,
#   '진곡동': 각화동_진곡동,
#   '진월동': 각화동_진월동,
#   '청풍동': 각화동_청풍동,
#   '충장동': 각화동_충장동,
#   '충효동': 각화동_충효동,
#   '치평동': 각화동_치평동,
#   '칠석동': 각화동_칠석동,
#   '태령동': 각화동_태령동,
#   '풍암동': 각화동_풍암동,
#   '풍향동': 각화동_풍향동,
#   '하남동': 각화동_하남동,
#   '하산동': 각화동_하산동,
#   '학동': 각화동_학동,
#   '행암동': 각화동_행암동,
#   '호남동': 각화동_호남동,
#   '화암동': 각화동_화암동,
#   '화장동': 각화동_화장동,
#   '화정동': 각화동_화정동,
#   '황금동': 각화동_황금동,
#   '황룡동': 각화동_황룡동,
#   '효령동': 각화동_효령동,
#   '흑석동': 각화동_흑석동},
#  '계림동': {'각화동': 계림동_각화동,
#   '계림동': 계림동_계림동,
#   '고룡동': 계림동_고룡동,
#   '광산동': 계림동_광산동,
#   '광산동.1': 계림동_광산동.1,
#   '광천동': 계림동_광천동,
#   '구동': 계림동_구동,
#   '구소동': 계림동_구소동,
#   '궁동': 계림동_궁동,
#   '금곡동': 계림동_금곡동,
#   '금동': 계림동_금동,
#   '금호동': 계림동_금호동,
#   '남동': 계림동_남동,
#   '남산동': 계림동_남산동,
#   '내남동': 계림동_내남동,
#   '내방동': 계림동_내방동,
#   '내산동': 계림동_내산동,
#   '노대동': 계림동_노대동,
#   '농성동': 계림동_농성동,
#   '누문동': 계림동_누문동,
#   '대산동': 계림동_대산동,
#   '대의동': 계림동_대의동,
#   '대인동': 계림동_대인동,
#   '대지동': 계림동_대지동,
#   '대촌동': 계림동_대촌동,
#   '덕남동': 계림동_덕남동,
#   '덕림동': 계림동_덕림동,
#   '덕의동': 계림동_덕의동,
#   '덕흥동': 계림동_덕흥동,
#   '도금동': 계림동_도금동,
#   '도덕동': 계림동_도덕동,
#   '도산동': 계림동_도산동,
#   '도천동': 계림동_도천동,
#   '도호동': 계림동_도호동,
#   '동림동': 계림동_동림동,
#   '동림동.1': 계림동_동림동.1,
#   '동명동': 계림동_동명동,
#   '동산동': 계림동_동산동,
#   '동천동': 계림동_동천동,
#   '동호동': 계림동_동호동,
#   '두암동': 계림동_두암동,
#   '두정동': 계림동_두정동,
#   '등임동': 계림동_등임동,
#   '마륵동': 계림동_마륵동,
#   '망월동': 계림동_망월동,
#   '매곡동': 계림동_매곡동,
#   '매월동': 계림동_매월동,
#   '명도동': 계림동_명도동,
#   '명화동': 계림동_명화동,
#   '문흥동': 계림동_문흥동,
#   '박호동': 계림동_박호동,
#   '방림동': 계림동_방림동,
#   '백운동': 계림동_백운동,
#   '벽진동': 계림동_벽진동,
#   '복룡동': 계림동_복룡동,
#   '본덕동': 계림동_본덕동,
#   '본촌동': 계림동_본촌동,
#   '봉선동': 계림동_봉선동,
#   '북동': 계림동_북동,
#   '북산동': 계림동_북산동,
#   '불로동': 계림동_불로동,
#   '비아동': 계림동_비아동,
#   '사동': 계림동_사동,
#   '사호동': 계림동_사호동,
#   '산막동': 계림동_산막동,
#   '산수동': 계림동_산수동,
#   '산수동.1': 계림동_산수동.1,
#   '산월동': 계림동_산월동,
#   '산정동': 계림동_산정동,
#   '삼각동': 계림동_삼각동,
#   '삼거동': 계림동_삼거동,
#   '삼도동': 계림동_삼도동,
#   '생용동': 계림동_생용동,
#   '서동': 계림동_서동,
#   '서봉동': 계림동_서봉동,
#   '서석동': 계림동_서석동,
#   '서창동': 계림동_서창동,
#   '석정동': 계림동_석정동,
#   '선교동': 계림동_선교동,
#   '선동': 계림동_선동,
#   '선암동': 계림동_선암동,
#   '세하동': 계림동_세하동,
#   '소촌동': 계림동_소촌동,
#   '소태동': 계림동_소태동,
#   '송대동': 계림동_송대동,
#   '송산동': 계림동_송산동,
#   '송정동': 계림동_송정동,
#   '송촌동': 계림동_송촌동,
#   '송치동': 계림동_송치동,
#   '송하동': 계림동_송하동,
#   '송학동': 계림동_송학동,
#   '수곡동': 계림동_수곡동,
#   '수기동': 계림동_수기동,
#   '수완동': 계림동_수완동,
#   '승촌동': 계림동_승촌동,
#   '신가동': 계림동_신가동,
#   '신동': 계림동_신동,
#   '신룡동': 계림동_신룡동,
#   '신안동': 계림동_신안동,
#   '신용동': 계림동_신용동,
#   '신장동': 계림동_신장동,
#   '신창동': 계림동_신창동,
#   '신촌동': 계림동_신촌동,
#   '쌍암동': 계림동_쌍암동,
#   '쌍촌동': 계림동_쌍촌동,
#   '안청동': 계림동_안청동,
#   '압촌동': 계림동_압촌동,
#   '양과동': 계림동_양과동,
#   '양동': 계림동_양동,
#   '양동.1': 계림동_양동.1,
#   '양림동': 계림동_양림동,
#   '양산동': 계림동_양산동,
#   '양산동.1': 계림동_양산동.1,
#   '양촌동': 계림동_양촌동,
#   '연산동': 계림동_연산동,
#   '연제동': 계림동_연제동,
#   '오룡동': 계림동_오룡동,
#   '오산동': 계림동_오산동,
#   '오선동': 계림동_오선동,
#   '오운동': 계림동_오운동,
#   '오치동': 계림동_오치동,
#   '옥동': 계림동_옥동,
#   '왕동': 계림동_왕동,
#   '요기동': 계림동_요기동,
#   '용강동': 계림동_용강동,
#   '용곡동': 계림동_용곡동,
#   '용동': 계림동_용동,
#   '용두동': 계림동_용두동,
#   '용두동.1': 계림동_용두동.1,
#   '용봉동': 계림동_용봉동,
#   '용봉동.1': 계림동_용봉동.1,
#   '용산동': 계림동_용산동,
#   '용연동': 계림동_용연동,
#   '용전동': 계림동_용전동,
#   '우산동': 계림동_우산동,
#   '우산동.1': 계림동_우산동.1,
#   '운남동': 계림동_운남동,
#   '운림동': 계림동_운림동,
#   '운수동': 계림동_운수동,
#   '운암동': 계림동_운암동,
#   '운정동': 계림동_운정동,
#   '원산동': 계림동_원산동,
#   '월계동': 계림동_월계동,
#   '월곡동': 계림동_월곡동,
#   '월남동': 계림동_월남동,
#   '월산동': 계림동_월산동,
#   '월성동': 계림동_월성동,
#   '월전동': 계림동_월전동,
#   '월출동': 계림동_월출동,
#   '유계동': 계림동_유계동,
#   '유동': 계림동_유동,
#   '유촌동': 계림동_유촌동,
#   '이장동': 계림동_이장동,
#   '일곡동': 계림동_일곡동,
#   '임곡동': 계림동_임곡동,
#   '임동': 계림동_임동,
#   '임암동': 계림동_임암동,
#   '장덕동': 계림동_장덕동,
#   '장동': 계림동_장동,
#   '장등동': 계림동_장등동,
#   '장록동': 계림동_장록동,
#   '장수동': 계림동_장수동,
#   '주월동': 계림동_주월동,
#   '중흥동': 계림동_중흥동,
#   '지산동': 계림동_지산동,
#   '지산동.1': 계림동_지산동.1,
#   '지석동': 계림동_지석동,
#   '지야동': 계림동_지야동,
#   '지정동': 계림동_지정동,
#   '지죽동': 계림동_지죽동,
#   '지평동': 계림동_지평동,
#   '진곡동': 계림동_진곡동,
#   '진월동': 계림동_진월동,
#   '청풍동': 계림동_청풍동,
#   '충장동': 계림동_충장동,
#   '충효동': 계림동_충효동,
#   '치평동': 계림동_치평동,
#   '칠석동': 계림동_칠석동,
#   '태령동': 계림동_태령동,
#   '풍암동': 계림동_풍암동,
#   '풍향동': 계림동_풍향동,
#   '하남동': 계림동_하남동,
#   '하산동': 계림동_하산동,
#   '학동': 계림동_학동,
#   '행암동': 계림동_행암동,
#   '호남동': 계림동_호남동,
#   '화암동': 계림동_화암동,
#   '화장동': 계림동_화장동,
#   '화정동': 계림동_화정동,
#   '황금동': 계림동_황금동,
#   '황룡동': 계림동_황룡동,
#   '효령동': 계림동_효령동,
#   '흑석동': 계림동_흑석동},
#  '고룡동': {'각화동': 고룡동_각화동,
#   '계림동': 고룡동_계림동,
#   '고룡동': 고룡동_고룡동,
#   '광산동': 고룡동_광산동,
#   '광산동.1': 고룡동_광산동.1,
#   '광천동': 고룡동_광천동,
#   '구동': 고룡동_구동,
#   '구소동': 고룡동_구소동,
#   '궁동': 고룡동_궁동,
#   '금곡동': 고룡동_금곡동,
#   '금동': 고룡동_금동,
#   '금호동': 고룡동_금호동,
#   '남동': 고룡동_남동,
#   '남산동': 고룡동_남산동,
#   '내남동': 고룡동_내남동,
#   '내방동': 고룡동_내방동,
#   '내산동': 고룡동_내산동,
#   '노대동': 고룡동_노대동,
#   '농성동': 고룡동_농성동,
#   '누문동': 고룡동_누문동,
#   '대산동': 고룡동_대산동,
#   '대의동': 고룡동_대의동,
#   '대인동': 고룡동_대인동,
#   '대지동': 고룡동_대지동,
#   '대촌동': 고룡동_대촌동,
#   '덕남동': 고룡동_덕남동,
#   '덕림동': 고룡동_덕림동,
#   '덕의동': 고룡동_덕의동,
#   '덕흥동': 고룡동_덕흥동,
#   '도금동': 고룡동_도금동,
#   '도덕동': 고룡동_도덕동,
#   '도산동': 고룡동_도산동,
#   '도천동': 고룡동_도천동,
#   '도호동': 고룡동_도호동,
#   '동림동': 고룡동_동림동,
#   '동림동.1': 고룡동_동림동.1,
#   '동명동': 고룡동_동명동,
#   '동산동': 고룡동_동산동,
#   '동천동': 고룡동_동천동,
#   '동호동': 고룡동_동호동,
#   '두암동': 고룡동_두암동,
#   '두정동': 고룡동_두정동,
#   '등임동': 고룡동_등임동,
#   '마륵동': 고룡동_마륵동,
#   '망월동': 고룡동_망월동,
#   '매곡동': 고룡동_매곡동,
#   '매월동': 고룡동_매월동,
#   '명도동': 고룡동_명도동,
#   '명화동': 고룡동_명화동,
#   '문흥동': 고룡동_문흥동,
#   '박호동': 고룡동_박호동,
#   '방림동': 고룡동_방림동,
#   '백운동': 고룡동_백운동,
#   '벽진동': 고룡동_벽진동,
#   '복룡동': 고룡동_복룡동,
#   '본덕동': 고룡동_본덕동,
#   '본촌동': 고룡동_본촌동,
#   '봉선동': 고룡동_봉선동,
#   '북동': 고룡동_북동,
#   '북산동': 고룡동_북산동,
#   '불로동': 고룡동_불로동,
#   '비아동': 고룡동_비아동,
#   '사동': 고룡동_사동,
#   '사호동': 고룡동_사호동,
#   '산막동': 고룡동_산막동,
#   '산수동': 고룡동_산수동,
#   '산수동.1': 고룡동_산수동.1,
#   '산월동': 고룡동_산월동,
#   '산정동': 고룡동_산정동,
#   '삼각동': 고룡동_삼각동,
#   '삼거동': 고룡동_삼거동,
#   '삼도동': 고룡동_삼도동,
#   '생용동': 고룡동_생용동,
#   '서동': 고룡동_서동,
#   '서봉동': 고룡동_서봉동,
#   '서석동': 고룡동_서석동,
#   '서창동': 고룡동_서창동,
#   '석정동': 고룡동_석정동,
#   '선교동': 고룡동_선교동,
#   '선동': 고룡동_선동,
#   '선암동': 고룡동_선암동,
#   '세하동': 고룡동_세하동,
#   '소촌동': 고룡동_소촌동,
#   '소태동': 고룡동_소태동,
#   '송대동': 고룡동_송대동,
#   '송산동': 고룡동_송산동,
#   '송정동': 고룡동_송정동,
#   '송촌동': 고룡동_송촌동,
#   '송치동': 고룡동_송치동,
#   '송하동': 고룡동_송하동,
#   '송학동': 고룡동_송학동,
#   '수곡동': 고룡동_수곡동,
#   '수기동': 고룡동_수기동,
#   '수완동': 고룡동_수완동,
#   '승촌동': 고룡동_승촌동,
#   '신가동': 고룡동_신가동,
#   '신동': 고룡동_신동,
#   '신룡동': 고룡동_신룡동,
#   '신안동': 고룡동_신안동,
#   '신용동': 고룡동_신용동,
#   '신장동': 고룡동_신장동,
#   '신창동': 고룡동_신창동,
#   '신촌동': 고룡동_신촌동,
#   '쌍암동': 고룡동_쌍암동,
#   '쌍촌동': 고룡동_쌍촌동,
#   '안청동': 고룡동_안청동,
#   '압촌동': 고룡동_압촌동,
#   '양과동': 고룡동_양과동,
#   '양동': 고룡동_양동,
#   '양동.1': 고룡동_양동.1,
#   '양림동': 고룡동_양림동,
#   '양산동': 고룡동_양산동,
#   '양산동.1': 고룡동_양산동.1,
#   '양촌동': 고룡동_양촌동,
#   '연산동': 고룡동_연산동,
#   '연제동': 고룡동_연제동,
#   '오룡동': 고룡동_오룡동,
#   '오산동': 고룡동_오산동,
#   '오선동': 고룡동_오선동,
#   '오운동': 고룡동_오운동,
#   '오치동': 고룡동_오치동,
#   '옥동': 고룡동_옥동,
#   '왕동': 고룡동_왕동,
#   '요기동': 고룡동_요기동,
#   '용강동': 고룡동_용강동,
#   '용곡동': 고룡동_용곡동,
#   '용동': 고룡동_용동,
#   '용두동': 고룡동_용두동,
#   '용두동.1': 고룡동_용두동.1,
#   '용봉동': 고룡동_용봉동,
#   '용봉동.1': 고룡동_용봉동.1,
#   '용산동': 고룡동_용산동,
#   '용연동': 고룡동_용연동,
#   '용전동': 고룡동_용전동,
#   '우산동': 고룡동_우산동,
#   '우산동.1': 고룡동_우산동.1,
#   '운남동': 고룡동_운남동,
#   '운림동': 고룡동_운림동,
#   '운수동': 고룡동_운수동,
#   '운암동': 고룡동_운암동,
#   '운정동': 고룡동_운정동,
#   '원산동': 고룡동_원산동,
#   '월계동': 고룡동_월계동,
#   '월곡동': 고룡동_월곡동,
#   '월남동': 고룡동_월남동,
#   '월산동': 고룡동_월산동,
#   '월성동': 고룡동_월성동,
#   '월전동': 고룡동_월전동,
#   '월출동': 고룡동_월출동,
#   '유계동': 고룡동_유계동,
#   '유동': 고룡동_유동,
#   '유촌동': 고룡동_유촌동,
#   '이장동': 고룡동_이장동,
#   '일곡동': 고룡동_일곡동,
#   '임곡동': 고룡동_임곡동,
#   '임동': 고룡동_임동,
#   '임암동': 고룡동_임암동,
#   '장덕동': 고룡동_장덕동,
#   '장동': 고룡동_장동,
#   '장등동': 고룡동_장등동,
#   '장록동': 고룡동_장록동,
#   '장수동': 고룡동_장수동,
#   '주월동': 고룡동_주월동,
#   '중흥동': 고룡동_중흥동,
#   '지산동': 고룡동_지산동,
#   '지산동.1': 고룡동_지산동.1,
#   '지석동': 고룡동_지석동,
#   '지야동': 고룡동_지야동,
#   '지정동': 고룡동_지정동,
#   '지죽동': 고룡동_지죽동,
#   '지평동': 고룡동_지평동,
#   '진곡동': 고룡동_진곡동,
#   '진월동': 고룡동_진월동,
#   '청풍동': 고룡동_청풍동,
#   '충장동': 고룡동_충장동,
#   '충효동': 고룡동_충효동,
#   '치평동': 고룡동_치평동,
#   '칠석동': 고룡동_칠석동,
#   '태령동': 고룡동_태령동,
#   '풍암동': 고룡동_풍암동,
#   '풍향동': 고룡동_풍향동,
#   '하남동': 고룡동_하남동,
#   '하산동': 고룡동_하산동,
#   '학동': 고룡동_학동,
#   '행암동': 고룡동_행암동,
#   '호남동': 고룡동_호남동,
#   '화암동': 고룡동_화암동,
#   '화장동': 고룡동_화장동,
#   '화정동': 고룡동_화정동,
#   '황금동': 고룡동_황금동,
#   '황룡동': 고룡동_황룡동,
#   '효령동': 고룡동_효령동,
#   '흑석동': 고룡동_흑석동},
#  '광산동': {'각화동': 광산동_각화동,
#   '계림동': 광산동_계림동,
#   '고룡동': 광산동_고룡동,
#   '광산동': 광산동_광산동,
#   '광산동.1': 광산동_광산동.1,
#   '광천동': 광산동_광천동,
#   '구동': 광산동_구동,
#   '구소동': 광산동_구소동,
#   '궁동': 광산동_궁동,
#   '금곡동': 광산동_금곡동,
#   '금동': 광산동_금동,
#   '금호동': 광산동_금호동,
#   '남동': 광산동_남동,
#   '남산동': 광산동_남산동,
#   '내남동': 광산동_내남동,
#   '내방동': 광산동_내방동,
#   '내산동': 광산동_내산동,
#   '노대동': 광산동_노대동,
#   '농성동': 광산동_농성동,
#   '누문동': 광산동_누문동,
#   '대산동': 광산동_대산동,
#   '대의동': 광산동_대의동,
#   '대인동': 광산동_대인동,
#   '대지동': 광산동_대지동,
#   '대촌동': 광산동_대촌동,
#   '덕남동': 광산동_덕남동,
#   '덕림동': 광산동_덕림동,
#   '덕의동': 광산동_덕의동,
#   '덕흥동': 광산동_덕흥동,
#   '도금동': 광산동_도금동,
#   '도덕동': 광산동_도덕동,
#   '도산동': 광산동_도산동,
#   '도천동': 광산동_도천동,
#   '도호동': 광산동_도호동,
#   '동림동': 광산동_동림동,
#   '동림동.1': 광산동_동림동.1,
#   '동명동': 광산동_동명동,
#   '동산동': 광산동_동산동,
#   '동천동': 광산동_동천동,
#   '동호동': 광산동_동호동,
#   '두암동': 광산동_두암동,
#   '두정동': 광산동_두정동,
#   '등임동': 광산동_등임동,
#   '마륵동': 광산동_마륵동,
#   '망월동': 광산동_망월동,
#   '매곡동': 광산동_매곡동,
#   '매월동': 광산동_매월동,
#   '명도동': 광산동_명도동,
#   '명화동': 광산동_명화동,
#   '문흥동': 광산동_문흥동,
#   '박호동': 광산동_박호동,
#   '방림동': 광산동_방림동,
#   '백운동': 광산동_백운동,
#   '벽진동': 광산동_벽진동,
#   '복룡동': 광산동_복룡동,
#   '본덕동': 광산동_본덕동,
#   '본촌동': 광산동_본촌동,
#   '봉선동': 광산동_봉선동,
#   '북동': 광산동_북동,
#   '북산동': 광산동_북산동,
#   '불로동': 광산동_불로동,
#   '비아동': 광산동_비아동,
#   '사동': 광산동_사동,
#   '사호동': 광산동_사호동,
#   '산막동': 광산동_산막동,
#   '산수동': 광산동_산수동,
#   '산수동.1': 광산동_산수동.1,
#   '산월동': 광산동_산월동,
#   '산정동': 광산동_산정동,
#   '삼각동': 광산동_삼각동,
#   '삼거동': 광산동_삼거동,
#   '삼도동': 광산동_삼도동,
#   '생용동': 광산동_생용동,
#   '서동': 광산동_서동,
#   '서봉동': 광산동_서봉동,
#   '서석동': 광산동_서석동,
#   '서창동': 광산동_서창동,
#   '석정동': 광산동_석정동,
#   '선교동': 광산동_선교동,
#   '선동': 광산동_선동,
#   '선암동': 광산동_선암동,
#   '세하동': 광산동_세하동,
#   '소촌동': 광산동_소촌동,
#   '소태동': 광산동_소태동,
#   '송대동': 광산동_송대동,
#   '송산동': 광산동_송산동,
#   '송정동': 광산동_송정동,
#   '송촌동': 광산동_송촌동,
#   '송치동': 광산동_송치동,
#   '송하동': 광산동_송하동,
#   '송학동': 광산동_송학동,
#   '수곡동': 광산동_수곡동,
#   '수기동': 광산동_수기동,
#   '수완동': 광산동_수완동,
#   '승촌동': 광산동_승촌동,
#   '신가동': 광산동_신가동,
#   '신동': 광산동_신동,
#   '신룡동': 광산동_신룡동,
#   '신안동': 광산동_신안동,
#   '신용동': 광산동_신용동,
#   '신장동': 광산동_신장동,
#   '신창동': 광산동_신창동,
#   '신촌동': 광산동_신촌동,
#   '쌍암동': 광산동_쌍암동,
#   '쌍촌동': 광산동_쌍촌동,
#   '안청동': 광산동_안청동,
#   '압촌동': 광산동_압촌동,
#   '양과동': 광산동_양과동,
#   '양동': 광산동_양동,
#   '양동.1': 광산동_양동.1,
#   '양림동': 광산동_양림동,
#   '양산동': 광산동_양산동,
#   '양산동.1': 광산동_양산동.1,
#   '양촌동': 광산동_양촌동,
#   '연산동': 광산동_연산동,
#   '연제동': 광산동_연제동,
#   '오룡동': 광산동_오룡동,
#   '오산동': 광산동_오산동,
#   '오선동': 광산동_오선동,
#   '오운동': 광산동_오운동,
#   '오치동': 광산동_오치동,
#   '옥동': 광산동_옥동,
#   '왕동': 광산동_왕동,
#   '요기동': 광산동_요기동,
#   '용강동': 광산동_용강동,
#   '용곡동': 광산동_용곡동,
#   '용동': 광산동_용동,
#   '용두동': 광산동_용두동,
#   '용두동.1': 광산동_용두동.1,
#   '용봉동': 광산동_용봉동,
#   '용봉동.1': 광산동_용봉동.1,
#   '용산동': 광산동_용산동,
#   '용연동': 광산동_용연동,
#   '용전동': 광산동_용전동,
#   '우산동': 광산동_우산동,
#   '우산동.1': 광산동_우산동.1,
#   '운남동': 광산동_운남동,
#   '운림동': 광산동_운림동,
#   '운수동': 광산동_운수동,
#   '운암동': 광산동_운암동,
#   '운정동': 광산동_운정동,
#   '원산동': 광산동_원산동,
#   '월계동': 광산동_월계동,
#   '월곡동': 광산동_월곡동,
#   '월남동': 광산동_월남동,
#   '월산동': 광산동_월산동,
#   '월성동': 광산동_월성동,
#   '월전동': 광산동_월전동,
#   '월출동': 광산동_월출동,
#   '유계동': 광산동_유계동,
#   '유동': 광산동_유동,
#   '유촌동': 광산동_유촌동,
#   '이장동': 광산동_이장동,
#   '일곡동': 광산동_일곡동,
#   '임곡동': 광산동_임곡동,
#   '임동': 광산동_임동,
#   '임암동': 광산동_임암동,
#   '장덕동': 광산동_장덕동,
#   '장동': 광산동_장동,
#   '장등동': 광산동_장등동,
#   '장록동': 광산동_장록동,
#   '장수동': 광산동_장수동,
#   '주월동': 광산동_주월동,
#   '중흥동': 광산동_중흥동,
#   '지산동': 광산동_지산동,
#   '지산동.1': 광산동_지산동.1,
#   '지석동': 광산동_지석동,
#   '지야동': 광산동_지야동,
#   '지정동': 광산동_지정동,
#   '지죽동': 광산동_지죽동,
#   '지평동': 광산동_지평동,
#   '진곡동': 광산동_진곡동,
#   '진월동': 광산동_진월동,
#   '청풍동': 광산동_청풍동,
#   '충장동': 광산동_충장동,
#   '충효동': 광산동_충효동,
#   '치평동': 광산동_치평동,
#   '칠석동': 광산동_칠석동,
#   '태령동': 광산동_태령동,
#   '풍암동': 광산동_풍암동,
#   '풍향동': 광산동_풍향동,
#   '하남동': 광산동_하남동,
#   '하산동': 광산동_하산동,
#   '학동': 광산동_학동,
#   '행암동': 광산동_행암동,
#   '호남동': 광산동_호남동,
#   '화암동': 광산동_화암동,
#   '화장동': 광산동_화장동,
#   '화정동': 광산동_화정동,
#   '황금동': 광산동_황금동,
#   '황룡동': 광산동_황룡동,
#   '효령동': 광산동_효령동,
#   '흑석동': 광산동_흑석동},
#  '광산동.1': {'각화동': 광산동.1_각화동,
#   '계림동': 광산동.1_계림동,
#   '고룡동': 광산동.1_고룡동,
#   '광산동': 광산동.1_광산동,
#   '광산동.1': 광산동.1_광산동.1,
#   '광천동': 광산동.1_광천동,
#   '구동': 광산동.1_구동,
#   '구소동': 광산동.1_구소동,
#   '궁동': 광산동.1_궁동,
#   '금곡동': 광산동.1_금곡동,
#   '금동': 광산동.1_금동,
#   '금호동': 광산동.1_금호동,
#   '남동': 광산동.1_남동,
#   '남산동': 광산동.1_남산동,
#   '내남동': 광산동.1_내남동,
#   '내방동': 광산동.1_내방동,
#   '내산동': 광산동.1_내산동,
#   '노대동': 광산동.1_노대동,
#   '농성동': 광산동.1_농성동,
#   '누문동': 광산동.1_누문동,
#   '대산동': 광산동.1_대산동,
#   '대의동': 광산동.1_대의동,
#   '대인동': 광산동.1_대인동,
#   '대지동': 광산동.1_대지동,
#   '대촌동': 광산동.1_대촌동,
#   '덕남동': 광산동.1_덕남동,
#   '덕림동': 광산동.1_덕림동,
#   '덕의동': 광산동.1_덕의동,
#   '덕흥동': 광산동.1_덕흥동,
#   '도금동': 광산동.1_도금동,
#   '도덕동': 광산동.1_도덕동,
#   '도산동': 광산동.1_도산동,
#   '도천동': 광산동.1_도천동,
#   '도호동': 광산동.1_도호동,
#   '동림동': 광산동.1_동림동,
#   '동림동.1': 광산동.1_동림동.1,
#   '동명동': 광산동.1_동명동,
#   '동산동': 광산동.1_동산동,
#   '동천동': 광산동.1_동천동,
#   '동호동': 광산동.1_동호동,
#   '두암동': 광산동.1_두암동,
#   '두정동': 광산동.1_두정동,
#   '등임동': 광산동.1_등임동,
#   '마륵동': 광산동.1_마륵동,
#   '망월동': 광산동.1_망월동,
#   '매곡동': 광산동.1_매곡동,
#   '매월동': 광산동.1_매월동,
#   '명도동': 광산동.1_명도동,
#   '명화동': 광산동.1_명화동,
#   '문흥동': 광산동.1_문흥동,
#   '박호동': 광산동.1_박호동,
#   '방림동': 광산동.1_방림동,
#   '백운동': 광산동.1_백운동,
#   '벽진동': 광산동.1_벽진동,
#   '복룡동': 광산동.1_복룡동,
#   '본덕동': 광산동.1_본덕동,
#   '본촌동': 광산동.1_본촌동,
#   '봉선동': 광산동.1_봉선동,
#   '북동': 광산동.1_북동,
#   '북산동': 광산동.1_북산동,
#   '불로동': 광산동.1_불로동,
#   '비아동': 광산동.1_비아동,
#   '사동': 광산동.1_사동,
#   '사호동': 광산동.1_사호동,
#   '산막동': 광산동.1_산막동,
#   '산수동': 광산동.1_산수동,
#   '산수동.1': 광산동.1_산수동.1,
#   '산월동': 광산동.1_산월동,
#   '산정동': 광산동.1_산정동,
#   '삼각동': 광산동.1_삼각동,
#   '삼거동': 광산동.1_삼거동,
#   '삼도동': 광산동.1_삼도동,
#   '생용동': 광산동.1_생용동,
#   '서동': 광산동.1_서동,
#   '서봉동': 광산동.1_서봉동,
#   '서석동': 광산동.1_서석동,
#   '서창동': 광산동.1_서창동,
#   '석정동': 광산동.1_석정동,
#   '선교동': 광산동.1_선교동,
#   '선동': 광산동.1_선동,
#   '선암동': 광산동.1_선암동,
#   '세하동': 광산동.1_세하동,
#   '소촌동': 광산동.1_소촌동,
#   '소태동': 광산동.1_소태동,
#   '송대동': 광산동.1_송대동,
#   '송산동': 광산동.1_송산동,
#   '송정동': 광산동.1_송정동,
#   '송촌동': 광산동.1_송촌동,
#   '송치동': 광산동.1_송치동,
#   '송하동': 광산동.1_송하동,
#   '송학동': 광산동.1_송학동,
#   '수곡동': 광산동.1_수곡동,
#   '수기동': 광산동.1_수기동,
#   '수완동': 광산동.1_수완동,
#   '승촌동': 광산동.1_승촌동,
#   '신가동': 광산동.1_신가동,
#   '신동': 광산동.1_신동,
#   '신룡동': 광산동.1_신룡동,
#   '신안동': 광산동.1_신안동,
#   '신용동': 광산동.1_신용동,
#   '신장동': 광산동.1_신장동,
#   '신창동': 광산동.1_신창동,
#   '신촌동': 광산동.1_신촌동,
#   '쌍암동': 광산동.1_쌍암동,
#   '쌍촌동': 광산동.1_쌍촌동,
#   '안청동': 광산동.1_안청동,
#   '압촌동': 광산동.1_압촌동,
#   '양과동': 광산동.1_양과동,
#   '양동': 광산동.1_양동,
#   '양동.1': 광산동.1_양동.1,
#   '양림동': 광산동.1_양림동,
#   '양산동': 광산동.1_양산동,
#   '양산동.1': 광산동.1_양산동.1,
#   '양촌동': 광산동.1_양촌동,
#   '연산동': 광산동.1_연산동,
#   '연제동': 광산동.1_연제동,
#   '오룡동': 광산동.1_오룡동,
#   '오산동': 광산동.1_오산동,
#   '오선동': 광산동.1_오선동,
#   '오운동': 광산동.1_오운동,
#   '오치동': 광산동.1_오치동,
#   '옥동': 광산동.1_옥동,
#   '왕동': 광산동.1_왕동,
#   '요기동': 광산동.1_요기동,
#   '용강동': 광산동.1_용강동,
#   '용곡동': 광산동.1_용곡동,
#   '용동': 광산동.1_용동,
#   '용두동': 광산동.1_용두동,
#   '용두동.1': 광산동.1_용두동.1,
#   '용봉동': 광산동.1_용봉동,
#   '용봉동.1': 광산동.1_용봉동.1,
#   '용산동': 광산동.1_용산동,
#   '용연동': 광산동.1_용연동,
#   '용전동': 광산동.1_용전동,
#   '우산동': 광산동.1_우산동,
#   '우산동.1': 광산동.1_우산동.1,
#   '운남동': 광산동.1_운남동,
#   '운림동': 광산동.1_운림동,
#   '운수동': 광산동.1_운수동,
#   '운암동': 광산동.1_운암동,
#   '운정동': 광산동.1_운정동,
#   '원산동': 광산동.1_원산동,
#   '월계동': 광산동.1_월계동,
#   '월곡동': 광산동.1_월곡동,
#   '월남동': 광산동.1_월남동,
#   '월산동': 광산동.1_월산동,
#   '월성동': 광산동.1_월성동,
#   '월전동': 광산동.1_월전동,
#   '월출동': 광산동.1_월출동,
#   '유계동': 광산동.1_유계동,
#   '유동': 광산동.1_유동,
#   '유촌동': 광산동.1_유촌동,
#   '이장동': 광산동.1_이장동,
#   '일곡동': 광산동.1_일곡동,
#   '임곡동': 광산동.1_임곡동,
#   '임동': 광산동.1_임동,
#   '임암동': 광산동.1_임암동,
#   '장덕동': 광산동.1_장덕동,
#   '장동': 광산동.1_장동,
#   '장등동': 광산동.1_장등동,
#   '장록동': 광산동.1_장록동,
#   '장수동': 광산동.1_장수동,
#   '주월동': 광산동.1_주월동,
#   '중흥동': 광산동.1_중흥동,
#   '지산동': 광산동.1_지산동,
#   '지산동.1': 광산동.1_지산동.1,
#   '지석동': 광산동.1_지석동,
#   '지야동': 광산동.1_지야동,
#   '지정동': 광산동.1_지정동,
#   '지죽동': 광산동.1_지죽동,
#   '지평동': 광산동.1_지평동,
#   '진곡동': 광산동.1_진곡동,
#   '진월동': 광산동.1_진월동,
#   '청풍동': 광산동.1_청풍동,
#   '충장동': 광산동.1_충장동,
#   '충효동': 광산동.1_충효동,
#   '치평동': 광산동.1_치평동,
#   '칠석동': 광산동.1_칠석동,
#   '태령동': 광산동.1_태령동,
#   '풍암동': 광산동.1_풍암동,
#   '풍향동': 광산동.1_풍향동,
#   '하남동': 광산동.1_하남동,
#   '하산동': 광산동.1_하산동,
#   '학동': 광산동.1_학동,
#   '행암동': 광산동.1_행암동,
#   '호남동': 광산동.1_호남동,
#   '화암동': 광산동.1_화암동,
#   '화장동': 광산동.1_화장동,
#   '화정동': 광산동.1_화정동,
#   '황금동': 광산동.1_황금동,
#   '황룡동': 광산동.1_황룡동,
#   '효령동': 광산동.1_효령동,
#   '흑석동': 광산동.1_흑석동},
#  '광천동': {'각화동': 광천동_각화동,
#   '계림동': 광천동_계림동,
#   '고룡동': 광천동_고룡동,
#   '광산동': 광천동_광산동,
#   '광산동.1': 광천동_광산동.1,
#   '광천동': 광천동_광천동,
#   '구동': 광천동_구동,
#   '구소동': 광천동_구소동,
#   '궁동': 광천동_궁동,
#   '금곡동': 광천동_금곡동,
#   '금동': 광천동_금동,
#   '금호동': 광천동_금호동,
#   '남동': 광천동_남동,
#   '남산동': 광천동_남산동,
#   '내남동': 광천동_내남동,
#   '내방동': 광천동_내방동,
#   '내산동': 광천동_내산동,
#   '노대동': 광천동_노대동,
#   '농성동': 광천동_농성동,
#   '누문동': 광천동_누문동,
#   '대산동': 광천동_대산동,
#   '대의동': 광천동_대의동,
#   '대인동': 광천동_대인동,
#   '대지동': 광천동_대지동,
#   '대촌동': 광천동_대촌동,
#   '덕남동': 광천동_덕남동,
#   '덕림동': 광천동_덕림동,
#   '덕의동': 광천동_덕의동,
#   '덕흥동': 광천동_덕흥동,
#   '도금동': 광천동_도금동,
#   '도덕동': 광천동_도덕동,
#   '도산동': 광천동_도산동,
#   '도천동': 광천동_도천동,
#   '도호동': 광천동_도호동,
#   '동림동': 광천동_동림동,
#   '동림동.1': 광천동_동림동.1,
#   '동명동': 광천동_동명동,
#   '동산동': 광천동_동산동,
#   '동천동': 광천동_동천동,
#   '동호동': 광천동_동호동,
#   '두암동': 광천동_두암동,
#   '두정동': 광천동_두정동,
#   '등임동': 광천동_등임동,
#   '마륵동': 광천동_마륵동,
#   '망월동': 광천동_망월동,
#   '매곡동': 광천동_매곡동,
#   '매월동': 광천동_매월동,
#   '명도동': 광천동_명도동,
#   '명화동': 광천동_명화동,
#   '문흥동': 광천동_문흥동,
#   '박호동': 광천동_박호동,
#   '방림동': 광천동_방림동,
#   '백운동': 광천동_백운동,
#   '벽진동': 광천동_벽진동,
#   '복룡동': 광천동_복룡동,
#   '본덕동': 광천동_본덕동,
#   '본촌동': 광천동_본촌동,
#   '봉선동': 광천동_봉선동,
#   '북동': 광천동_북동,
#   '북산동': 광천동_북산동,
#   '불로동': 광천동_불로동,
#   '비아동': 광천동_비아동,
#   '사동': 광천동_사동,
#   '사호동': 광천동_사호동,
#   '산막동': 광천동_산막동,
#   '산수동': 광천동_산수동,
#   '산수동.1': 광천동_산수동.1,
#   '산월동': 광천동_산월동,
#   '산정동': 광천동_산정동,
#   '삼각동': 광천동_삼각동,
#   '삼거동': 광천동_삼거동,
#   '삼도동': 광천동_삼도동,
#   '생용동': 광천동_생용동,
#   '서동': 광천동_서동,
#   '서봉동': 광천동_서봉동,
#   '서석동': 광천동_서석동,
#   '서창동': 광천동_서창동,
#   '석정동': 광천동_석정동,
#   '선교동': 광천동_선교동,
#   '선동': 광천동_선동,
#   '선암동': 광천동_선암동,
#   '세하동': 광천동_세하동,
#   '소촌동': 광천동_소촌동,
#   '소태동': 광천동_소태동,
#   '송대동': 광천동_송대동,
#   '송산동': 광천동_송산동,
#   '송정동': 광천동_송정동,
#   '송촌동': 광천동_송촌동,
#   '송치동': 광천동_송치동,
#   '송하동': 광천동_송하동,
#   '송학동': 광천동_송학동,
#   '수곡동': 광천동_수곡동,
#   '수기동': 광천동_수기동,
#   '수완동': 광천동_수완동,
#   '승촌동': 광천동_승촌동,
#   '신가동': 광천동_신가동,
#   '신동': 광천동_신동,
#   '신룡동': 광천동_신룡동,
#   '신안동': 광천동_신안동,
#   '신용동': 광천동_신용동,
#   '신장동': 광천동_신장동,
#   '신창동': 광천동_신창동,
#   '신촌동': 광천동_신촌동,
#   '쌍암동': 광천동_쌍암동,
#   '쌍촌동': 광천동_쌍촌동,
#   '안청동': 광천동_안청동,
#   '압촌동': 광천동_압촌동,
#   '양과동': 광천동_양과동,
#   '양동': 광천동_양동,
#   '양동.1': 광천동_양동.1,
#   '양림동': 광천동_양림동,
#   '양산동': 광천동_양산동,
#   '양산동.1': 광천동_양산동.1,
#   '양촌동': 광천동_양촌동,
#   '연산동': 광천동_연산동,
#   '연제동': 광천동_연제동,
#   '오룡동': 광천동_오룡동,
#   '오산동': 광천동_오산동,
#   '오선동': 광천동_오선동,
#   '오운동': 광천동_오운동,
#   '오치동': 광천동_오치동,
#   '옥동': 광천동_옥동,
#   '왕동': 광천동_왕동,
#   '요기동': 광천동_요기동,
#   '용강동': 광천동_용강동,
#   '용곡동': 광천동_용곡동,
#   '용동': 광천동_용동,
#   '용두동': 광천동_용두동,
#   '용두동.1': 광천동_용두동.1,
#   '용봉동': 광천동_용봉동,
#   '용봉동.1': 광천동_용봉동.1,
#   '용산동': 광천동_용산동,
#   '용연동': 광천동_용연동,
#   '용전동': 광천동_용전동,
#   '우산동': 광천동_우산동,
#   '우산동.1': 광천동_우산동.1,
#   '운남동': 광천동_운남동,
#   '운림동': 광천동_운림동,
#   '운수동': 광천동_운수동,
#   '운암동': 광천동_운암동,
#   '운정동': 광천동_운정동,
#   '원산동': 광천동_원산동,
#   '월계동': 광천동_월계동,
#   '월곡동': 광천동_월곡동,
#   '월남동': 광천동_월남동,
#   '월산동': 광천동_월산동,
#   '월성동': 광천동_월성동,
#   '월전동': 광천동_월전동,
#   '월출동': 광천동_월출동,
#   '유계동': 광천동_유계동,
#   '유동': 광천동_유동,
#   '유촌동': 광천동_유촌동,
#   '이장동': 광천동_이장동,
#   '일곡동': 광천동_일곡동,
#   '임곡동': 광천동_임곡동,
#   '임동': 광천동_임동,
#   '임암동': 광천동_임암동,
#   '장덕동': 광천동_장덕동,
#   '장동': 광천동_장동,
#   '장등동': 광천동_장등동,
#   '장록동': 광천동_장록동,
#   '장수동': 광천동_장수동,
#   '주월동': 광천동_주월동,
#   '중흥동': 광천동_중흥동,
#   '지산동': 광천동_지산동,
#   '지산동.1': 광천동_지산동.1,
#   '지석동': 광천동_지석동,
#   '지야동': 광천동_지야동,
#   '지정동': 광천동_지정동,
#   '지죽동': 광천동_지죽동,
#   '지평동': 광천동_지평동,
#   '진곡동': 광천동_진곡동,
#   '진월동': 광천동_진월동,
#   '청풍동': 광천동_청풍동,
#   '충장동': 광천동_충장동,
#   '충효동': 광천동_충효동,
#   '치평동': 광천동_치평동,
#   '칠석동': 광천동_칠석동,
#   '태령동': 광천동_태령동,
#   '풍암동': 광천동_풍암동,
#   '풍향동': 광천동_풍향동,
#   '하남동': 광천동_하남동,
#   '하산동': 광천동_하산동,
#   '학동': 광천동_학동,
#   '행암동': 광천동_행암동,
#   '호남동': 광천동_호남동,
#   '화암동': 광천동_화암동,
#   '화장동': 광천동_화장동,
#   '화정동': 광천동_화정동,
#   '황금동': 광천동_황금동,
#   '황룡동': 광천동_황룡동,
#   '효령동': 광천동_효령동,
#   '흑석동': 광천동_흑석동},
#  '구동': {'각화동': 구동_각화동,
#   '계림동': 구동_계림동,
#   '고룡동': 구동_고룡동,
#   '광산동': 구동_광산동,
#   '광산동.1': 구동_광산동.1,
#   '광천동': 구동_광천동,
#   '구동': 구동_구동,
#   '구소동': 구동_구소동,
#   '궁동': 구동_궁동,
#   '금곡동': 구동_금곡동,
#   '금동': 구동_금동,
#   '금호동': 구동_금호동,
#   '남동': 구동_남동,
#   '남산동': 구동_남산동,
#   '내남동': 구동_내남동,
#   '내방동': 구동_내방동,
#   '내산동': 구동_내산동,
#   '노대동': 구동_노대동,
#   '농성동': 구동_농성동,
#   '누문동': 구동_누문동,
#   '대산동': 구동_대산동,
#   '대의동': 구동_대의동,
#   '대인동': 구동_대인동,
#   '대지동': 구동_대지동,
#   '대촌동': 구동_대촌동,
#   '덕남동': 구동_덕남동,
#   '덕림동': 구동_덕림동,
#   '덕의동': 구동_덕의동,
#   '덕흥동': 구동_덕흥동,
#   '도금동': 구동_도금동,
#   '도덕동': 구동_도덕동,
#   '도산동': 구동_도산동,
#   '도천동': 구동_도천동,
#   '도호동': 구동_도호동,
#   '동림동': 구동_동림동,
#   '동림동.1': 구동_동림동.1,
#   '동명동': 구동_동명동,
#   '동산동': 구동_동산동,
#   '동천동': 구동_동천동,
#   '동호동': 구동_동호동,
#   '두암동': 구동_두암동,
#   '두정동': 구동_두정동,
#   '등임동': 구동_등임동,
#   '마륵동': 구동_마륵동,
#   '망월동': 구동_망월동,
#   '매곡동': 구동_매곡동,
#   '매월동': 구동_매월동,
#   '명도동': 구동_명도동,
#   '명화동': 구동_명화동,
#   '문흥동': 구동_문흥동,
#   '박호동': 구동_박호동,
#   '방림동': 구동_방림동,
#   '백운동': 구동_백운동,
#   '벽진동': 구동_벽진동,
#   '복룡동': 구동_복룡동,
#   '본덕동': 구동_본덕동,
#   '본촌동': 구동_본촌동,
#   '봉선동': 구동_봉선동,
#   '북동': 구동_북동,
#   '북산동': 구동_북산동,
#   '불로동': 구동_불로동,
#   '비아동': 구동_비아동,
#   '사동': 구동_사동,
#   '사호동': 구동_사호동,
#   '산막동': 구동_산막동,
#   '산수동': 구동_산수동,
#   '산수동.1': 구동_산수동.1,
#   '산월동': 구동_산월동,
#   '산정동': 구동_산정동,
#   '삼각동': 구동_삼각동,
#   '삼거동': 구동_삼거동,
#   '삼도동': 구동_삼도동,
#   '생용동': 구동_생용동,
#   '서동': 구동_서동,
#   '서봉동': 구동_서봉동,
#   '서석동': 구동_서석동,
#   '서창동': 구동_서창동,
#   '석정동': 구동_석정동,
#   '선교동': 구동_선교동,
#   '선동': 구동_선동,
#   '선암동': 구동_선암동,
#   '세하동': 구동_세하동,
#   '소촌동': 구동_소촌동,
#   '소태동': 구동_소태동,
#   '송대동': 구동_송대동,
#   '송산동': 구동_송산동,
#   '송정동': 구동_송정동,
#   '송촌동': 구동_송촌동,
#   '송치동': 구동_송치동,
#   '송하동': 구동_송하동,
#   '송학동': 구동_송학동,
#   '수곡동': 구동_수곡동,
#   '수기동': 구동_수기동,
#   '수완동': 구동_수완동,
#   '승촌동': 구동_승촌동,
#   '신가동': 구동_신가동,
#   '신동': 구동_신동,
#   '신룡동': 구동_신룡동,
#   '신안동': 구동_신안동,
#   '신용동': 구동_신용동,
#   '신장동': 구동_신장동,
#   '신창동': 구동_신창동,
#   '신촌동': 구동_신촌동,
#   '쌍암동': 구동_쌍암동,
#   '쌍촌동': 구동_쌍촌동,
#   '안청동': 구동_안청동,
#   '압촌동': 구동_압촌동,
#   '양과동': 구동_양과동,
#   '양동': 구동_양동,
#   '양동.1': 구동_양동.1,
#   '양림동': 구동_양림동,
#   '양산동': 구동_양산동,
#   '양산동.1': 구동_양산동.1,
#   '양촌동': 구동_양촌동,
#   '연산동': 구동_연산동,
#   '연제동': 구동_연제동,
#   '오룡동': 구동_오룡동,
#   '오산동': 구동_오산동,
#   '오선동': 구동_오선동,
#   '오운동': 구동_오운동,
#   '오치동': 구동_오치동,
#   '옥동': 구동_옥동,
#   '왕동': 구동_왕동,
#   '요기동': 구동_요기동,
#   '용강동': 구동_용강동,
#   '용곡동': 구동_용곡동,
#   '용동': 구동_용동,
#   '용두동': 구동_용두동,
#   '용두동.1': 구동_용두동.1,
#   '용봉동': 구동_용봉동,
#   '용봉동.1': 구동_용봉동.1,
#   '용산동': 구동_용산동,
#   '용연동': 구동_용연동,
#   '용전동': 구동_용전동,
#   '우산동': 구동_우산동,
#   '우산동.1': 구동_우산동.1,
#   '운남동': 구동_운남동,
#   '운림동': 구동_운림동,
#   '운수동': 구동_운수동,
#   '운암동': 구동_운암동,
#   '운정동': 구동_운정동,
#   '원산동': 구동_원산동,
#   '월계동': 구동_월계동,
#   '월곡동': 구동_월곡동,
#   '월남동': 구동_월남동,
#   '월산동': 구동_월산동,
#   '월성동': 구동_월성동,
#   '월전동': 구동_월전동,
#   '월출동': 구동_월출동,
#   '유계동': 구동_유계동,
#   '유동': 구동_유동,
#   '유촌동': 구동_유촌동,
#   '이장동': 구동_이장동,
#   '일곡동': 구동_일곡동,
#   '임곡동': 구동_임곡동,
#   '임동': 구동_임동,
#   '임암동': 구동_임암동,
#   '장덕동': 구동_장덕동,
#   '장동': 구동_장동,
#   '장등동': 구동_장등동,
#   '장록동': 구동_장록동,
#   '장수동': 구동_장수동,
#   '주월동': 구동_주월동,
#   '중흥동': 구동_중흥동,
#   '지산동': 구동_지산동,
#   '지산동.1': 구동_지산동.1,
#   '지석동': 구동_지석동,
#   '지야동': 구동_지야동,
#   '지정동': 구동_지정동,
#   '지죽동': 구동_지죽동,
#   '지평동': 구동_지평동,
#   '진곡동': 구동_진곡동,
#   '진월동': 구동_진월동,
#   '청풍동': 구동_청풍동,
#   '충장동': 구동_충장동,
#   '충효동': 구동_충효동,
#   '치평동': 구동_치평동,
#   '칠석동': 구동_칠석동,
#   '태령동': 구동_태령동,
#   '풍암동': 구동_풍암동,
#   '풍향동': 구동_풍향동,
#   '하남동': 구동_하남동,
#   '하산동': 구동_하산동,
#   '학동': 구동_학동,
#   '행암동': 구동_행암동,
#   '호남동': 구동_호남동,
#   '화암동': 구동_화암동,
#   '화장동': 구동_화장동,
#   '화정동': 구동_화정동,
#   '황금동': 구동_황금동,
#   '황룡동': 구동_황룡동,
#   '효령동': 구동_효령동,
#   '흑석동': 구동_흑석동},
#  '구소동': {'각화동': 구소동_각화동,
#   '계림동': 구소동_계림동,
#   '고룡동': 구소동_고룡동,
#   '광산동': 구소동_광산동,
#   '광산동.1': 구소동_광산동.1,
#   '광천동': 구소동_광천동,
#   '구동': 구소동_구동,
#   '구소동': 구소동_구소동,
#   '궁동': 구소동_궁동,
#   '금곡동': 구소동_금곡동,
#   '금동': 구소동_금동,
#   '금호동': 구소동_금호동,
#   '남동': 구소동_남동,
#   '남산동': 구소동_남산동,
#   '내남동': 구소동_내남동,
#   '내방동': 구소동_내방동,
#   '내산동': 구소동_내산동,
#   '노대동': 구소동_노대동,
#   '농성동': 구소동_농성동,
#   '누문동': 구소동_누문동,
#   '대산동': 구소동_대산동,
#   '대의동': 구소동_대의동,
#   '대인동': 구소동_대인동,
#   '대지동': 구소동_대지동,
#   '대촌동': 구소동_대촌동,
#   '덕남동': 구소동_덕남동,
#   '덕림동': 구소동_덕림동,
#   '덕의동': 구소동_덕의동,
#   '덕흥동': 구소동_덕흥동,
#   '도금동': 구소동_도금동,
#   '도덕동': 구소동_도덕동,
#   '도산동': 구소동_도산동,
#   '도천동': 구소동_도천동,
#   '도호동': 구소동_도호동,
#   '동림동': 구소동_동림동,
#   '동림동.1': 구소동_동림동.1,
#   '동명동': 구소동_동명동,
#   '동산동': 구소동_동산동,
#   '동천동': 구소동_동천동,
#   '동호동': 구소동_동호동,
#   '두암동': 구소동_두암동,
#   '두정동': 구소동_두정동,
#   '등임동': 구소동_등임동,
#   '마륵동': 구소동_마륵동,
#   '망월동': 구소동_망월동,
#   '매곡동': 구소동_매곡동,
#   '매월동': 구소동_매월동,
#   '명도동': 구소동_명도동,
#   '명화동': 구소동_명화동,
#   '문흥동': 구소동_문흥동,
#   '박호동': 구소동_박호동,
#   '방림동': 구소동_방림동,
#   '백운동': 구소동_백운동,
#   '벽진동': 구소동_벽진동,
#   '복룡동': 구소동_복룡동,
#   '본덕동': 구소동_본덕동,
#   '본촌동': 구소동_본촌동,
#   '봉선동': 구소동_봉선동,
#   '북동': 구소동_북동,
#   '북산동': 구소동_북산동,
#   '불로동': 구소동_불로동,
#   '비아동': 구소동_비아동,
#   '사동': 구소동_사동,
#   '사호동': 구소동_사호동,
#   '산막동': 구소동_산막동,
#   '산수동': 구소동_산수동,
#   '산수동.1': 구소동_산수동.1,
#   '산월동': 구소동_산월동,
#   '산정동': 구소동_산정동,
#   '삼각동': 구소동_삼각동,
#   '삼거동': 구소동_삼거동,
#   '삼도동': 구소동_삼도동,
#   '생용동': 구소동_생용동,
#   '서동': 구소동_서동,
#   '서봉동': 구소동_서봉동,
#   '서석동': 구소동_서석동,
#   '서창동': 구소동_서창동,
#   '석정동': 구소동_석정동,
#   '선교동': 구소동_선교동,
#   '선동': 구소동_선동,
#   '선암동': 구소동_선암동,
#   '세하동': 구소동_세하동,
#   '소촌동': 구소동_소촌동,
#   '소태동': 구소동_소태동,
#   '송대동': 구소동_송대동,
#   '송산동': 구소동_송산동,
#   '송정동': 구소동_송정동,
#   '송촌동': 구소동_송촌동,
#   '송치동': 구소동_송치동,
#   '송하동': 구소동_송하동,
#   '송학동': 구소동_송학동,
#   '수곡동': 구소동_수곡동,
#   '수기동': 구소동_수기동,
#   '수완동': 구소동_수완동,
#   '승촌동': 구소동_승촌동,
#   '신가동': 구소동_신가동,
#   '신동': 구소동_신동,
#   '신룡동': 구소동_신룡동,
#   '신안동': 구소동_신안동,
#   '신용동': 구소동_신용동,
#   '신장동': 구소동_신장동,
#   '신창동': 구소동_신창동,
#   '신촌동': 구소동_신촌동,
#   '쌍암동': 구소동_쌍암동,
#   '쌍촌동': 구소동_쌍촌동,
#   '안청동': 구소동_안청동,
#   '압촌동': 구소동_압촌동,
#   '양과동': 구소동_양과동,
#   '양동': 구소동_양동,
#   '양동.1': 구소동_양동.1,
#   '양림동': 구소동_양림동,
#   '양산동': 구소동_양산동,
#   '양산동.1': 구소동_양산동.1,
#   '양촌동': 구소동_양촌동,
#   '연산동': 구소동_연산동,
#   '연제동': 구소동_연제동,
#   '오룡동': 구소동_오룡동,
#   '오산동': 구소동_오산동,
#   '오선동': 구소동_오선동,
#   '오운동': 구소동_오운동,
#   '오치동': 구소동_오치동,
#   '옥동': 구소동_옥동,
#   '왕동': 구소동_왕동,
#   '요기동': 구소동_요기동,
#   '용강동': 구소동_용강동,
#   '용곡동': 구소동_용곡동,
#   '용동': 구소동_용동,
#   '용두동': 구소동_용두동,
#   '용두동.1': 구소동_용두동.1,
#   '용봉동': 구소동_용봉동,
#   '용봉동.1': 구소동_용봉동.1,
#   '용산동': 구소동_용산동,
#   '용연동': 구소동_용연동,
#   '용전동': 구소동_용전동,
#   '우산동': 구소동_우산동,
#   '우산동.1': 구소동_우산동.1,
#   '운남동': 구소동_운남동,
#   '운림동': 구소동_운림동,
#   '운수동': 구소동_운수동,
#   '운암동': 구소동_운암동,
#   '운정동': 구소동_운정동,
#   '원산동': 구소동_원산동,
#   '월계동': 구소동_월계동,
#   '월곡동': 구소동_월곡동,
#   '월남동': 구소동_월남동,
#   '월산동': 구소동_월산동,
#   '월성동': 구소동_월성동,
#   '월전동': 구소동_월전동,
#   '월출동': 구소동_월출동,
#   '유계동': 구소동_유계동,
#   '유동': 구소동_유동,
#   '유촌동': 구소동_유촌동,
#   '이장동': 구소동_이장동,
#   '일곡동': 구소동_일곡동,
#   '임곡동': 구소동_임곡동,
#   '임동': 구소동_임동,
#   '임암동': 구소동_임암동,
#   '장덕동': 구소동_장덕동,
#   '장동': 구소동_장동,
#   '장등동': 구소동_장등동,
#   '장록동': 구소동_장록동,
#   '장수동': 구소동_장수동,
#   '주월동': 구소동_주월동,
#   '중흥동': 구소동_중흥동,
#   '지산동': 구소동_지산동,
#   '지산동.1': 구소동_지산동.1,
#   '지석동': 구소동_지석동,
#   '지야동': 구소동_지야동,
#   '지정동': 구소동_지정동,
#   '지죽동': 구소동_지죽동,
#   '지평동': 구소동_지평동,
#   '진곡동': 구소동_진곡동,
#   '진월동': 구소동_진월동,
#   '청풍동': 구소동_청풍동,
#   '충장동': 구소동_충장동,
#   '충효동': 구소동_충효동,
#   '치평동': 구소동_치평동,
#   '칠석동': 구소동_칠석동,
#   '태령동': 구소동_태령동,
#   '풍암동': 구소동_풍암동,
#   '풍향동': 구소동_풍향동,
#   '하남동': 구소동_하남동,
#   '하산동': 구소동_하산동,
#   '학동': 구소동_학동,
#   '행암동': 구소동_행암동,
#   '호남동': 구소동_호남동,
#   '화암동': 구소동_화암동,
#   '화장동': 구소동_화장동,
#   '화정동': 구소동_화정동,
#   '황금동': 구소동_황금동,
#   '황룡동': 구소동_황룡동,
#   '효령동': 구소동_효령동,
#   '흑석동': 구소동_흑석동},
#  '궁동': {'각화동': 궁동_각화동,
#   '계림동': 궁동_계림동,
#   '고룡동': 궁동_고룡동,
#   '광산동': 궁동_광산동,
#   '광산동.1': 궁동_광산동.1,
#   '광천동': 궁동_광천동,
#   '구동': 궁동_구동,
#   '구소동': 궁동_구소동,
#   '궁동': 궁동_궁동,
#   '금곡동': 궁동_금곡동,
#   '금동': 궁동_금동,
#   '금호동': 궁동_금호동,
#   '남동': 궁동_남동,
#   '남산동': 궁동_남산동,
#   '내남동': 궁동_내남동,
#   '내방동': 궁동_내방동,
#   '내산동': 궁동_내산동,
#   '노대동': 궁동_노대동,
#   '농성동': 궁동_농성동,
#   '누문동': 궁동_누문동,
#   '대산동': 궁동_대산동,
#   '대의동': 궁동_대의동,
#   '대인동': 궁동_대인동,
#   '대지동': 궁동_대지동,
#   '대촌동': 궁동_대촌동,
#   '덕남동': 궁동_덕남동,
#   '덕림동': 궁동_덕림동,
#   '덕의동': 궁동_덕의동,
#   '덕흥동': 궁동_덕흥동,
#   '도금동': 궁동_도금동,
#   '도덕동': 궁동_도덕동,
#   '도산동': 궁동_도산동,
#   '도천동': 궁동_도천동,
#   '도호동': 궁동_도호동,
#   '동림동': 궁동_동림동,
#   '동림동.1': 궁동_동림동.1,
#   '동명동': 궁동_동명동,
#   '동산동': 궁동_동산동,
#   '동천동': 궁동_동천동,
#   '동호동': 궁동_동호동,
#   '두암동': 궁동_두암동,
#   '두정동': 궁동_두정동,
#   '등임동': 궁동_등임동,
#   '마륵동': 궁동_마륵동,
#   '망월동': 궁동_망월동,
#   '매곡동': 궁동_매곡동,
#   '매월동': 궁동_매월동,
#   '명도동': 궁동_명도동,
#   '명화동': 궁동_명화동,
#   '문흥동': 궁동_문흥동,
#   '박호동': 궁동_박호동,
#   '방림동': 궁동_방림동,
#   '백운동': 궁동_백운동,
#   '벽진동': 궁동_벽진동,
#   '복룡동': 궁동_복룡동,
#   '본덕동': 궁동_본덕동,
#   '본촌동': 궁동_본촌동,
#   '봉선동': 궁동_봉선동,
#   '북동': 궁동_북동,
#   '북산동': 궁동_북산동,
#   '불로동': 궁동_불로동,
#   '비아동': 궁동_비아동,
#   '사동': 궁동_사동,
#   '사호동': 궁동_사호동,
#   '산막동': 궁동_산막동,
#   '산수동': 궁동_산수동,
#   '산수동.1': 궁동_산수동.1,
#   '산월동': 궁동_산월동,
#   '산정동': 궁동_산정동,
#   '삼각동': 궁동_삼각동,
#   '삼거동': 궁동_삼거동,
#   '삼도동': 궁동_삼도동,
#   '생용동': 궁동_생용동,
#   '서동': 궁동_서동,
#   '서봉동': 궁동_서봉동,
#   '서석동': 궁동_서석동,
#   '서창동': 궁동_서창동,
#   '석정동': 궁동_석정동,
#   '선교동': 궁동_선교동,
#   '선동': 궁동_선동,
#   '선암동': 궁동_선암동,
#   '세하동': 궁동_세하동,
#   '소촌동': 궁동_소촌동,
#   '소태동': 궁동_소태동,
#   '송대동': 궁동_송대동,
#   '송산동': 궁동_송산동,
#   '송정동': 궁동_송정동,
#   '송촌동': 궁동_송촌동,
#   '송치동': 궁동_송치동,
#   '송하동': 궁동_송하동,
#   '송학동': 궁동_송학동,
#   '수곡동': 궁동_수곡동,
#   '수기동': 궁동_수기동,
#   '수완동': 궁동_수완동,
#   '승촌동': 궁동_승촌동,
#   '신가동': 궁동_신가동,
#   '신동': 궁동_신동,
#   '신룡동': 궁동_신룡동,
#   '신안동': 궁동_신안동,
#   '신용동': 궁동_신용동,
#   '신장동': 궁동_신장동,
#   '신창동': 궁동_신창동,
#   '신촌동': 궁동_신촌동,
#   '쌍암동': 궁동_쌍암동,
#   '쌍촌동': 궁동_쌍촌동,
#   '안청동': 궁동_안청동,
#   '압촌동': 궁동_압촌동,
#   '양과동': 궁동_양과동,
#   '양동': 궁동_양동,
#   '양동.1': 궁동_양동.1,
#   '양림동': 궁동_양림동,
#   '양산동': 궁동_양산동,
#   '양산동.1': 궁동_양산동.1,
#   '양촌동': 궁동_양촌동,
#   '연산동': 궁동_연산동,
#   '연제동': 궁동_연제동,
#   '오룡동': 궁동_오룡동,
#   '오산동': 궁동_오산동,
#   '오선동': 궁동_오선동,
#   '오운동': 궁동_오운동,
#   '오치동': 궁동_오치동,
#   '옥동': 궁동_옥동,
#   '왕동': 궁동_왕동,
#   '요기동': 궁동_요기동,
#   '용강동': 궁동_용강동,
#   '용곡동': 궁동_용곡동,
#   '용동': 궁동_용동,
#   '용두동': 궁동_용두동,
#   '용두동.1': 궁동_용두동.1,
#   '용봉동': 궁동_용봉동,
#   '용봉동.1': 궁동_용봉동.1,
#   '용산동': 궁동_용산동,
#   '용연동': 궁동_용연동,
#   '용전동': 궁동_용전동,
#   '우산동': 궁동_우산동,
#   '우산동.1': 궁동_우산동.1,
#   '운남동': 궁동_운남동,
#   '운림동': 궁동_운림동,
#   '운수동': 궁동_운수동,
#   '운암동': 궁동_운암동,
#   '운정동': 궁동_운정동,
#   '원산동': 궁동_원산동,
#   '월계동': 궁동_월계동,
#   '월곡동': 궁동_월곡동,
#   '월남동': 궁동_월남동,
#   '월산동': 궁동_월산동,
#   '월성동': 궁동_월성동,
#   '월전동': 궁동_월전동,
#   '월출동': 궁동_월출동,
#   '유계동': 궁동_유계동,
#   '유동': 궁동_유동,
#   '유촌동': 궁동_유촌동,
#   '이장동': 궁동_이장동,
#   '일곡동': 궁동_일곡동,
#   '임곡동': 궁동_임곡동,
#   '임동': 궁동_임동,
#   '임암동': 궁동_임암동,
#   '장덕동': 궁동_장덕동,
#   '장동': 궁동_장동,
#   '장등동': 궁동_장등동,
#   '장록동': 궁동_장록동,
#   '장수동': 궁동_장수동,
#   '주월동': 궁동_주월동,
#   '중흥동': 궁동_중흥동,
#   '지산동': 궁동_지산동,
#   '지산동.1': 궁동_지산동.1,
#   '지석동': 궁동_지석동,
#   '지야동': 궁동_지야동,
#   '지정동': 궁동_지정동,
#   '지죽동': 궁동_지죽동,
#   '지평동': 궁동_지평동,
#   '진곡동': 궁동_진곡동,
#   '진월동': 궁동_진월동,
#   '청풍동': 궁동_청풍동,
#   '충장동': 궁동_충장동,
#   '충효동': 궁동_충효동,
#   '치평동': 궁동_치평동,
#   '칠석동': 궁동_칠석동,
#   '태령동': 궁동_태령동,
#   '풍암동': 궁동_풍암동,
#   '풍향동': 궁동_풍향동,
#   '하남동': 궁동_하남동,
#   '하산동': 궁동_하산동,
#   '학동': 궁동_학동,
#   '행암동': 궁동_행암동,
#   '호남동': 궁동_호남동,
#   '화암동': 궁동_화암동,
#   '화장동': 궁동_화장동,
#   '화정동': 궁동_화정동,
#   '황금동': 궁동_황금동,
#   '황룡동': 궁동_황룡동,
#   '효령동': 궁동_효령동,
#   '흑석동': 궁동_흑석동},
#  '금곡동': {'각화동': 금곡동_각화동,
#   '계림동': 금곡동_계림동,
#   '고룡동': 금곡동_고룡동,
#   '광산동': 금곡동_광산동,
#   '광산동.1': 금곡동_광산동.1,
#   '광천동': 금곡동_광천동,
#   '구동': 금곡동_구동,
#   '구소동': 금곡동_구소동,
#   '궁동': 금곡동_궁동,
#   '금곡동': 금곡동_금곡동,
#   '금동': 금곡동_금동,
#   '금호동': 금곡동_금호동,
#   '남동': 금곡동_남동,
#   '남산동': 금곡동_남산동,
#   '내남동': 금곡동_내남동,
#   '내방동': 금곡동_내방동,
#   '내산동': 금곡동_내산동,
#   '노대동': 금곡동_노대동,
#   '농성동': 금곡동_농성동,
#   '누문동': 금곡동_누문동,
#   '대산동': 금곡동_대산동,
#   '대의동': 금곡동_대의동,
#   '대인동': 금곡동_대인동,
#   '대지동': 금곡동_대지동,
#   '대촌동': 금곡동_대촌동,
#   '덕남동': 금곡동_덕남동,
#   '덕림동': 금곡동_덕림동,
#   '덕의동': 금곡동_덕의동,
#   '덕흥동': 금곡동_덕흥동,
#   '도금동': 금곡동_도금동,
#   '도덕동': 금곡동_도덕동,
#   '도산동': 금곡동_도산동,
#   '도천동': 금곡동_도천동,
#   '도호동': 금곡동_도호동,
#   '동림동': 금곡동_동림동,
#   '동림동.1': 금곡동_동림동.1,
#   '동명동': 금곡동_동명동,
#   '동산동': 금곡동_동산동,
#   '동천동': 금곡동_동천동,
#   '동호동': 금곡동_동호동,
#   '두암동': 금곡동_두암동,
#   '두정동': 금곡동_두정동,
#   '등임동': 금곡동_등임동,
#   '마륵동': 금곡동_마륵동,
#   '망월동': 금곡동_망월동,
#   '매곡동': 금곡동_매곡동,
#   '매월동': 금곡동_매월동,
#   '명도동': 금곡동_명도동,
#   '명화동': 금곡동_명화동,
#   '문흥동': 금곡동_문흥동,
#   '박호동': 금곡동_박호동,
#   '방림동': 금곡동_방림동,
#   '백운동': 금곡동_백운동,
#   '벽진동': 금곡동_벽진동,
#   '복룡동': 금곡동_복룡동,
#   '본덕동': 금곡동_본덕동,
#   '본촌동': 금곡동_본촌동,
#   '봉선동': 금곡동_봉선동,
#   '북동': 금곡동_북동,
#   '북산동': 금곡동_북산동,
#   '불로동': 금곡동_불로동,
#   '비아동': 금곡동_비아동,
#   '사동': 금곡동_사동,
#   '사호동': 금곡동_사호동,
#   '산막동': 금곡동_산막동,
#   '산수동': 금곡동_산수동,
#   '산수동.1': 금곡동_산수동.1,
#   '산월동': 금곡동_산월동,
#   '산정동': 금곡동_산정동,
#   '삼각동': 금곡동_삼각동,
#   '삼거동': 금곡동_삼거동,
#   '삼도동': 금곡동_삼도동,
#   '생용동': 금곡동_생용동,
#   '서동': 금곡동_서동,
#   '서봉동': 금곡동_서봉동,
#   '서석동': 금곡동_서석동,
#   '서창동': 금곡동_서창동,
#   '석정동': 금곡동_석정동,
#   '선교동': 금곡동_선교동,
#   '선동': 금곡동_선동,
#   '선암동': 금곡동_선암동,
#   '세하동': 금곡동_세하동,
#   '소촌동': 금곡동_소촌동,
#   '소태동': 금곡동_소태동,
#   '송대동': 금곡동_송대동,
#   '송산동': 금곡동_송산동,
#   '송정동': 금곡동_송정동,
#   '송촌동': 금곡동_송촌동,
#   '송치동': 금곡동_송치동,
#   '송하동': 금곡동_송하동,
#   '송학동': 금곡동_송학동,
#   '수곡동': 금곡동_수곡동,
#   '수기동': 금곡동_수기동,
#   '수완동': 금곡동_수완동,
#   '승촌동': 금곡동_승촌동,
#   '신가동': 금곡동_신가동,
#   '신동': 금곡동_신동,
#   '신룡동': 금곡동_신룡동,
#   '신안동': 금곡동_신안동,
#   '신용동': 금곡동_신용동,
#   '신장동': 금곡동_신장동,
#   '신창동': 금곡동_신창동,
#   '신촌동': 금곡동_신촌동,
#   '쌍암동': 금곡동_쌍암동,
#   '쌍촌동': 금곡동_쌍촌동,
#   '안청동': 금곡동_안청동,
#   '압촌동': 금곡동_압촌동,
#   '양과동': 금곡동_양과동,
#   '양동': 금곡동_양동,
#   '양동.1': 금곡동_양동.1,
#   '양림동': 금곡동_양림동,
#   '양산동': 금곡동_양산동,
#   '양산동.1': 금곡동_양산동.1,
#   '양촌동': 금곡동_양촌동,
#   '연산동': 금곡동_연산동,
#   '연제동': 금곡동_연제동,
#   '오룡동': 금곡동_오룡동,
#   '오산동': 금곡동_오산동,
#   '오선동': 금곡동_오선동,
#   '오운동': 금곡동_오운동,
#   '오치동': 금곡동_오치동,
#   '옥동': 금곡동_옥동,
#   '왕동': 금곡동_왕동,
#   '요기동': 금곡동_요기동,
#   '용강동': 금곡동_용강동,
#   '용곡동': 금곡동_용곡동,
#   '용동': 금곡동_용동,
#   '용두동': 금곡동_용두동,
#   '용두동.1': 금곡동_용두동.1,
#   '용봉동': 금곡동_용봉동,
#   '용봉동.1': 금곡동_용봉동.1,
#   '용산동': 금곡동_용산동,
#   '용연동': 금곡동_용연동,
#   '용전동': 금곡동_용전동,
#   '우산동': 금곡동_우산동,
#   '우산동.1': 금곡동_우산동.1,
#   '운남동': 금곡동_운남동,
#   '운림동': 금곡동_운림동,
#   '운수동': 금곡동_운수동,
#   '운암동': 금곡동_운암동,
#   '운정동': 금곡동_운정동,
#   '원산동': 금곡동_원산동,
#   '월계동': 금곡동_월계동,
#   '월곡동': 금곡동_월곡동,
#   '월남동': 금곡동_월남동,
#   '월산동': 금곡동_월산동,
#   '월성동': 금곡동_월성동,
#   '월전동': 금곡동_월전동,
#   '월출동': 금곡동_월출동,
#   '유계동': 금곡동_유계동,
#   '유동': 금곡동_유동,
#   '유촌동': 금곡동_유촌동,
#   '이장동': 금곡동_이장동,
#   '일곡동': 금곡동_일곡동,
#   '임곡동': 금곡동_임곡동,
#   '임동': 금곡동_임동,
#   '임암동': 금곡동_임암동,
#   '장덕동': 금곡동_장덕동,
#   '장동': 금곡동_장동,
#   '장등동': 금곡동_장등동,
#   '장록동': 금곡동_장록동,
#   '장수동': 금곡동_장수동,
#   '주월동': 금곡동_주월동,
#   '중흥동': 금곡동_중흥동,
#   '지산동': 금곡동_지산동,
#   '지산동.1': 금곡동_지산동.1,
#   '지석동': 금곡동_지석동,
#   '지야동': 금곡동_지야동,
#   '지정동': 금곡동_지정동,
#   '지죽동': 금곡동_지죽동,
#   '지평동': 금곡동_지평동,
#   '진곡동': 금곡동_진곡동,
#   '진월동': 금곡동_진월동,
#   '청풍동': 금곡동_청풍동,
#   '충장동': 금곡동_충장동,
#   '충효동': 금곡동_충효동,
#   '치평동': 금곡동_치평동,
#   '칠석동': 금곡동_칠석동,
#   '태령동': 금곡동_태령동,
#   '풍암동': 금곡동_풍암동,
#   '풍향동': 금곡동_풍향동,
#   '하남동': 금곡동_하남동,
#   '하산동': 금곡동_하산동,
#   '학동': 금곡동_학동,
#   '행암동': 금곡동_행암동,
#   '호남동': 금곡동_호남동,
#   '화암동': 금곡동_화암동,
#   '화장동': 금곡동_화장동,
#   '화정동': 금곡동_화정동,
#   '황금동': 금곡동_황금동,
#   '황룡동': 금곡동_황룡동,
#   '효령동': 금곡동_효령동,
#   '흑석동': 금곡동_흑석동},
#  '금동': {'각화동': 금동_각화동,
#   '계림동': 금동_계림동,
#   '고룡동': 금동_고룡동,
#   '광산동': 금동_광산동,
#   '광산동.1': 금동_광산동.1,
#   '광천동': 금동_광천동,
#   '구동': 금동_구동,
#   '구소동': 금동_구소동,
#   '궁동': 금동_궁동,
#   '금곡동': 금동_금곡동,
#   '금동': 금동_금동,
#   '금호동': 금동_금호동,
#   '남동': 금동_남동,
#   '남산동': 금동_남산동,
#   '내남동': 금동_내남동,
#   '내방동': 금동_내방동,
#   '내산동': 금동_내산동,
#   '노대동': 금동_노대동,
#   '농성동': 금동_농성동,
#   '누문동': 금동_누문동,
#   '대산동': 금동_대산동,
#   '대의동': 금동_대의동,
#   '대인동': 금동_대인동,
#   '대지동': 금동_대지동,
#   '대촌동': 금동_대촌동,
#   '덕남동': 금동_덕남동,
#   '덕림동': 금동_덕림동,
#   '덕의동': 금동_덕의동,
#   '덕흥동': 금동_덕흥동,
#   '도금동': 금동_도금동,
#   '도덕동': 금동_도덕동,
#   '도산동': 금동_도산동,
#   '도천동': 금동_도천동,
#   '도호동': 금동_도호동,
#   '동림동': 금동_동림동,
#   '동림동.1': 금동_동림동.1,
#   '동명동': 금동_동명동,
#   '동산동': 금동_동산동,
#   '동천동': 금동_동천동,
#   '동호동': 금동_동호동,
#   '두암동': 금동_두암동,
#   '두정동': 금동_두정동,
#   '등임동': 금동_등임동,
#   '마륵동': 금동_마륵동,
#   '망월동': 금동_망월동,
#   '매곡동': 금동_매곡동,
#   '매월동': 금동_매월동,
#   '명도동': 금동_명도동,
#   '명화동': 금동_명화동,
#   '문흥동': 금동_문흥동,
#   '박호동': 금동_박호동,
#   '방림동': 금동_방림동,
#   '백운동': 금동_백운동,
#   '벽진동': 금동_벽진동,
#   '복룡동': 금동_복룡동,
#   '본덕동': 금동_본덕동,
#   '본촌동': 금동_본촌동,
#   '봉선동': 금동_봉선동,
#   '북동': 금동_북동,
#   '북산동': 금동_북산동,
#   '불로동': 금동_불로동,
#   '비아동': 금동_비아동,
#   '사동': 금동_사동,
#   '사호동': 금동_사호동,
#   '산막동': 금동_산막동,
#   '산수동': 금동_산수동,
#   '산수동.1': 금동_산수동.1,
#   '산월동': 금동_산월동,
#   '산정동': 금동_산정동,
#   '삼각동': 금동_삼각동,
#   '삼거동': 금동_삼거동,
#   '삼도동': 금동_삼도동,
#   '생용동': 금동_생용동,
#   '서동': 금동_서동,
#   '서봉동': 금동_서봉동,
#   '서석동': 금동_서석동,
#   '서창동': 금동_서창동,
#   '석정동': 금동_석정동,
#   '선교동': 금동_선교동,
#   '선동': 금동_선동,
#   '선암동': 금동_선암동,
#   '세하동': 금동_세하동,
#   '소촌동': 금동_소촌동,
#   '소태동': 금동_소태동,
#   '송대동': 금동_송대동,
#   '송산동': 금동_송산동,
#   '송정동': 금동_송정동,
#   '송촌동': 금동_송촌동,
#   '송치동': 금동_송치동,
#   '송하동': 금동_송하동,
#   '송학동': 금동_송학동,
#   '수곡동': 금동_수곡동,
#   '수기동': 금동_수기동,
#   '수완동': 금동_수완동,
#   '승촌동': 금동_승촌동,
#   '신가동': 금동_신가동,
#   '신동': 금동_신동,
#   '신룡동': 금동_신룡동,
#   '신안동': 금동_신안동,
#   '신용동': 금동_신용동,
#   '신장동': 금동_신장동,
#   '신창동': 금동_신창동,
#   '신촌동': 금동_신촌동,
#   '쌍암동': 금동_쌍암동,
#   '쌍촌동': 금동_쌍촌동,
#   '안청동': 금동_안청동,
#   '압촌동': 금동_압촌동,
#   '양과동': 금동_양과동,
#   '양동': 금동_양동,
#   '양동.1': 금동_양동.1,
#   '양림동': 금동_양림동,
#   '양산동': 금동_양산동,
#   '양산동.1': 금동_양산동.1,
#   '양촌동': 금동_양촌동,
#   '연산동': 금동_연산동,
#   '연제동': 금동_연제동,
#   '오룡동': 금동_오룡동,
#   '오산동': 금동_오산동,
#   '오선동': 금동_오선동,
#   '오운동': 금동_오운동,
#   '오치동': 금동_오치동,
#   '옥동': 금동_옥동,
#   '왕동': 금동_왕동,
#   '요기동': 금동_요기동,
#   '용강동': 금동_용강동,
#   '용곡동': 금동_용곡동,
#   '용동': 금동_용동,
#   '용두동': 금동_용두동,
#   '용두동.1': 금동_용두동.1,
#   '용봉동': 금동_용봉동,
#   '용봉동.1': 금동_용봉동.1,
#   '용산동': 금동_용산동,
#   '용연동': 금동_용연동,
#   '용전동': 금동_용전동,
#   '우산동': 금동_우산동,
#   '우산동.1': 금동_우산동.1,
#   '운남동': 금동_운남동,
#   '운림동': 금동_운림동,
#   '운수동': 금동_운수동,
#   '운암동': 금동_운암동,
#   '운정동': 금동_운정동,
#   '원산동': 금동_원산동,
#   '월계동': 금동_월계동,
#   '월곡동': 금동_월곡동,
#   '월남동': 금동_월남동,
#   '월산동': 금동_월산동,
#   '월성동': 금동_월성동,
#   '월전동': 금동_월전동,
#   '월출동': 금동_월출동,
#   '유계동': 금동_유계동,
#   '유동': 금동_유동,
#   '유촌동': 금동_유촌동,
#   '이장동': 금동_이장동,
#   '일곡동': 금동_일곡동,
#   '임곡동': 금동_임곡동,
#   '임동': 금동_임동,
#   '임암동': 금동_임암동,
#   '장덕동': 금동_장덕동,
#   '장동': 금동_장동,
#   '장등동': 금동_장등동,
#   '장록동': 금동_장록동,
#   '장수동': 금동_장수동,
#   '주월동': 금동_주월동,
#   '중흥동': 금동_중흥동,
#   '지산동': 금동_지산동,
#   '지산동.1': 금동_지산동.1,
#   '지석동': 금동_지석동,
#   '지야동': 금동_지야동,
#   '지정동': 금동_지정동,
#   '지죽동': 금동_지죽동,
#   '지평동': 금동_지평동,
#   '진곡동': 금동_진곡동,
#   '진월동': 금동_진월동,
#   '청풍동': 금동_청풍동,
#   '충장동': 금동_충장동,
#   '충효동': 금동_충효동,
#   '치평동': 금동_치평동,
#   '칠석동': 금동_칠석동,
#   '태령동': 금동_태령동,
#   '풍암동': 금동_풍암동,
#   '풍향동': 금동_풍향동,
#   '하남동': 금동_하남동,
#   '하산동': 금동_하산동,
#   '학동': 금동_학동,
#   '행암동': 금동_행암동,
#   '호남동': 금동_호남동,
#   '화암동': 금동_화암동,
#   '화장동': 금동_화장동,
#   '화정동': 금동_화정동,
#   '황금동': 금동_황금동,
#   '황룡동': 금동_황룡동,
#   '효령동': 금동_효령동,
#   '흑석동': 금동_흑석동},
#  '금호동': {'각화동': 금호동_각화동,
#   '계림동': 금호동_계림동,
#   '고룡동': 금호동_고룡동,
#   '광산동': 금호동_광산동,
#   '광산동.1': 금호동_광산동.1,
#   '광천동': 금호동_광천동,
#   '구동': 금호동_구동,
#   '구소동': 금호동_구소동,
#   '궁동': 금호동_궁동,
#   '금곡동': 금호동_금곡동,
#   '금동': 금호동_금동,
#   '금호동': 금호동_금호동,
#   '남동': 금호동_남동,
#   '남산동': 금호동_남산동,
#   '내남동': 금호동_내남동,
#   '내방동': 금호동_내방동,
#   '내산동': 금호동_내산동,
#   '노대동': 금호동_노대동,
#   '농성동': 금호동_농성동,
#   '누문동': 금호동_누문동,
#   '대산동': 금호동_대산동,
#   '대의동': 금호동_대의동,
#   '대인동': 금호동_대인동,
#   '대지동': 금호동_대지동,
#   '대촌동': 금호동_대촌동,
#   '덕남동': 금호동_덕남동,
#   '덕림동': 금호동_덕림동,
#   '덕의동': 금호동_덕의동,
#   '덕흥동': 금호동_덕흥동,
#   '도금동': 금호동_도금동,
#   '도덕동': 금호동_도덕동,
#   '도산동': 금호동_도산동,
#   '도천동': 금호동_도천동,
#   '도호동': 금호동_도호동,
#   '동림동': 금호동_동림동,
#   '동림동.1': 금호동_동림동.1,
#   '동명동': 금호동_동명동,
#   '동산동': 금호동_동산동,
#   '동천동': 금호동_동천동,
#   '동호동': 금호동_동호동,
#   '두암동': 금호동_두암동,
#   '두정동': 금호동_두정동,
#   '등임동': 금호동_등임동,
#   '마륵동': 금호동_마륵동,
#   '망월동': 금호동_망월동,
#   '매곡동': 금호동_매곡동,
#   '매월동': 금호동_매월동,
#   '명도동': 금호동_명도동,
#   '명화동': 금호동_명화동,
#   '문흥동': 금호동_문흥동,
#   '박호동': 금호동_박호동,
#   '방림동': 금호동_방림동,
#   '백운동': 금호동_백운동,
#   '벽진동': 금호동_벽진동,
#   '복룡동': 금호동_복룡동,
#   '본덕동': 금호동_본덕동,
#   '본촌동': 금호동_본촌동,
#   '봉선동': 금호동_봉선동,
#   '북동': 금호동_북동,
#   '북산동': 금호동_북산동,
#   '불로동': 금호동_불로동,
#   '비아동': 금호동_비아동,
#   '사동': 금호동_사동,
#   '사호동': 금호동_사호동,
#   '산막동': 금호동_산막동,
#   '산수동': 금호동_산수동,
#   '산수동.1': 금호동_산수동.1,
#   '산월동': 금호동_산월동,
#   '산정동': 금호동_산정동,
#   '삼각동': 금호동_삼각동,
#   '삼거동': 금호동_삼거동,
#   '삼도동': 금호동_삼도동,
#   '생용동': 금호동_생용동,
#   '서동': 금호동_서동,
#   '서봉동': 금호동_서봉동,
#   '서석동': 금호동_서석동,
#   '서창동': 금호동_서창동,
#   '석정동': 금호동_석정동,
#   '선교동': 금호동_선교동,
#   '선동': 금호동_선동,
#   '선암동': 금호동_선암동,
#   '세하동': 금호동_세하동,
#   '소촌동': 금호동_소촌동,
#   '소태동': 금호동_소태동,
#   '송대동': 금호동_송대동,
#   '송산동': 금호동_송산동,
#   '송정동': 금호동_송정동,
#   '송촌동': 금호동_송촌동,
#   '송치동': 금호동_송치동,
#   '송하동': 금호동_송하동,
#   '송학동': 금호동_송학동,
#   '수곡동': 금호동_수곡동,
#   '수기동': 금호동_수기동,
#   '수완동': 금호동_수완동,
#   '승촌동': 금호동_승촌동,
#   '신가동': 금호동_신가동,
#   '신동': 금호동_신동,
#   '신룡동': 금호동_신룡동,
#   '신안동': 금호동_신안동,
#   '신용동': 금호동_신용동,
#   '신장동': 금호동_신장동,
#   '신창동': 금호동_신창동,
#   '신촌동': 금호동_신촌동,
#   '쌍암동': 금호동_쌍암동,
#   '쌍촌동': 금호동_쌍촌동,
#   '안청동': 금호동_안청동,
#   '압촌동': 금호동_압촌동,
#   '양과동': 금호동_양과동,
#   '양동': 금호동_양동,
#   '양동.1': 금호동_양동.1,
#   '양림동': 금호동_양림동,
#   '양산동': 금호동_양산동,
#   '양산동.1': 금호동_양산동.1,
#   '양촌동': 금호동_양촌동,
#   '연산동': 금호동_연산동,
#   '연제동': 금호동_연제동,
#   '오룡동': 금호동_오룡동,
#   '오산동': 금호동_오산동,
#   '오선동': 금호동_오선동,
#   '오운동': 금호동_오운동,
#   '오치동': 금호동_오치동,
#   '옥동': 금호동_옥동,
#   '왕동': 금호동_왕동,
#   '요기동': 금호동_요기동,
#   '용강동': 금호동_용강동,
#   '용곡동': 금호동_용곡동,
#   '용동': 금호동_용동,
#   '용두동': 금호동_용두동,
#   '용두동.1': 금호동_용두동.1,
#   '용봉동': 금호동_용봉동,
#   '용봉동.1': 금호동_용봉동.1,
#   '용산동': 금호동_용산동,
#   '용연동': 금호동_용연동,
#   '용전동': 금호동_용전동,
#   '우산동': 금호동_우산동,
#   '우산동.1': 금호동_우산동.1,
#   '운남동': 금호동_운남동,
#   '운림동': 금호동_운림동,
#   '운수동': 금호동_운수동,
#   '운암동': 금호동_운암동,
#   '운정동': 금호동_운정동,
#   '원산동': 금호동_원산동,
#   '월계동': 금호동_월계동,
#   '월곡동': 금호동_월곡동,
#   '월남동': 금호동_월남동,
#   '월산동': 금호동_월산동,
#   '월성동': 금호동_월성동,
#   '월전동': 금호동_월전동,
#   '월출동': 금호동_월출동,
#   '유계동': 금호동_유계동,
#   '유동': 금호동_유동,
#   '유촌동': 금호동_유촌동,
#   '이장동': 금호동_이장동,
#   '일곡동': 금호동_일곡동,
#   '임곡동': 금호동_임곡동,
#   '임동': 금호동_임동,
#   '임암동': 금호동_임암동,
#   '장덕동': 금호동_장덕동,
#   '장동': 금호동_장동,
#   '장등동': 금호동_장등동,
#   '장록동': 금호동_장록동,
#   '장수동': 금호동_장수동,
#   '주월동': 금호동_주월동,
#   '중흥동': 금호동_중흥동,
#   '지산동': 금호동_지산동,
#   '지산동.1': 금호동_지산동.1,
#   '지석동': 금호동_지석동,
#   '지야동': 금호동_지야동,
#   '지정동': 금호동_지정동,
#   '지죽동': 금호동_지죽동,
#   '지평동': 금호동_지평동,
#   '진곡동': 금호동_진곡동,
#   '진월동': 금호동_진월동,
#   '청풍동': 금호동_청풍동,
#   '충장동': 금호동_충장동,
#   '충효동': 금호동_충효동,
#   '치평동': 금호동_치평동,
#   '칠석동': 금호동_칠석동,
#   '태령동': 금호동_태령동,
#   '풍암동': 금호동_풍암동,
#   '풍향동': 금호동_풍향동,
#   '하남동': 금호동_하남동,
#   '하산동': 금호동_하산동,
#   '학동': 금호동_학동,
#   '행암동': 금호동_행암동,
#   '호남동': 금호동_호남동,
#   '화암동': 금호동_화암동,
#   '화장동': 금호동_화장동,
#   '화정동': 금호동_화정동,
#   '황금동': 금호동_황금동,
#   '황룡동': 금호동_황룡동,
#   '효령동': 금호동_효령동,
#   '흑석동': 금호동_흑석동},
#  '남동': {'각화동': 남동_각화동,
#   '계림동': 남동_계림동,
#   '고룡동': 남동_고룡동,
#   '광산동': 남동_광산동,
#   '광산동.1': 남동_광산동.1,
#   '광천동': 남동_광천동,
#   '구동': 남동_구동,
#   '구소동': 남동_구소동,
#   '궁동': 남동_궁동,
#   '금곡동': 남동_금곡동,
#   '금동': 남동_금동,
#   '금호동': 남동_금호동,
#   '남동': 남동_남동,
#   '남산동': 남동_남산동,
#   '내남동': 남동_내남동,
#   '내방동': 남동_내방동,
#   '내산동': 남동_내산동,
#   '노대동': 남동_노대동,
#   '농성동': 남동_농성동,
#   '누문동': 남동_누문동,
#   '대산동': 남동_대산동,
#   '대의동': 남동_대의동,
#   '대인동': 남동_대인동,
#   '대지동': 남동_대지동,
#   '대촌동': 남동_대촌동,
#   '덕남동': 남동_덕남동,
#   '덕림동': 남동_덕림동,
#   '덕의동': 남동_덕의동,
#   '덕흥동': 남동_덕흥동,
#   '도금동': 남동_도금동,
#   '도덕동': 남동_도덕동,
#   '도산동': 남동_도산동,
#   '도천동': 남동_도천동,
#   '도호동': 남동_도호동,
#   '동림동': 남동_동림동,
#   '동림동.1': 남동_동림동.1,
#   '동명동': 남동_동명동,
#   '동산동': 남동_동산동,
#   '동천동': 남동_동천동,
#   '동호동': 남동_동호동,
#   '두암동': 남동_두암동,
#   '두정동': 남동_두정동,
#   '등임동': 남동_등임동,
#   '마륵동': 남동_마륵동,
#   '망월동': 남동_망월동,
#   '매곡동': 남동_매곡동,
#   '매월동': 남동_매월동,
#   '명도동': 남동_명도동,
#   '명화동': 남동_명화동,
#   '문흥동': 남동_문흥동,
#   '박호동': 남동_박호동,
#   '방림동': 남동_방림동,
#   '백운동': 남동_백운동,
#   '벽진동': 남동_벽진동,
#   '복룡동': 남동_복룡동,
#   '본덕동': 남동_본덕동,
#   '본촌동': 남동_본촌동,
#   '봉선동': 남동_봉선동,
#   '북동': 남동_북동,
#   '북산동': 남동_북산동,
#   '불로동': 남동_불로동,
#   '비아동': 남동_비아동,
#   '사동': 남동_사동,
#   '사호동': 남동_사호동,
#   '산막동': 남동_산막동,
#   '산수동': 남동_산수동,
#   '산수동.1': 남동_산수동.1,
#   '산월동': 남동_산월동,
#   '산정동': 남동_산정동,
#   '삼각동': 남동_삼각동,
#   '삼거동': 남동_삼거동,
#   '삼도동': 남동_삼도동,
#   '생용동': 남동_생용동,
#   '서동': 남동_서동,
#   '서봉동': 남동_서봉동,
#   '서석동': 남동_서석동,
#   '서창동': 남동_서창동,
#   '석정동': 남동_석정동,
#   '선교동': 남동_선교동,
#   '선동': 남동_선동,
#   '선암동': 남동_선암동,
#   '세하동': 남동_세하동,
#   '소촌동': 남동_소촌동,
#   '소태동': 남동_소태동,
#   '송대동': 남동_송대동,
#   '송산동': 남동_송산동,
#   '송정동': 남동_송정동,
#   '송촌동': 남동_송촌동,
#   '송치동': 남동_송치동,
#   '송하동': 남동_송하동,
#   '송학동': 남동_송학동,
#   '수곡동': 남동_수곡동,
#   '수기동': 남동_수기동,
#   '수완동': 남동_수완동,
#   '승촌동': 남동_승촌동,
#   '신가동': 남동_신가동,
#   '신동': 남동_신동,
#   '신룡동': 남동_신룡동,
#   '신안동': 남동_신안동,
#   '신용동': 남동_신용동,
#   '신장동': 남동_신장동,
#   '신창동': 남동_신창동,
#   '신촌동': 남동_신촌동,
#   '쌍암동': 남동_쌍암동,
#   '쌍촌동': 남동_쌍촌동,
#   '안청동': 남동_안청동,
#   '압촌동': 남동_압촌동,
#   '양과동': 남동_양과동,
#   '양동': 남동_양동,
#   '양동.1': 남동_양동.1,
#   '양림동': 남동_양림동,
#   '양산동': 남동_양산동,
#   '양산동.1': 남동_양산동.1,
#   '양촌동': 남동_양촌동,
#   '연산동': 남동_연산동,
#   '연제동': 남동_연제동,
#   '오룡동': 남동_오룡동,
#   '오산동': 남동_오산동,
#   '오선동': 남동_오선동,
#   '오운동': 남동_오운동,
#   '오치동': 남동_오치동,
#   '옥동': 남동_옥동,
#   '왕동': 남동_왕동,
#   '요기동': 남동_요기동,
#   '용강동': 남동_용강동,
#   '용곡동': 남동_용곡동,
#   '용동': 남동_용동,
#   '용두동': 남동_용두동,
#   '용두동.1': 남동_용두동.1,
#   '용봉동': 남동_용봉동,
#   '용봉동.1': 남동_용봉동.1,
#   '용산동': 남동_용산동,
#   '용연동': 남동_용연동,
#   '용전동': 남동_용전동,
#   '우산동': 남동_우산동,
#   '우산동.1': 남동_우산동.1,
#   '운남동': 남동_운남동,
#   '운림동': 남동_운림동,
#   '운수동': 남동_운수동,
#   '운암동': 남동_운암동,
#   '운정동': 남동_운정동,
#   '원산동': 남동_원산동,
#   '월계동': 남동_월계동,
#   '월곡동': 남동_월곡동,
#   '월남동': 남동_월남동,
#   '월산동': 남동_월산동,
#   '월성동': 남동_월성동,
#   '월전동': 남동_월전동,
#   '월출동': 남동_월출동,
#   '유계동': 남동_유계동,
#   '유동': 남동_유동,
#   '유촌동': 남동_유촌동,
#   '이장동': 남동_이장동,
#   '일곡동': 남동_일곡동,
#   '임곡동': 남동_임곡동,
#   '임동': 남동_임동,
#   '임암동': 남동_임암동,
#   '장덕동': 남동_장덕동,
#   '장동': 남동_장동,
#   '장등동': 남동_장등동,
#   '장록동': 남동_장록동,
#   '장수동': 남동_장수동,
#   '주월동': 남동_주월동,
#   '중흥동': 남동_중흥동,
#   '지산동': 남동_지산동,
#   '지산동.1': 남동_지산동.1,
#   '지석동': 남동_지석동,
#   '지야동': 남동_지야동,
#   '지정동': 남동_지정동,
#   '지죽동': 남동_지죽동,
#   '지평동': 남동_지평동,
#   '진곡동': 남동_진곡동,
#   '진월동': 남동_진월동,
#   '청풍동': 남동_청풍동,
#   '충장동': 남동_충장동,
#   '충효동': 남동_충효동,
#   '치평동': 남동_치평동,
#   '칠석동': 남동_칠석동,
#   '태령동': 남동_태령동,
#   '풍암동': 남동_풍암동,
#   '풍향동': 남동_풍향동,
#   '하남동': 남동_하남동,
#   '하산동': 남동_하산동,
#   '학동': 남동_학동,
#   '행암동': 남동_행암동,
#   '호남동': 남동_호남동,
#   '화암동': 남동_화암동,
#   '화장동': 남동_화장동,
#   '화정동': 남동_화정동,
#   '황금동': 남동_황금동,
#   '황룡동': 남동_황룡동,
#   '효령동': 남동_효령동,
#   '흑석동': 남동_흑석동},
#  '남산동': {'각화동': 남산동_각화동,
#   '계림동': 남산동_계림동,
#   '고룡동': 남산동_고룡동,
#   '광산동': 남산동_광산동,
#   '광산동.1': 남산동_광산동.1,
#   '광천동': 남산동_광천동,
#   '구동': 남산동_구동,
#   '구소동': 남산동_구소동,
#   '궁동': 남산동_궁동,
#   '금곡동': 남산동_금곡동,
#   '금동': 남산동_금동,
#   '금호동': 남산동_금호동,
#   '남동': 남산동_남동,
#   '남산동': 남산동_남산동,
#   '내남동': 남산동_내남동,
#   '내방동': 남산동_내방동,
#   '내산동': 남산동_내산동,
#   '노대동': 남산동_노대동,
#   '농성동': 남산동_농성동,
#   '누문동': 남산동_누문동,
#   '대산동': 남산동_대산동,
#   '대의동': 남산동_대의동,
#   '대인동': 남산동_대인동,
#   '대지동': 남산동_대지동,
#   '대촌동': 남산동_대촌동,
#   '덕남동': 남산동_덕남동,
#   '덕림동': 남산동_덕림동,
#   '덕의동': 남산동_덕의동,
#   '덕흥동': 남산동_덕흥동,
#   '도금동': 남산동_도금동,
#   '도덕동': 남산동_도덕동,
#   '도산동': 남산동_도산동,
#   '도천동': 남산동_도천동,
#   '도호동': 남산동_도호동,
#   '동림동': 남산동_동림동,
#   '동림동.1': 남산동_동림동.1,
#   '동명동': 남산동_동명동,
#   '동산동': 남산동_동산동,
#   '동천동': 남산동_동천동,
#   '동호동': 남산동_동호동,
#   '두암동': 남산동_두암동,
#   '두정동': 남산동_두정동,
#   '등임동': 남산동_등임동,
#   '마륵동': 남산동_마륵동,
#   '망월동': 남산동_망월동,
#   '매곡동': 남산동_매곡동,
#   '매월동': 남산동_매월동,
#   '명도동': 남산동_명도동,
#   '명화동': 남산동_명화동,
#   '문흥동': 남산동_문흥동,
#   '박호동': 남산동_박호동,
#   '방림동': 남산동_방림동,
#   '백운동': 남산동_백운동,
#   '벽진동': 남산동_벽진동,
#   '복룡동': 남산동_복룡동,
#   '본덕동': 남산동_본덕동,
#   '본촌동': 남산동_본촌동,
#   '봉선동': 남산동_봉선동,
#   '북동': 남산동_북동,
#   '북산동': 남산동_북산동,
#   '불로동': 남산동_불로동,
#   '비아동': 남산동_비아동,
#   '사동': 남산동_사동,
#   '사호동': 남산동_사호동,
#   '산막동': 남산동_산막동,
#   '산수동': 남산동_산수동,
#   '산수동.1': 남산동_산수동.1,
#   '산월동': 남산동_산월동,
#   '산정동': 남산동_산정동,
#   '삼각동': 남산동_삼각동,
#   '삼거동': 남산동_삼거동,
#   '삼도동': 남산동_삼도동,
#   '생용동': 남산동_생용동,
#   '서동': 남산동_서동,
#   '서봉동': 남산동_서봉동,
#   '서석동': 남산동_서석동,
#   '서창동': 남산동_서창동,
#   '석정동': 남산동_석정동,
#   '선교동': 남산동_선교동,
#   '선동': 남산동_선동,
#   '선암동': 남산동_선암동,
#   '세하동': 남산동_세하동,
#   '소촌동': 남산동_소촌동,
#   '소태동': 남산동_소태동,
#   '송대동': 남산동_송대동,
#   '송산동': 남산동_송산동,
#   '송정동': 남산동_송정동,
#   '송촌동': 남산동_송촌동,
#   '송치동': 남산동_송치동,
#   '송하동': 남산동_송하동,
#   '송학동': 남산동_송학동,
#   '수곡동': 남산동_수곡동,
#   '수기동': 남산동_수기동,
#   '수완동': 남산동_수완동,
#   '승촌동': 남산동_승촌동,
#   '신가동': 남산동_신가동,
#   '신동': 남산동_신동,
#   '신룡동': 남산동_신룡동,
#   '신안동': 남산동_신안동,
#   '신용동': 남산동_신용동,
#   '신장동': 남산동_신장동,
#   '신창동': 남산동_신창동,
#   '신촌동': 남산동_신촌동,
#   '쌍암동': 남산동_쌍암동,
#   '쌍촌동': 남산동_쌍촌동,
#   '안청동': 남산동_안청동,
#   '압촌동': 남산동_압촌동,
#   '양과동': 남산동_양과동,
#   '양동': 남산동_양동,
#   '양동.1': 남산동_양동.1,
#   '양림동': 남산동_양림동,
#   '양산동': 남산동_양산동,
#   '양산동.1': 남산동_양산동.1,
#   '양촌동': 남산동_양촌동,
#   '연산동': 남산동_연산동,
#   '연제동': 남산동_연제동,
#   '오룡동': 남산동_오룡동,
#   '오산동': 남산동_오산동,
#   '오선동': 남산동_오선동,
#   '오운동': 남산동_오운동,
#   '오치동': 남산동_오치동,
#   '옥동': 남산동_옥동,
#   '왕동': 남산동_왕동,
#   '요기동': 남산동_요기동,
#   '용강동': 남산동_용강동,
#   '용곡동': 남산동_용곡동,
#   '용동': 남산동_용동,
#   '용두동': 남산동_용두동,
#   '용두동.1': 남산동_용두동.1,
#   '용봉동': 남산동_용봉동,
#   '용봉동.1': 남산동_용봉동.1,
#   '용산동': 남산동_용산동,
#   '용연동': 남산동_용연동,
#   '용전동': 남산동_용전동,
#   '우산동': 남산동_우산동,
#   '우산동.1': 남산동_우산동.1,
#   '운남동': 남산동_운남동,
#   '운림동': 남산동_운림동,
#   '운수동': 남산동_운수동,
#   '운암동': 남산동_운암동,
#   '운정동': 남산동_운정동,
#   '원산동': 남산동_원산동,
#   '월계동': 남산동_월계동,
#   '월곡동': 남산동_월곡동,
#   '월남동': 남산동_월남동,
#   '월산동': 남산동_월산동,
#   '월성동': 남산동_월성동,
#   '월전동': 남산동_월전동,
#   '월출동': 남산동_월출동,
#   '유계동': 남산동_유계동,
#   '유동': 남산동_유동,
#   '유촌동': 남산동_유촌동,
#   '이장동': 남산동_이장동,
#   '일곡동': 남산동_일곡동,
#   '임곡동': 남산동_임곡동,
#   '임동': 남산동_임동,
#   '임암동': 남산동_임암동,
#   '장덕동': 남산동_장덕동,
#   '장동': 남산동_장동,
#   '장등동': 남산동_장등동,
#   '장록동': 남산동_장록동,
#   '장수동': 남산동_장수동,
#   '주월동': 남산동_주월동,
#   '중흥동': 남산동_중흥동,
#   '지산동': 남산동_지산동,
#   '지산동.1': 남산동_지산동.1,
#   '지석동': 남산동_지석동,
#   '지야동': 남산동_지야동,
#   '지정동': 남산동_지정동,
#   '지죽동': 남산동_지죽동,
#   '지평동': 남산동_지평동,
#   '진곡동': 남산동_진곡동,
# ...
#   '선동': 화정동_선동,
#   '선암동': 화정동_선암동,
#   '세하동': 화정동_세하동,
#   '소촌동': 화정동_소촌동,
#   '소태동': 화정동_소태동,
#   '송대동': 화정동_송대동,
#   '송산동': 화정동_송산동,
#   '송정동': 화정동_송정동,
#   '송촌동': 화정동_송촌동,
#   '송치동': 화정동_송치동,
#   '송하동': 화정동_송하동,
#   '송학동': 화정동_송학동,
#   '수곡동': 화정동_수곡동,
#   '수기동': 화정동_수기동,
#   '수완동': 화정동_수완동,
#   '승촌동': 화정동_승촌동,
#   '신가동': 화정동_신가동,
#   '신동': 화정동_신동,
#   '신룡동': 화정동_신룡동,
#   '신안동': 화정동_신안동,
#   '신용동': 화정동_신용동,
#   '신장동': 화정동_신장동,
#   '신창동': 화정동_신창동,
#   '신촌동': 화정동_신촌동,
#   '쌍암동': 화정동_쌍암동,
#   '쌍촌동': 화정동_쌍촌동,
#   '안청동': 화정동_안청동,
#   '압촌동': 화정동_압촌동,
#   '양과동': 화정동_양과동,
#   '양동': 화정동_양동,
#   '양동.1': 화정동_양동.1,
#   '양림동': 화정동_양림동,
#   '양산동': 화정동_양산동,
#   '양산동.1': 화정동_양산동.1,
#   '양촌동': 화정동_양촌동,
#   '연산동': 화정동_연산동,
#   '연제동': 화정동_연제동,
#   '오룡동': 화정동_오룡동,
#   '오산동': 화정동_오산동,
#   '오선동': 화정동_오선동,
#   '오운동': 화정동_오운동,
#   '오치동': 화정동_오치동,
#   '옥동': 화정동_옥동,
#   '왕동': 화정동_왕동,
#   '요기동': 화정동_요기동,
#   '용강동': 화정동_용강동,
#   '용곡동': 화정동_용곡동,
#   '용동': 화정동_용동,
#   '용두동': 화정동_용두동,
#   '용두동.1': 화정동_용두동.1,
#   '용봉동': 화정동_용봉동,
#   '용봉동.1': 화정동_용봉동.1,
#   '용산동': 화정동_용산동,
#   '용연동': 화정동_용연동,
#   '용전동': 화정동_용전동,
#   '우산동': 화정동_우산동,
#   '우산동.1': 화정동_우산동.1,
#   '운남동': 화정동_운남동,
#   '운림동': 화정동_운림동,
#   '운수동': 화정동_운수동,
#   '운암동': 화정동_운암동,
#   '운정동': 화정동_운정동,
#   '원산동': 화정동_원산동,
#   '월계동': 화정동_월계동,
#   '월곡동': 화정동_월곡동,
#   '월남동': 화정동_월남동,
#   '월산동': 화정동_월산동,
#   '월성동': 화정동_월성동,
#   '월전동': 화정동_월전동,
#   '월출동': 화정동_월출동,
#   '유계동': 화정동_유계동,
#   '유동': 화정동_유동,
#   '유촌동': 화정동_유촌동,
#   '이장동': 화정동_이장동,
#   '일곡동': 화정동_일곡동,
#   '임곡동': 화정동_임곡동,
#   '임동': 화정동_임동,
#   '임암동': 화정동_임암동,
#   '장덕동': 화정동_장덕동,
#   '장동': 화정동_장동,
#   '장등동': 화정동_장등동,
#   '장록동': 화정동_장록동,
#   '장수동': 화정동_장수동,
#   '주월동': 화정동_주월동,
#   '중흥동': 화정동_중흥동,
#   '지산동': 화정동_지산동,
#   '지산동.1': 화정동_지산동.1,
#   '지석동': 화정동_지석동,
#   '지야동': 화정동_지야동,
#   '지정동': 화정동_지정동,
#   '지죽동': 화정동_지죽동,
#   '지평동': 화정동_지평동,
#   '진곡동': 화정동_진곡동,
#   '진월동': 화정동_진월동,
#   '청풍동': 화정동_청풍동,
#   '충장동': 화정동_충장동,
#   '충효동': 화정동_충효동,
#   '치평동': 화정동_치평동,
#   '칠석동': 화정동_칠석동,
#   '태령동': 화정동_태령동,
#   '풍암동': 화정동_풍암동,
#   '풍향동': 화정동_풍향동,
#   '하남동': 화정동_하남동,
#   '하산동': 화정동_하산동,
#   '학동': 화정동_학동,
#   '행암동': 화정동_행암동,
#   '호남동': 화정동_호남동,
#   '화암동': 화정동_화암동,
#   '화장동': 화정동_화장동,
#   '화정동': 화정동_화정동,
#   '황금동': 화정동_황금동,
#   '황룡동': 화정동_황룡동,
#   '효령동': 화정동_효령동,
#   '흑석동': 화정동_흑석동},
#  '황금동': {'각화동': 황금동_각화동,
#   '계림동': 황금동_계림동,
#   '고룡동': 황금동_고룡동,
#   '광산동': 황금동_광산동,
#   '광산동.1': 황금동_광산동.1,
#   '광천동': 황금동_광천동,
#   '구동': 황금동_구동,
#   '구소동': 황금동_구소동,
#   '궁동': 황금동_궁동,
#   '금곡동': 황금동_금곡동,
#   '금동': 황금동_금동,
#   '금호동': 황금동_금호동,
#   '남동': 황금동_남동,
#   '남산동': 황금동_남산동,
#   '내남동': 황금동_내남동,
#   '내방동': 황금동_내방동,
#   '내산동': 황금동_내산동,
#   '노대동': 황금동_노대동,
#   '농성동': 황금동_농성동,
#   '누문동': 황금동_누문동,
#   '대산동': 황금동_대산동,
#   '대의동': 황금동_대의동,
#   '대인동': 황금동_대인동,
#   '대지동': 황금동_대지동,
#   '대촌동': 황금동_대촌동,
#   '덕남동': 황금동_덕남동,
#   '덕림동': 황금동_덕림동,
#   '덕의동': 황금동_덕의동,
#   '덕흥동': 황금동_덕흥동,
#   '도금동': 황금동_도금동,
#   '도덕동': 황금동_도덕동,
#   '도산동': 황금동_도산동,
#   '도천동': 황금동_도천동,
#   '도호동': 황금동_도호동,
#   '동림동': 황금동_동림동,
#   '동림동.1': 황금동_동림동.1,
#   '동명동': 황금동_동명동,
#   '동산동': 황금동_동산동,
#   '동천동': 황금동_동천동,
#   '동호동': 황금동_동호동,
#   '두암동': 황금동_두암동,
#   '두정동': 황금동_두정동,
#   '등임동': 황금동_등임동,
#   '마륵동': 황금동_마륵동,
#   '망월동': 황금동_망월동,
#   '매곡동': 황금동_매곡동,
#   '매월동': 황금동_매월동,
#   '명도동': 황금동_명도동,
#   '명화동': 황금동_명화동,
#   '문흥동': 황금동_문흥동,
#   '박호동': 황금동_박호동,
#   '방림동': 황금동_방림동,
#   '백운동': 황금동_백운동,
#   '벽진동': 황금동_벽진동,
#   '복룡동': 황금동_복룡동,
#   '본덕동': 황금동_본덕동,
#   '본촌동': 황금동_본촌동,
#   '봉선동': 황금동_봉선동,
#   '북동': 황금동_북동,
#   '북산동': 황금동_북산동,
#   '불로동': 황금동_불로동,
#   '비아동': 황금동_비아동,
#   '사동': 황금동_사동,
#   '사호동': 황금동_사호동,
#   '산막동': 황금동_산막동,
#   '산수동': 황금동_산수동,
#   '산수동.1': 황금동_산수동.1,
#   '산월동': 황금동_산월동,
#   '산정동': 황금동_산정동,
#   '삼각동': 황금동_삼각동,
#   '삼거동': 황금동_삼거동,
#   '삼도동': 황금동_삼도동,
#   '생용동': 황금동_생용동,
#   '서동': 황금동_서동,
#   '서봉동': 황금동_서봉동,
#   '서석동': 황금동_서석동,
#   '서창동': 황금동_서창동,
#   '석정동': 황금동_석정동,
#   '선교동': 황금동_선교동,
#   '선동': 황금동_선동,
#   '선암동': 황금동_선암동,
#   '세하동': 황금동_세하동,
#   '소촌동': 황금동_소촌동,
#   '소태동': 황금동_소태동,
#   '송대동': 황금동_송대동,
#   '송산동': 황금동_송산동,
#   '송정동': 황금동_송정동,
#   '송촌동': 황금동_송촌동,
#   '송치동': 황금동_송치동,
#   '송하동': 황금동_송하동,
#   '송학동': 황금동_송학동,
#   '수곡동': 황금동_수곡동,
#   '수기동': 황금동_수기동,
#   '수완동': 황금동_수완동,
#   '승촌동': 황금동_승촌동,
#   '신가동': 황금동_신가동,
#   '신동': 황금동_신동,
#   '신룡동': 황금동_신룡동,
#   '신안동': 황금동_신안동,
#   '신용동': 황금동_신용동,
#   '신장동': 황금동_신장동,
#   '신창동': 황금동_신창동,
#   '신촌동': 황금동_신촌동,
#   '쌍암동': 황금동_쌍암동,
#   '쌍촌동': 황금동_쌍촌동,
#   '안청동': 황금동_안청동,
#   '압촌동': 황금동_압촌동,
#   '양과동': 황금동_양과동,
#   '양동': 황금동_양동,
#   '양동.1': 황금동_양동.1,
#   '양림동': 황금동_양림동,
#   '양산동': 황금동_양산동,
#   '양산동.1': 황금동_양산동.1,
#   '양촌동': 황금동_양촌동,
#   '연산동': 황금동_연산동,
#   '연제동': 황금동_연제동,
#   '오룡동': 황금동_오룡동,
#   '오산동': 황금동_오산동,
#   '오선동': 황금동_오선동,
#   '오운동': 황금동_오운동,
#   '오치동': 황금동_오치동,
#   '옥동': 황금동_옥동,
#   '왕동': 황금동_왕동,
#   '요기동': 황금동_요기동,
#   '용강동': 황금동_용강동,
#   '용곡동': 황금동_용곡동,
#   '용동': 황금동_용동,
#   '용두동': 황금동_용두동,
#   '용두동.1': 황금동_용두동.1,
#   '용봉동': 황금동_용봉동,
#   '용봉동.1': 황금동_용봉동.1,
#   '용산동': 황금동_용산동,
#   '용연동': 황금동_용연동,
#   '용전동': 황금동_용전동,
#   '우산동': 황금동_우산동,
#   '우산동.1': 황금동_우산동.1,
#   '운남동': 황금동_운남동,
#   '운림동': 황금동_운림동,
#   '운수동': 황금동_운수동,
#   '운암동': 황금동_운암동,
#   '운정동': 황금동_운정동,
#   '원산동': 황금동_원산동,
#   '월계동': 황금동_월계동,
#   '월곡동': 황금동_월곡동,
#   '월남동': 황금동_월남동,
#   '월산동': 황금동_월산동,
#   '월성동': 황금동_월성동,
#   '월전동': 황금동_월전동,
#   '월출동': 황금동_월출동,
#   '유계동': 황금동_유계동,
#   '유동': 황금동_유동,
#   '유촌동': 황금동_유촌동,
#   '이장동': 황금동_이장동,
#   '일곡동': 황금동_일곡동,
#   '임곡동': 황금동_임곡동,
#   '임동': 황금동_임동,
#   '임암동': 황금동_임암동,
#   '장덕동': 황금동_장덕동,
#   '장동': 황금동_장동,
#   '장등동': 황금동_장등동,
#   '장록동': 황금동_장록동,
#   '장수동': 황금동_장수동,
#   '주월동': 황금동_주월동,
#   '중흥동': 황금동_중흥동,
#   '지산동': 황금동_지산동,
#   '지산동.1': 황금동_지산동.1,
#   '지석동': 황금동_지석동,
#   '지야동': 황금동_지야동,
#   '지정동': 황금동_지정동,
#   '지죽동': 황금동_지죽동,
#   '지평동': 황금동_지평동,
#   '진곡동': 황금동_진곡동,
#   '진월동': 황금동_진월동,
#   '청풍동': 황금동_청풍동,
#   '충장동': 황금동_충장동,
#   '충효동': 황금동_충효동,
#   '치평동': 황금동_치평동,
#   '칠석동': 황금동_칠석동,
#   '태령동': 황금동_태령동,
#   '풍암동': 황금동_풍암동,
#   '풍향동': 황금동_풍향동,
#   '하남동': 황금동_하남동,
#   '하산동': 황금동_하산동,
#   '학동': 황금동_학동,
#   '행암동': 황금동_행암동,
#   '호남동': 황금동_호남동,
#   '화암동': 황금동_화암동,
#   '화장동': 황금동_화장동,
#   '화정동': 황금동_화정동,
#   '황금동': 황금동_황금동,
#   '황룡동': 황금동_황룡동,
#   '효령동': 황금동_효령동,
#   '흑석동': 황금동_흑석동},
#  '황룡동': {'각화동': 황룡동_각화동,
#   '계림동': 황룡동_계림동,
#   '고룡동': 황룡동_고룡동,
#   '광산동': 황룡동_광산동,
#   '광산동.1': 황룡동_광산동.1,
#   '광천동': 황룡동_광천동,
#   '구동': 황룡동_구동,
#   '구소동': 황룡동_구소동,
#   '궁동': 황룡동_궁동,
#   '금곡동': 황룡동_금곡동,
#   '금동': 황룡동_금동,
#   '금호동': 황룡동_금호동,
#   '남동': 황룡동_남동,
#   '남산동': 황룡동_남산동,
#   '내남동': 황룡동_내남동,
#   '내방동': 황룡동_내방동,
#   '내산동': 황룡동_내산동,
#   '노대동': 황룡동_노대동,
#   '농성동': 황룡동_농성동,
#   '누문동': 황룡동_누문동,
#   '대산동': 황룡동_대산동,
#   '대의동': 황룡동_대의동,
#   '대인동': 황룡동_대인동,
#   '대지동': 황룡동_대지동,
#   '대촌동': 황룡동_대촌동,
#   '덕남동': 황룡동_덕남동,
#   '덕림동': 황룡동_덕림동,
#   '덕의동': 황룡동_덕의동,
#   '덕흥동': 황룡동_덕흥동,
#   '도금동': 황룡동_도금동,
#   '도덕동': 황룡동_도덕동,
#   '도산동': 황룡동_도산동,
#   '도천동': 황룡동_도천동,
#   '도호동': 황룡동_도호동,
#   '동림동': 황룡동_동림동,
#   '동림동.1': 황룡동_동림동.1,
#   '동명동': 황룡동_동명동,
#   '동산동': 황룡동_동산동,
#   '동천동': 황룡동_동천동,
#   '동호동': 황룡동_동호동,
#   '두암동': 황룡동_두암동,
#   '두정동': 황룡동_두정동,
#   '등임동': 황룡동_등임동,
#   '마륵동': 황룡동_마륵동,
#   '망월동': 황룡동_망월동,
#   '매곡동': 황룡동_매곡동,
#   '매월동': 황룡동_매월동,
#   '명도동': 황룡동_명도동,
#   '명화동': 황룡동_명화동,
#   '문흥동': 황룡동_문흥동,
#   '박호동': 황룡동_박호동,
#   '방림동': 황룡동_방림동,
#   '백운동': 황룡동_백운동,
#   '벽진동': 황룡동_벽진동,
#   '복룡동': 황룡동_복룡동,
#   '본덕동': 황룡동_본덕동,
#   '본촌동': 황룡동_본촌동,
#   '봉선동': 황룡동_봉선동,
#   '북동': 황룡동_북동,
#   '북산동': 황룡동_북산동,
#   '불로동': 황룡동_불로동,
#   '비아동': 황룡동_비아동,
#   '사동': 황룡동_사동,
#   '사호동': 황룡동_사호동,
#   '산막동': 황룡동_산막동,
#   '산수동': 황룡동_산수동,
#   '산수동.1': 황룡동_산수동.1,
#   '산월동': 황룡동_산월동,
#   '산정동': 황룡동_산정동,
#   '삼각동': 황룡동_삼각동,
#   '삼거동': 황룡동_삼거동,
#   '삼도동': 황룡동_삼도동,
#   '생용동': 황룡동_생용동,
#   '서동': 황룡동_서동,
#   '서봉동': 황룡동_서봉동,
#   '서석동': 황룡동_서석동,
#   '서창동': 황룡동_서창동,
#   '석정동': 황룡동_석정동,
#   '선교동': 황룡동_선교동,
#   '선동': 황룡동_선동,
#   '선암동': 황룡동_선암동,
#   '세하동': 황룡동_세하동,
#   '소촌동': 황룡동_소촌동,
#   '소태동': 황룡동_소태동,
#   '송대동': 황룡동_송대동,
#   '송산동': 황룡동_송산동,
#   '송정동': 황룡동_송정동,
#   '송촌동': 황룡동_송촌동,
#   '송치동': 황룡동_송치동,
#   '송하동': 황룡동_송하동,
#   '송학동': 황룡동_송학동,
#   '수곡동': 황룡동_수곡동,
#   '수기동': 황룡동_수기동,
#   '수완동': 황룡동_수완동,
#   '승촌동': 황룡동_승촌동,
#   '신가동': 황룡동_신가동,
#   '신동': 황룡동_신동,
#   '신룡동': 황룡동_신룡동,
#   '신안동': 황룡동_신안동,
#   '신용동': 황룡동_신용동,
#   '신장동': 황룡동_신장동,
#   '신창동': 황룡동_신창동,
#   '신촌동': 황룡동_신촌동,
#   '쌍암동': 황룡동_쌍암동,
#   '쌍촌동': 황룡동_쌍촌동,
#   '안청동': 황룡동_안청동,
#   '압촌동': 황룡동_압촌동,
#   '양과동': 황룡동_양과동,
#   '양동': 황룡동_양동,
#   '양동.1': 황룡동_양동.1,
#   '양림동': 황룡동_양림동,
#   '양산동': 황룡동_양산동,
#   '양산동.1': 황룡동_양산동.1,
#   '양촌동': 황룡동_양촌동,
#   '연산동': 황룡동_연산동,
#   '연제동': 황룡동_연제동,
#   '오룡동': 황룡동_오룡동,
#   '오산동': 황룡동_오산동,
#   '오선동': 황룡동_오선동,
#   '오운동': 황룡동_오운동,
#   '오치동': 황룡동_오치동,
#   '옥동': 황룡동_옥동,
#   '왕동': 황룡동_왕동,
#   '요기동': 황룡동_요기동,
#   '용강동': 황룡동_용강동,
#   '용곡동': 황룡동_용곡동,
#   '용동': 황룡동_용동,
#   '용두동': 황룡동_용두동,
#   '용두동.1': 황룡동_용두동.1,
#   '용봉동': 황룡동_용봉동,
#   '용봉동.1': 황룡동_용봉동.1,
#   '용산동': 황룡동_용산동,
#   '용연동': 황룡동_용연동,
#   '용전동': 황룡동_용전동,
#   '우산동': 황룡동_우산동,
#   '우산동.1': 황룡동_우산동.1,
#   '운남동': 황룡동_운남동,
#   '운림동': 황룡동_운림동,
#   '운수동': 황룡동_운수동,
#   '운암동': 황룡동_운암동,
#   '운정동': 황룡동_운정동,
#   '원산동': 황룡동_원산동,
#   '월계동': 황룡동_월계동,
#   '월곡동': 황룡동_월곡동,
#   '월남동': 황룡동_월남동,
#   '월산동': 황룡동_월산동,
#   '월성동': 황룡동_월성동,
#   '월전동': 황룡동_월전동,
#   '월출동': 황룡동_월출동,
#   '유계동': 황룡동_유계동,
#   '유동': 황룡동_유동,
#   '유촌동': 황룡동_유촌동,
#   '이장동': 황룡동_이장동,
#   '일곡동': 황룡동_일곡동,
#   '임곡동': 황룡동_임곡동,
#   '임동': 황룡동_임동,
#   '임암동': 황룡동_임암동,
#   '장덕동': 황룡동_장덕동,
#   '장동': 황룡동_장동,
#   '장등동': 황룡동_장등동,
#   '장록동': 황룡동_장록동,
#   '장수동': 황룡동_장수동,
#   '주월동': 황룡동_주월동,
#   '중흥동': 황룡동_중흥동,
#   '지산동': 황룡동_지산동,
#   '지산동.1': 황룡동_지산동.1,
#   '지석동': 황룡동_지석동,
#   '지야동': 황룡동_지야동,
#   '지정동': 황룡동_지정동,
#   '지죽동': 황룡동_지죽동,
#   '지평동': 황룡동_지평동,
#   '진곡동': 황룡동_진곡동,
#   '진월동': 황룡동_진월동,
#   '청풍동': 황룡동_청풍동,
#   '충장동': 황룡동_충장동,
#   '충효동': 황룡동_충효동,
#   '치평동': 황룡동_치평동,
#   '칠석동': 황룡동_칠석동,
#   '태령동': 황룡동_태령동,
#   '풍암동': 황룡동_풍암동,
#   '풍향동': 황룡동_풍향동,
#   '하남동': 황룡동_하남동,
#   '하산동': 황룡동_하산동,
#   '학동': 황룡동_학동,
#   '행암동': 황룡동_행암동,
#   '호남동': 황룡동_호남동,
#   '화암동': 황룡동_화암동,
#   '화장동': 황룡동_화장동,
#   '화정동': 황룡동_화정동,
#   '황금동': 황룡동_황금동,
#   '황룡동': 황룡동_황룡동,
#   '효령동': 황룡동_효령동,
#   '흑석동': 황룡동_흑석동},
#  '효령동': {'각화동': 효령동_각화동,
#   '계림동': 효령동_계림동,
#   '고룡동': 효령동_고룡동,
#   '광산동': 효령동_광산동,
#   '광산동.1': 효령동_광산동.1,
#   '광천동': 효령동_광천동,
#   '구동': 효령동_구동,
#   '구소동': 효령동_구소동,
#   '궁동': 효령동_궁동,
#   '금곡동': 효령동_금곡동,
#   '금동': 효령동_금동,
#   '금호동': 효령동_금호동,
#   '남동': 효령동_남동,
#   '남산동': 효령동_남산동,
#   '내남동': 효령동_내남동,
#   '내방동': 효령동_내방동,
#   '내산동': 효령동_내산동,
#   '노대동': 효령동_노대동,
#   '농성동': 효령동_농성동,
#   '누문동': 효령동_누문동,
#   '대산동': 효령동_대산동,
#   '대의동': 효령동_대의동,
#   '대인동': 효령동_대인동,
#   '대지동': 효령동_대지동,
#   '대촌동': 효령동_대촌동,
#   '덕남동': 효령동_덕남동,
#   '덕림동': 효령동_덕림동,
#   '덕의동': 효령동_덕의동,
#   '덕흥동': 효령동_덕흥동,
#   '도금동': 효령동_도금동,
#   '도덕동': 효령동_도덕동,
#   '도산동': 효령동_도산동,
#   '도천동': 효령동_도천동,
#   '도호동': 효령동_도호동,
#   '동림동': 효령동_동림동,
#   '동림동.1': 효령동_동림동.1,
#   '동명동': 효령동_동명동,
#   '동산동': 효령동_동산동,
#   '동천동': 효령동_동천동,
#   '동호동': 효령동_동호동,
#   '두암동': 효령동_두암동,
#   '두정동': 효령동_두정동,
#   '등임동': 효령동_등임동,
#   '마륵동': 효령동_마륵동,
#   '망월동': 효령동_망월동,
#   '매곡동': 효령동_매곡동,
#   '매월동': 효령동_매월동,
#   '명도동': 효령동_명도동,
#   '명화동': 효령동_명화동,
#   '문흥동': 효령동_문흥동,
#   '박호동': 효령동_박호동,
#   '방림동': 효령동_방림동,
#   '백운동': 효령동_백운동,
#   '벽진동': 효령동_벽진동,
#   '복룡동': 효령동_복룡동,
#   '본덕동': 효령동_본덕동,
#   '본촌동': 효령동_본촌동,
#   '봉선동': 효령동_봉선동,
#   '북동': 효령동_북동,
#   '북산동': 효령동_북산동,
#   '불로동': 효령동_불로동,
#   '비아동': 효령동_비아동,
#   '사동': 효령동_사동,
#   '사호동': 효령동_사호동,
#   '산막동': 효령동_산막동,
#   '산수동': 효령동_산수동,
#   '산수동.1': 효령동_산수동.1,
#   '산월동': 효령동_산월동,
#   '산정동': 효령동_산정동,
#   '삼각동': 효령동_삼각동,
#   '삼거동': 효령동_삼거동,
#   '삼도동': 효령동_삼도동,
#   '생용동': 효령동_생용동,
#   '서동': 효령동_서동,
#   '서봉동': 효령동_서봉동,
#   '서석동': 효령동_서석동,
#   '서창동': 효령동_서창동,
#   '석정동': 효령동_석정동,
#   '선교동': 효령동_선교동,
#   '선동': 효령동_선동,
#   '선암동': 효령동_선암동,
#   '세하동': 효령동_세하동,
#   '소촌동': 효령동_소촌동,
#   '소태동': 효령동_소태동,
#   '송대동': 효령동_송대동,
#   '송산동': 효령동_송산동,
#   '송정동': 효령동_송정동,
#   '송촌동': 효령동_송촌동,
#   '송치동': 효령동_송치동,
#   '송하동': 효령동_송하동,
#   '송학동': 효령동_송학동,
#   '수곡동': 효령동_수곡동,
#   '수기동': 효령동_수기동,
#   '수완동': 효령동_수완동,
#   '승촌동': 효령동_승촌동,
#   '신가동': 효령동_신가동,
#   '신동': 효령동_신동,
#   '신룡동': 효령동_신룡동,
#   '신안동': 효령동_신안동,
#   '신용동': 효령동_신용동,
#   '신장동': 효령동_신장동,
#   '신창동': 효령동_신창동,
#   '신촌동': 효령동_신촌동,
#   '쌍암동': 효령동_쌍암동,
#   '쌍촌동': 효령동_쌍촌동,
#   '안청동': 효령동_안청동,
#   '압촌동': 효령동_압촌동,
#   '양과동': 효령동_양과동,
#   '양동': 효령동_양동,
#   '양동.1': 효령동_양동.1,
#   '양림동': 효령동_양림동,
#   '양산동': 효령동_양산동,
#   '양산동.1': 효령동_양산동.1,
#   '양촌동': 효령동_양촌동,
#   '연산동': 효령동_연산동,
#   '연제동': 효령동_연제동,
#   '오룡동': 효령동_오룡동,
#   '오산동': 효령동_오산동,
#   '오선동': 효령동_오선동,
#   '오운동': 효령동_오운동,
#   '오치동': 효령동_오치동,
#   '옥동': 효령동_옥동,
#   '왕동': 효령동_왕동,
#   '요기동': 효령동_요기동,
#   '용강동': 효령동_용강동,
#   '용곡동': 효령동_용곡동,
#   '용동': 효령동_용동,
#   '용두동': 효령동_용두동,
#   '용두동.1': 효령동_용두동.1,
#   '용봉동': 효령동_용봉동,
#   '용봉동.1': 효령동_용봉동.1,
#   '용산동': 효령동_용산동,
#   '용연동': 효령동_용연동,
#   '용전동': 효령동_용전동,
#   '우산동': 효령동_우산동,
#   '우산동.1': 효령동_우산동.1,
#   '운남동': 효령동_운남동,
#   '운림동': 효령동_운림동,
#   '운수동': 효령동_운수동,
#   '운암동': 효령동_운암동,
#   '운정동': 효령동_운정동,
#   '원산동': 효령동_원산동,
#   '월계동': 효령동_월계동,
#   '월곡동': 효령동_월곡동,
#   '월남동': 효령동_월남동,
#   '월산동': 효령동_월산동,
#   '월성동': 효령동_월성동,
#   '월전동': 효령동_월전동,
#   '월출동': 효령동_월출동,
#   '유계동': 효령동_유계동,
#   '유동': 효령동_유동,
#   '유촌동': 효령동_유촌동,
#   '이장동': 효령동_이장동,
#   '일곡동': 효령동_일곡동,
#   '임곡동': 효령동_임곡동,
#   '임동': 효령동_임동,
#   '임암동': 효령동_임암동,
#   '장덕동': 효령동_장덕동,
#   '장동': 효령동_장동,
#   '장등동': 효령동_장등동,
#   '장록동': 효령동_장록동,
#   '장수동': 효령동_장수동,
#   '주월동': 효령동_주월동,
#   '중흥동': 효령동_중흥동,
#   '지산동': 효령동_지산동,
#   '지산동.1': 효령동_지산동.1,
#   '지석동': 효령동_지석동,
#   '지야동': 효령동_지야동,
#   '지정동': 효령동_지정동,
#   '지죽동': 효령동_지죽동,
#   '지평동': 효령동_지평동,
#   '진곡동': 효령동_진곡동,
#   '진월동': 효령동_진월동,
#   '청풍동': 효령동_청풍동,
#   '충장동': 효령동_충장동,
#   '충효동': 효령동_충효동,
#   '치평동': 효령동_치평동,
#   '칠석동': 효령동_칠석동,
#   '태령동': 효령동_태령동,
#   '풍암동': 효령동_풍암동,
#   '풍향동': 효령동_풍향동,
#   '하남동': 효령동_하남동,
#   '하산동': 효령동_하산동,
#   '학동': 효령동_학동,
#   '행암동': 효령동_행암동,
#   '호남동': 효령동_호남동,
#   '화암동': 효령동_화암동,
#   '화장동': 효령동_화장동,
#   '화정동': 효령동_화정동,
#   '황금동': 효령동_황금동,
#   '황룡동': 효령동_황룡동,
#   '효령동': 효령동_효령동,
#   '흑석동': 효령동_흑석동},
#  '흑석동': {'각화동': 흑석동_각화동,
#   '계림동': 흑석동_계림동,
#   '고룡동': 흑석동_고룡동,
#   '광산동': 흑석동_광산동,
#   '광산동.1': 흑석동_광산동.1,
#   '광천동': 흑석동_광천동,
#   '구동': 흑석동_구동,
#   '구소동': 흑석동_구소동,
#   '궁동': 흑석동_궁동,
#   '금곡동': 흑석동_금곡동,
#   '금동': 흑석동_금동,
#   '금호동': 흑석동_금호동,
#   '남동': 흑석동_남동,
#   '남산동': 흑석동_남산동,
#   '내남동': 흑석동_내남동,
#   '내방동': 흑석동_내방동,
#   '내산동': 흑석동_내산동,
#   '노대동': 흑석동_노대동,
#   '농성동': 흑석동_농성동,
#   '누문동': 흑석동_누문동,
#   '대산동': 흑석동_대산동,
#   '대의동': 흑석동_대의동,
#   '대인동': 흑석동_대인동,
#   '대지동': 흑석동_대지동,
#   '대촌동': 흑석동_대촌동,
#   '덕남동': 흑석동_덕남동,
#   '덕림동': 흑석동_덕림동,
#   '덕의동': 흑석동_덕의동,
#   '덕흥동': 흑석동_덕흥동,
#   '도금동': 흑석동_도금동,
#   '도덕동': 흑석동_도덕동,
#   '도산동': 흑석동_도산동,
#   '도천동': 흑석동_도천동,
#   '도호동': 흑석동_도호동,
#   '동림동': 흑석동_동림동,
#   '동림동.1': 흑석동_동림동.1,
#   '동명동': 흑석동_동명동,
#   '동산동': 흑석동_동산동,
#   '동천동': 흑석동_동천동,
#   '동호동': 흑석동_동호동,
#   '두암동': 흑석동_두암동,
#   '두정동': 흑석동_두정동,
#   '등임동': 흑석동_등임동,
#   '마륵동': 흑석동_마륵동,
#   '망월동': 흑석동_망월동,
#   '매곡동': 흑석동_매곡동,
#   '매월동': 흑석동_매월동,
#   '명도동': 흑석동_명도동,
#   '명화동': 흑석동_명화동,
#   '문흥동': 흑석동_문흥동,
#   '박호동': 흑석동_박호동,
#   '방림동': 흑석동_방림동,
#   '백운동': 흑석동_백운동,
#   '벽진동': 흑석동_벽진동,
#   '복룡동': 흑석동_복룡동,
#   '본덕동': 흑석동_본덕동,
#   '본촌동': 흑석동_본촌동,
#   '봉선동': 흑석동_봉선동,
#   '북동': 흑석동_북동,
#   '북산동': 흑석동_북산동,
#   '불로동': 흑석동_불로동,
#   '비아동': 흑석동_비아동,
#   '사동': 흑석동_사동,
#   '사호동': 흑석동_사호동,
#   '산막동': 흑석동_산막동,
#   '산수동': 흑석동_산수동,
#   '산수동.1': 흑석동_산수동.1,
#   '산월동': 흑석동_산월동,
#   '산정동': 흑석동_산정동,
#   '삼각동': 흑석동_삼각동,
#   '삼거동': 흑석동_삼거동,
#   '삼도동': 흑석동_삼도동,
#   '생용동': 흑석동_생용동,
#   '서동': 흑석동_서동,
#   '서봉동': 흑석동_서봉동,
#   '서석동': 흑석동_서석동,
#   '서창동': 흑석동_서창동,
#   '석정동': 흑석동_석정동,
#   '선교동': 흑석동_선교동,
#   '선동': 흑석동_선동,
#   '선암동': 흑석동_선암동,
#   '세하동': 흑석동_세하동,
#   '소촌동': 흑석동_소촌동,
#   '소태동': 흑석동_소태동,
#   '송대동': 흑석동_송대동,
#   '송산동': 흑석동_송산동,
#   '송정동': 흑석동_송정동,
#   '송촌동': 흑석동_송촌동,
#   '송치동': 흑석동_송치동,
#   '송하동': 흑석동_송하동,
#   '송학동': 흑석동_송학동,
#   '수곡동': 흑석동_수곡동,
#   '수기동': 흑석동_수기동,
#   '수완동': 흑석동_수완동,
#   '승촌동': 흑석동_승촌동,
#   '신가동': 흑석동_신가동,
#   '신동': 흑석동_신동,
#   '신룡동': 흑석동_신룡동,
#   '신안동': 흑석동_신안동,
#   '신용동': 흑석동_신용동,
#   '신장동': 흑석동_신장동,
#   '신창동': 흑석동_신창동,
#   '신촌동': 흑석동_신촌동,
#   '쌍암동': 흑석동_쌍암동,
#   '쌍촌동': 흑석동_쌍촌동,
#   '안청동': 흑석동_안청동,
#   '압촌동': 흑석동_압촌동,
#   '양과동': 흑석동_양과동,
#   '양동': 흑석동_양동,
#   '양동.1': 흑석동_양동.1,
#   '양림동': 흑석동_양림동,
#   '양산동': 흑석동_양산동,
#   '양산동.1': 흑석동_양산동.1,
#   '양촌동': 흑석동_양촌동,
#   '연산동': 흑석동_연산동,
#   '연제동': 흑석동_연제동,
#   '오룡동': 흑석동_오룡동,
#   '오산동': 흑석동_오산동,
#   '오선동': 흑석동_오선동,
#   '오운동': 흑석동_오운동,
#   '오치동': 흑석동_오치동,
#   '옥동': 흑석동_옥동,
#   '왕동': 흑석동_왕동,
#   '요기동': 흑석동_요기동,
#   '용강동': 흑석동_용강동,
#   '용곡동': 흑석동_용곡동,
#   '용동': 흑석동_용동,
#   '용두동': 흑석동_용두동,
#   '용두동.1': 흑석동_용두동.1,
#   '용봉동': 흑석동_용봉동,
#   '용봉동.1': 흑석동_용봉동.1,
#   '용산동': 흑석동_용산동,
#   '용연동': 흑석동_용연동,
#   '용전동': 흑석동_용전동,
#   '우산동': 흑석동_우산동,
#   '우산동.1': 흑석동_우산동.1,
#   '운남동': 흑석동_운남동,
#   '운림동': 흑석동_운림동,
#   '운수동': 흑석동_운수동,
#   '운암동': 흑석동_운암동,
#   '운정동': 흑석동_운정동,
#   '원산동': 흑석동_원산동,
#   '월계동': 흑석동_월계동,
#   '월곡동': 흑석동_월곡동,
#   '월남동': 흑석동_월남동,
#   '월산동': 흑석동_월산동,
#   '월성동': 흑석동_월성동,
#   '월전동': 흑석동_월전동,
#   '월출동': 흑석동_월출동,
#   '유계동': 흑석동_유계동,
#   '유동': 흑석동_유동,
#   '유촌동': 흑석동_유촌동,
#   '이장동': 흑석동_이장동,
#   '일곡동': 흑석동_일곡동,
#   '임곡동': 흑석동_임곡동,
#   '임동': 흑석동_임동,
#   '임암동': 흑석동_임암동,
#   '장덕동': 흑석동_장덕동,
#   '장동': 흑석동_장동,
#   '장등동': 흑석동_장등동,
#   '장록동': 흑석동_장록동,
#   '장수동': 흑석동_장수동,
#   '주월동': 흑석동_주월동,
#   '중흥동': 흑석동_중흥동,
#   '지산동': 흑석동_지산동,
#   '지산동.1': 흑석동_지산동.1,
#   '지석동': 흑석동_지석동,
#   '지야동': 흑석동_지야동,
#   '지정동': 흑석동_지정동,
#   '지죽동': 흑석동_지죽동,
#   '지평동': 흑석동_지평동,
#   '진곡동': 흑석동_진곡동,
#   '진월동': 흑석동_진월동,
#   '청풍동': 흑석동_청풍동,
#   '충장동': 흑석동_충장동,
#   '충효동': 흑석동_충효동,
#   '치평동': 흑석동_치평동,
#   '칠석동': 흑석동_칠석동,
#   '태령동': 흑석동_태령동,
#   '풍암동': 흑석동_풍암동,
#   '풍향동': 흑석동_풍향동,
#   '하남동': 흑석동_하남동,
#   '하산동': 흑석동_하산동,
#   '학동': 흑석동_학동,
#   '행암동': 흑석동_행암동,
#   '호남동': 흑석동_호남동,
#   '화암동': 흑석동_화암동,
#   '화장동': 흑석동_화장동,
#   '화정동': 흑석동_화정동,
#   '황금동': 흑석동_황금동,
#   '황룡동': 흑석동_황룡동,
#   '효령동': 흑석동_효령동,
#   '흑석동': 흑석동_흑석동}}
